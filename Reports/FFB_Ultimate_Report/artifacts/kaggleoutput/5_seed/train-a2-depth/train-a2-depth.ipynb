# %% [markdown]
# # A.2 - Real Depth Only Training
#
# **Experiment:** A.2
# **Input:** Real depth maps (3-channel, normalized 0-255)
# **Objective:** Detection using real depth sensor data only
# **Classes:** 1 (fresh_fruit_bunch)
#
# ## Workflow
# 1. Load real depth dataset (YOLO format)
# 2. Train YOLOv11n with 5 seeds (42, 123, 456, 789, 101)
# 3. Evaluate on test set
# 4. Calculate mean ± std deviation
#
# ## Training Config
# - Model: YOLOv11n
# - Epochs: 100
# - Patience: 30
# - Other parameters: default
#
# ## Depth Preprocessing
# - Raw depth: 0.6m - 6.0m range
# - Normalized to 0-255 grayscale
# - Replicated to 3 channels (R=G=B)

# %%
# =============================================================================
# Cell 1: Setup
# =============================================================================
import os
import torch
import numpy as np
import shutil
from pathlib import Path
from datetime import datetime

IS_KAGGLE = os.path.exists('/kaggle/input')
print(f"Running on: {'Kaggle' if IS_KAGGLE else 'Local'}")

# Paths
DATASET_PATH = Path('/kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth')
BASE_PATH = Path('/kaggle/working')
RUNS_PATH = BASE_PATH / 'runs' / 'detect'
KAGGLE_OUTPUT = BASE_PATH / 'kaggleoutput'
KAGGLE_OUTPUT.mkdir(parents=True, exist_ok=True)

print(f"Dataset: {DATASET_PATH} (exists: {DATASET_PATH.exists()})")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# Verify dataset
for split in ['train', 'val', 'test']:
    imgs = len(list((DATASET_PATH / 'images' / split).glob('*.png')))
    lbls = len(list((DATASET_PATH / 'labels' / split).glob('*.txt')))
    print(f"  {split}: {imgs} images, {lbls} labels")
# Out:
# Running on: Kaggle
# Dataset: /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth (exists: True)
# CUDA: True
# GPU: Tesla T4
#   train: 280 images, 280 labels
#   val: 80 images, 80 labels
#   test: 40 images, 40 labels

# %%
# %%writefile /kaggle/working/dataset_depth.yaml
# # A.2 Real Depth Only Dataset
# path: /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth
# train: images/train
# val: images/val
# test: images/test
#
# nc: 1
# names: ['fresh_fruit_bunch']
# Out:
# Writing /kaggle/working/dataset_depth.yaml

# %%
# =============================================================================
# Cell 3: Verify YAML
# =============================================================================
config_path = Path('/kaggle/working/dataset_depth.yaml')
print(f"YAML: {config_path}")
print(config_path.read_text())
# Out:
# YAML: /kaggle/working/dataset_depth.yaml
# # A.2 Real Depth Only Dataset
# path: /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth
# train: images/train
# val: images/val
# test: images/test
#
# nc: 1
# names: ['fresh_fruit_bunch']

# %%
# =============================================================================
# Cell 4: Install Ultralytics
# =============================================================================
# !pip install -q ultralytics

from ultralytics import YOLO
import pandas as pd
print("Ultralytics ready")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.9 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics ready

# %%
# =============================================================================
# Cell 5: Training Config
# =============================================================================
SEEDS = [42, 123, 456, 789, 101]
EXP_PREFIX = 'exp_a2_depth'

print(f"Seeds: {SEEDS} ({len(SEEDS)} runs)")
print("Metrics: mean ± std deviation")
# Out:
# Seeds: [42, 123, 456, 789, 101] (5 runs)
# Metrics: mean ± std deviation

# %%
# =============================================================================
# Cell 6: Training Loop
# =============================================================================
for seed in SEEDS:
    print(f"\n{'='*60}")
    print(f"TRAINING A.2 REAL DEPTH - Seed {seed} ({SEEDS.index(seed)+1}/{len(SEEDS)})")
    print(f"{'='*60}\n")
    
    torch.manual_seed(seed)
    np.random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      3.01G      1.516     0.9796      1.205         48        640: 100% ━━━━━━━━━━━━ 18/18 4.3it/s 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.733      0.661      0.717      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.02G      1.487     0.9745      1.176         24        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.718      0.661      0.713      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      3.04G      1.499     0.9661      1.196         33        640: 100% ━━━━━━━━━━━━ 18/18 4.4it/s 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        186      0.759       0.66      0.723      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      3.05G      1.455     0.9322      1.178         35        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186       0.74      0.675      0.734      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      3.06G      1.456     0.9275      1.169         32        640: 100% ━━━━━━━━━━━━ 18/18 4.5it/s 4.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.709      0.699      0.722      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      3.08G      1.436     0.9181      1.154         38        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186       0.75      0.679      0.724       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      3.09G      1.478     0.9289       1.18         40        640: 100% ━━━━━━━━━━━━ 18/18 4.3it/s 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.735      0.688      0.722      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      3.11G      1.427     0.8987      1.151         43        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.756      0.667      0.727      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      3.12G      1.436       0.91      1.163         36        640: 100% ━━━━━━━━━━━━ 18/18 4.5it/s 4.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        186      0.703      0.726      0.719      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      3.14G      1.419     0.8925      1.143         38        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.4it/s 0.4s
#                    all         80        186      0.693       0.68      0.704      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      3.15G      1.415     0.9244      1.167         35        640: 100% ━━━━━━━━━━━━ 18/18 4.4it/s 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.725      0.694      0.715      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      3.17G      1.373     0.8542      1.135         41        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.735      0.677      0.708       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      3.18G      1.438     0.8868      1.157         46        640: 100% ━━━━━━━━━━━━ 18/18 4.6it/s 3.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.6it/s 0.6s
#                    all         80        186      0.746      0.661      0.719      0.259
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 33, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 63 epochs completed in 0.093 hours.
# Optimizer stripped from /kaggle/working/runs/detect/exp_a2_depth_seed101/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/exp_a2_depth_seed101/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/exp_a2_depth_seed101/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.0it/s 1.0s
#                    all         80        186      0.754       0.71      0.735      0.324
# Speed: 0.1ms preprocess, 1.1ms inference, 0.0ms loss, 2.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/exp_a2_depth_seed101
#
# Seed 101 complete!
# mAP50: 0.735

# %%
# =============================================================================
# Cell 7: Evaluation on Test Set
# =============================================================================
results_dict = {}

print("="*60)
print("EVALUATION ON TEST SET")
print("="*60)

for seed in SEEDS:
    model_path = RUNS_PATH / f"{EXP_PREFIX}_seed{seed}" / 'weights' / 'best.pt'
    
    if not model_path.exists():
        print(f"Not found: {model_path}")
        continue
    
    print(f"\nSeed {seed}:")
    model = YOLO(str(model_path))
    metrics = model.val(data=str(config_path), split='test')
    
    results_dict[seed] = {
        'mAP50': metrics.box.map50,
        'mAP50-95': metrics.box.map,
        'Precision': metrics.box.mp,
        'Recall': metrics.box.mr
    }
    
    print(f"  mAP50: {metrics.box.map50:.3f}")
    print(f"  mAP50-95: {metrics.box.map:.3f}")
    print(f"  Precision: {metrics.box.mp:.3f}")
    print(f"  Recall: {metrics.box.mr:.3f}")
# Out:
# ============================================================
# EVALUATION ON TEST SET
# ============================================================
#
# Seed 42:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.8 ms, read: 53.2±8.0 MB/s, size: 280.0 KB)
# val: Scanning /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 235.8it/s 0.2s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         40        105      0.765      0.774      0.787      0.291
# Speed: 3.8ms preprocess, 12.6ms inference, 0.0ms loss, 4.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
#   mAP50: 0.787
#   mAP50-95: 0.291
#   Precision: 0.765
#   Recall: 0.774
#
# Seed 123:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 375.3±117.1 MB/s, size: 247.3 KB)
# val: Scanning /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 649.3it/s 0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         40        105       0.77      0.695      0.728      0.256
# Speed: 3.6ms preprocess, 4.8ms inference, 0.0ms loss, 8.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val2
#   mAP50: 0.728
#   mAP50-95: 0.256
#   Precision: 0.770
#   Recall: 0.695
#
# Seed 456:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 356.3±63.3 MB/s, size: 250.2 KB)
# val: Scanning /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 679.5it/s 0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         40        105      0.759      0.721      0.751      0.278
# Speed: 3.3ms preprocess, 3.2ms inference, 0.0ms loss, 4.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val3
#   mAP50: 0.751
#   mAP50-95: 0.278
#   Precision: 0.759
#   Recall: 0.721
#
# Seed 789:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 452.8±123.2 MB/s, size: 282.6 KB)
# val: Scanning /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 650.1it/s 0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         40        105      0.725      0.762      0.779      0.295
# Speed: 3.4ms preprocess, 3.9ms inference, 0.0ms loss, 8.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val4
#   mAP50: 0.779
#   mAP50-95: 0.295
#   Precision: 0.725
#   Recall: 0.762
#
# Seed 101:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 390.6±153.0 MB/s, size: 270.6 KB)
# val: Scanning /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 680.6it/s 0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-localization-depth-dataset/ffb_localization_depth/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         40        105      0.698      0.676      0.696      0.259
# Speed: 3.0ms preprocess, 3.4ms inference, 0.0ms loss, 7.3ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val5
#   mAP50: 0.696
#   mAP50-95: 0.259
#   Precision: 0.698
#   Recall: 0.676

# %%
# =============================================================================
# Cell 8: Results Summary
# =============================================================================
df = pd.DataFrame(results_dict).T
df.index.name = 'Seed'

# Calculate mean and std
avg = df.mean()
std = df.std()

print("\n" + "="*60)
print("A.2 REAL DEPTH ONLY - FINAL RESULTS")
print("="*60 + "\n")
print(df.to_string(float_format=lambda x: f"{x:.3f}"))

print("\n" + "-"*60)
print("SUMMARY (Mean ± Std)")
print("-"*60)
for col in df.columns:
    print(f"  {col}: {avg[col]:.3f} ± {std[col]:.3f}")
# Out:
# ============================================================
# A.2 REAL DEPTH ONLY - FINAL RESULTS
# ============================================================
#
#       mAP50  mAP50-95  Precision  Recall
# Seed
# 42    0.787     0.291      0.765   0.774
# 123   0.728     0.256      0.770   0.695
# 456   0.751     0.278      0.759   0.721
# 789   0.779     0.295      0.725   0.762
# 101   0.696     0.259      0.698   0.676
#
# ------------------------------------------------------------
# SUMMARY (Mean ± Std)
# ------------------------------------------------------------
#   mAP50: 0.748 ± 0.038
#   mAP50-95: 0.276 ± 0.018
#   Precision: 0.743 ± 0.031
#   Recall: 0.726 ± 0.042

# %%
# =============================================================================
# Cell 9: Save Results
# =============================================================================
output_file = KAGGLE_OUTPUT / 'a2_depth_results.txt'

with open(output_file, 'w') as f:
    f.write("="*60 + "\n")
    f.write("A.2 Real Depth Only Results\n")
    f.write(f"Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write("Training: epochs=100, patience=30, other=default\n")
    f.write(f"Seeds: {SEEDS}\n")
    f.write("="*60 + "\n\n")
    f.write("Per-Seed Results:\n")
    f.write(df.to_string(float_format=lambda x: f"{x:.3f}"))
    f.write("\n\n" + "-"*60 + "\n")
    f.write("Summary (Mean ± Std):\n")
    for col in df.columns:
        f.write(f"  {col}: {avg[col]:.3f} ± {std[col]:.3f}\n")

print(f"Results saved: {output_file}")
# Out:
# Results saved: /kaggle/working/kaggleoutput/a2_depth_results.txt

# %%
# =============================================================================
# Cell 10: Create Archives
# =============================================================================
if RUNS_PATH.exists():
    shutil.make_archive('/kaggle/working/a2_runs', 'zip', RUNS_PATH)
    print(f"a2_runs.zip: {os.path.getsize('/kaggle/working/a2_runs.zip')/1024/1024:.1f} MB")

shutil.make_archive('/kaggle/working/a2_output', 'zip', KAGGLE_OUTPUT)
print("a2_output.zip created")

print("\nDownload from Output tab")
# Out:
# a2_runs.zip: 85.7 MB
# a2_output.zip created
#
# Download from Output tab
