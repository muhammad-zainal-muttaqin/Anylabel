# %%
# ============================================================
# CELL 1: Setup & Imports
# ============================================================
# !pip install -q ultralytics

import os
import shutil
import cv2
import numpy as np
import torch
import torch.nn as nn
import pandas as pd
from pathlib import Path
from datetime import datetime

os.environ["WANDB_DISABLED"] = "true"

IS_KAGGLE = os.path.exists('/kaggle/input')
print(f"Running on: {'Kaggle' if IS_KAGGLE else 'Local'}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.8 MB/s eta 0:00:00
# Running on: Kaggle
# PyTorch: 2.8.0+cu126
# CUDA: True
# GPU: Tesla T4

# %%
# ============================================================
# CELL 2: Dataset Path Setup
# ============================================================
if IS_KAGGLE:
    DATASET_DIR = Path("/kaggle/input/ffb-localization-rgbd-dataset/ffb_localization_rgbd")
    WORK_DIR = Path("/kaggle/working/ffb_localization_rgbd")
    BASE_PATH = Path("/kaggle/working")
else:
    BASE_PATH = Path(r"D:/Work/Assisten Dosen/Anylabel/Experiments")
    DATASET_DIR = BASE_PATH / "datasets" / "ffb_localization_rgbd"
    WORK_DIR = BASE_PATH / "working" / "ffb_localization_rgbd"

RUNS_PATH = BASE_PATH / 'runs' / 'detect'
KAGGLE_OUTPUT = BASE_PATH / 'kaggleoutput'
KAGGLE_OUTPUT.mkdir(parents=True, exist_ok=True)

print(f"Dataset Dir: {DATASET_DIR}")
print(f"Work Dir: {WORK_DIR}")
# Out:
# Dataset Dir: /kaggle/input/ffb-localization-rgbd-dataset/ffb_localization_rgbd
# Work Dir: /kaggle/working/ffb_localization_rgbd

# %%
# ============================================================
# CELL 3: Create Pre-merged RGBD 4-Channel PNG Images
# ============================================================
def create_rgbd_dataset(root: Path, work_root: Path) -> None:
    splits = ("train", "val", "test")
    
    for split in splits:
        rgb_dir = root / "rgb" / split
        depth_dir = root / "depth" / split
        label_dir = root / "labels" / split
        
        if not all([rgb_dir.exists(), depth_dir.exists(), label_dir.exists()]):
            print(f"Warning: Missing folders for {split}")
            continue
        
        rgb_files = {p.name for p in rgb_dir.glob("*.png")}
        depth_files = {p.name for p in depth_dir.glob("*.png")}
        label_files = {p.with_suffix(".png").name for p in label_dir.glob("*.txt")}
        
        keep = rgb_files & depth_files & label_files
        print(f"{split}: Keep={len(keep)}")
        
        images_dir = work_root / "images" / split
        images_dir.mkdir(parents=True, exist_ok=True)
        
        labels_out_dir = work_root / "labels" / split
        labels_out_dir.mkdir(parents=True, exist_ok=True)
        
        for fname in keep:
            dst_rgbd = images_dir / fname
            
            if not dst_rgbd.exists():
                rgb = cv2.imread(str(rgb_dir / fname), cv2.IMREAD_COLOR)
                depth = cv2.imread(str(depth_dir / fname), cv2.IMREAD_GRAYSCALE)
                
                if rgb is None or depth is None:
                    continue
                
                if depth.shape[:2] != rgb.shape[:2]:
                    depth = cv2.resize(depth, (rgb.shape[1], rgb.shape[0]))
                
                rgbd = np.dstack([rgb, depth])
                cv2.imwrite(str(dst_rgbd), rgbd)
            
            src_label = label_dir / fname.replace(".png", ".txt")
            dst_label = labels_out_dir / fname.replace(".png", ".txt")
            if not dst_label.exists():
                shutil.copy2(src_label, dst_label)
        
        sample = list(images_dir.glob("*.png"))[0]
        test_img = cv2.imread(str(sample), cv2.IMREAD_UNCHANGED)
        print(f"  -> shape: {test_img.shape}")

create_rgbd_dataset(DATASET_DIR, WORK_DIR)

for p in WORK_DIR.rglob("*.cache"):
    try:
        p.unlink()
    except:
        pass
print("Done!")
# Out:
# train: Keep=280
#   -> shape: (720, 1280, 4)
# val: Keep=80
#   -> shape: (720, 1280, 4)
# test: Keep=40
#   -> shape: (720, 1280, 4)
# Done!

# %%
# ============================================================
# CELL 4: Monkey-Patch Ultralytics imread
# ============================================================
import ultralytics.utils.patches as patches

_original_imread = patches.imread

def imread_4ch(filename, flags=cv2.IMREAD_UNCHANGED):
    return _original_imread(filename, cv2.IMREAD_UNCHANGED)

patches.imread = imread_4ch
print("✅ Patched imread")

from ultralytics import YOLO
print("✅ YOLO imported")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ Patched imread
# ✅ YOLO imported

# %%
# ============================================================
# CELL 5: Create Dataset Config YAML dengan channels: 4
# ============================================================
config_content = f"""path: {WORK_DIR}
train: images/train
val: images/val
test: images/test

nc: 1
channels: 4

names:
  0: ffb
"""

config_path = WORK_DIR / "dataset_rgbd.yaml"
with open(config_path, 'w') as f:
    f.write(config_content)
print(f"✅ Config saved: {config_path}")
print("   (includes channels: 4)")
# Out:
# ✅ Config saved: /kaggle/working/ffb_localization_rgbd/dataset_rgbd.yaml
#    (includes channels: 4)

# %%
# ============================================================
# CELL 6: Custom Trainer & Validator with 4-Channel Support (FIXED)
# ============================================================
from ultralytics.models.yolo.detect import DetectionTrainer, DetectionValidator
from ultralytics.nn.autobackend import AutoBackend

def convert_conv_to_4ch(conv_layer):
    """Convert a conv layer from 3ch to 4ch input"""
    if conv_layer.in_channels == 4:
        return conv_layer
    
    new_conv = nn.Conv2d(
        in_channels=4,
        out_channels=conv_layer.out_channels,
        kernel_size=conv_layer.kernel_size,
        stride=conv_layer.stride,
        padding=conv_layer.padding,
        bias=conv_layer.bias is not None
    )
    
    with torch.no_grad():
        new_conv.weight[:, :3, :, :] = conv_layer.weight.clone()
        new_conv.weight[:, 3:4, :, :] = conv_layer.weight.mean(dim=1, keepdim=True)
        if conv_layer.bias is not None:
            new_conv.bias = nn.Parameter(conv_layer.bias.clone())
    
    return new_conv


def ensure_model_4ch(model):
    """Ensure model has 4-channel input, works with different model types"""
    try:
        # For AutoBackend wrapped models
        if hasattr(model, 'model') and hasattr(model.model, 'model'):
            first_conv = model.model.model[0].conv
            if first_conv.in_channels == 3:
                print("[4ch] Converting AutoBackend model...")
                model.model.model[0].conv = convert_conv_to_4ch(first_conv)
                return True
        # For direct DetectionModel
        elif hasattr(model, 'model') and hasattr(model.model[0], 'conv'):
            first_conv = model.model[0].conv
            if first_conv.in_channels == 3:
                print("[4ch] Converting DetectionModel...")
                model.model[0].conv = convert_conv_to_4ch(first_conv)
                return True
    except Exception as e:
        print(f"[4ch] Warning: {e}")
    return False


class RGBD4ChValidator(DetectionValidator):
    """Validator yang convert model ke 4ch sebelum validasi"""
    
    def __call__(self, trainer=None, model=None):
        """Override untuk convert model ke 4ch"""
        # Call parent first to setup everything
        # Model akan di-load dari path oleh parent class
        return super().__call__(trainer, model)
    
    def setup_model(self):
        """Override: setelah model di-load, convert ke 4ch"""
        super().setup_model()
        
        # self.model sudah di-set oleh parent
        if self.model is not None:
            ensure_model_4ch(self.model)
            print(f"[Validator] Model 4ch ready")


class RGBD4ChTrainer(DetectionTrainer):
    """Trainer yang convert model ke 4-channel"""
    
    def setup_model(self):
        """Setup model lalu convert ke 4-channel"""
        super().setup_model()
        
        first_conv = self.model.model[0].conv
        
        if first_conv.in_channels == 4:
            print("[Trainer] Model sudah 4-channel")
            return
        
        print(f"[Trainer] Converting to 4-channel...")
        self.model.model[0].conv = convert_conv_to_4ch(first_conv)
        print(f"[Trainer] ✅ Converted! Shape: {self.model.model[0].conv.weight.shape}")
    
    def get_validator(self):
        """Return custom validator"""
        self.loss_names = "box_loss", "cls_loss", "dfl_loss"
        return RGBD4ChValidator(
            self.test_loader, 
            save_dir=self.save_dir, 
            args=self.args,
            _callbacks=self.callbacks
        )

print("✅ Custom Trainer & Validator defined (FIXED)")
# Out:
# ✅ Custom Trainer & Validator defined (FIXED)

# %%
# ============================================================
# CELL 7: Training Configuration
# ============================================================
EXP_PREFIX = "exp_a3_rgbd"
SEEDS = [42, 123, 456, 789, 101]
EPOCHS = 100
IMGSZ = 640
BATCH_SIZE = 16
DEVICE = 0 if torch.cuda.is_available() else 'cpu'

print(f"Seeds: {SEEDS}")
print(f"Epochs: {EPOCHS}")
print(f"Batch: {BATCH_SIZE}")
print(f"Device: {DEVICE}")
# Out:
# Seeds: [42, 123, 456, 789, 101]
# Epochs: 100
# Batch: 16
# Device: 0

# %%
# ============================================================
# CELL 8: Training Loop
# ============================================================
results_all = {}

for seed in SEEDS:
    print(f"\n{'='*60}")
    print(f"TRAINING - Seed {seed} ({SEEDS.index(seed)+1}/{len(SEEDS)})")
    print(f"{'='*60}\n")
    
    trainer = RGBD4ChTrainer(overrides={
        'model': 'yolo11n.pt',
        'data': str(config_path),
        'imgsz': IMGSZ,
        'epochs': EPOCHS,
        'batch': BATCH_SIZE,
        'device': DEVICE,
        'seed': seed,
        'name': f"{EXP_PREFIX}_seed{seed}",
        'project': str(RUNS_PATH),
        'exist_ok': True,
        'pretrained': True,
        'patience': 30,
        'val': True,
        'hsv_h': 0.0,
        'hsv_s': 0.0,
        'hsv_v': 0.0,
        'degrees': 0.0,
        'translate': 0.1,
        'scale': 0.5,
        'fliplr': 0.5,
        'mosaic': 1.0,
        'mixup': 0.0,
        'copy_paste': 0.0,
        'erasing': 0.0,
    })
    
    trainer.train()
    
    results_all[seed] = {
        'model_path': str(RUNS_PATH / f"{EXP_PREFIX}_seed{seed}" / "weights" / "best.pt"),
    }
    
    print(f"\n✅ Seed {seed} completed!")
    
    del trainer
    torch.cuda.empty_cache()

print("\n" + "="*60)
print("ALL TRAINING COMPLETED!")
print("="*60)
# Out:
# ============================================================
# TRAINING - Seed 42 (1/5)
# ============================================================
#
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/ffb_localization_rgbd/dataset_rgbd.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.0, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_a3_rgbd_seed42, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/exp_a3_rgbd_seed42, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.6MB/s 0.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 63.7MB/s 0.1s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       608  ultralytics.nn.modules.conv.Conv             [4, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,179 parameters, 2,590,163 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# [Trainer] Model sudah 4-channel
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 66.1MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4427.3±1040.1 MB/s, size: 2076.3 KB)
# train: Scanning /kaggle/working/ffb_localization_rgbd/labels/train... 280 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━
0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.85G      1.318      0.803      1.117         40        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.816      0.806      0.846      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.87G      1.344     0.7811       1.11         55        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186      0.813      0.828      0.842      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.88G      1.339     0.7869      1.114         27        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.818      0.823      0.834      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      2.89G      1.316     0.7949      1.096         44        640: 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.789       0.86      0.855      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      2.91G        1.3     0.7581      1.082         37        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        186      0.788      0.833       0.85      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.92G      1.293     0.7377      1.093         30        640: 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.878      0.726      0.826      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.94G      1.243     0.7245       1.06         26        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.832      0.763      0.829      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      2.95G      1.286     0.7626      1.081         41        640: 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.854      0.758       0.81      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.97G      1.273     0.7529      1.082         57        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.817      0.769      0.813      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.98G      1.258     0.7311      1.066         43        640: 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.827      0.753      0.815      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100         3G      1.226     0.7255      1.056         49        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        186      0.858       0.79      0.828      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      3.01G      1.243      0.723      1.067         39        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186       0.86       0.79      0.847      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      3.03G      1.226     0.6885       1.05         39        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.837      0.799      0.822      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      3.04G      1.199      0.689      1.048         49        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        186      0.834      0.784      0.838       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      3.06G      1.195     0.6954      1.047         48        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.824      0.782      0.806      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.07G      1.173     0.6895      1.027         24        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186       0.81      0.774      0.802      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      3.09G      1.191     0.6727      1.045         33        640: 100% ━━━━━━━━━━━━ 18/18 4.3it/s 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.802      0.828      0.836      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100       3.1G      1.154     0.6537      1.023         35        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.854      0.754      0.836      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      3.12G      1.134     0.6536      1.022         32        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.771      0.813       0.84      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      3.13G      1.159     0.6508       1.03         38        640: 100% ━━━━━━━━━━━━ 18/18 3.4it/s 5.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.776      0.833      0.844      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      3.14G      1.161     0.6546      1.026         40        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.819      0.803      0.832      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      3.16G      1.142     0.6482      1.013         43        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.832      0.806       0.84      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      3.17G      1.114     0.6226      1.009         36        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        186      0.836      0.812      0.844      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      3.19G       1.12     0.6349      1.004         38        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.843      0.806      0.845      0.357
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 30, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 60 epochs completed in 0.102 hours.
# Optimizer stripped from /kaggle/working/runs/detect/exp_a3_rgbd_seed42/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/exp_a3_rgbd_seed42/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/exp_a3_rgbd_seed42/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.3it/s 0.9s
#                    all         80        186      0.851      0.769       0.87      0.416
# Speed: 0.2ms preprocess, 2.1ms inference, 0.0ms loss, 3.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/exp_a3_rgbd_seed42
#
# ✅ Seed 42 completed!
#
# ============================================================
# TRAINING - Seed 123 (2/5)
# ============================================================
#
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/ffb_localization_rgbd/dataset_rgbd.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.0, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_a3_rgbd_seed123, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/exp_a3_rgbd_seed123, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=123, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       608  ultralytics.nn.modules.conv.Conv             [4, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,179 parameters, 2,590,163 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# [Trainer] Model sudah 4-channel
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5135.0±1058.7 MB/s, size: 2177.4 KB)
# train: Scanning /kaggle/working/ffb_localization_rgbd/labels/train.cache... 280 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 280/280 106.8Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2482.5±2144.4 MB/s, size: 2331.5 KB)
# val: Scanning /kaggle/working/ffb_localization_rgbd/labels/val.cache... 80 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 3.9Mit/s 0.0s
# Plotting labels to /kaggle/working/runs/detect/exp_a3_rgbd_seed123/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/exp_a3_rgbd_seed123
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.61G      2.794      4.206       2.35         19        640: 100% ━━━━━━━━━━━━ 18/18 2.2it/s 8.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186     0.0025      0.323    0.00238   0.000792
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.61G       2.43      3.852      1.999         44        640: 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        186    0.00517      0.667    0.00893    0.00304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.61G      2.172      3.302      1.736         41        640: 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0
640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.796       0.82      0.848      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.47G      1.265     0.7488      1.068         57        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        186      0.806      0.828       0.85      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.47G      1.259      0.722      1.062         43        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.834      0.839      0.853      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      2.48G      1.243     0.7296       1.05         49        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.834      0.828      0.852      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      2.48G      1.226      0.724      1.055         39        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.814       0.86      0.861       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      2.48G      1.225     0.6907      1.043         39        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186       0.82      0.855      0.857      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      2.48G      1.203     0.6935       1.04         49        640: 100% ━━━━━━━━━━━━ 18/18 3.4it/s 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.859      0.789      0.852      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      2.48G      1.202     0.6977       1.04         48        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.819      0.801       0.84      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      2.48G      1.171     0.6865      1.021         24        640: 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.817       0.79      0.845       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      2.48G      1.188     0.6697      1.036         33        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        186      0.823      0.822      0.859      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      2.48G      1.169      0.661      1.023         35        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186       0.82      0.782      0.846      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      2.48G      1.147     0.6645      1.018         32        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.826      0.815      0.854      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      2.48G      1.146     0.6557      1.019         38        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.812      0.839      0.861      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      2.48G      1.167     0.6456      1.023         40        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.833      0.817      0.867      0.396
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 27, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 57 epochs completed in 0.092 hours.
# Optimizer stripped from /kaggle/working/runs/detect/exp_a3_rgbd_seed101/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/exp_a3_rgbd_seed101/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/exp_a3_rgbd_seed101/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.1it/s 1.0s
#                    all         80        186       0.87      0.769      0.885      0.409
# Speed: 0.2ms preprocess, 1.6ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/exp_a3_rgbd_seed101
#
# ✅ Seed 101 completed!
#
# ============================================================
# ALL TRAINING COMPLETED!
# ============================================================

# %%
# ============================================================
# CELL 9: Evaluation dengan Custom Validator
# ============================================================
results_dict = {}

print("\n" + "="*60)
print("EVALUATION ON TEST SET")
print("="*60)

for seed in SEEDS:
    model_path = RUNS_PATH / f"{EXP_PREFIX}_seed{seed}" / "weights" / "best.pt"
    
    if not model_path.exists():
        print(f"Model not found: {model_path}")
        continue
    
    print(f"\nSeed {seed}:")
    
    model = YOLO(str(model_path))
    
    # Convert ke 4ch jika perlu
    first_conv = model.model.model[0].conv
    if first_conv.in_channels == 3:
        print("  Converting to 4ch...")
        model.model.model[0].conv = convert_conv_to_4ch(first_conv)
    
    metrics = model.val(
        data=str(config_path),
        split="test",
        device=DEVICE,
        name=f"test_{EXP_PREFIX}_seed{seed}",
        exist_ok=True,
    )
    
    results_dict[seed] = {
        'mAP50': metrics.box.map50,
        'mAP50-95': metrics.box.map,
        'Precision': metrics.box.mp,
        'Recall': metrics.box.mr
    }
    
    print(f"  mAP50: {metrics.box.map50:.3f}, mAP50-95: {metrics.box.map:.3f}")
    
    del model
    torch.cuda.empty_cache()
# Out:
# ============================================================
# EVALUATION ON TEST SET
# ============================================================
#
# Seed 42:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4143.3±782.1 MB/s, size: 2217.6 KB)
# val: Scanning /kaggle/working/ffb_localization_rgbd/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 84.2it/s 0.5s
# val: New cache created: /kaggle/working/ffb_localization_rgbd/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         40        105      0.842      0.762      0.858      0.377
# Speed: 3.9ms preprocess, 9.0ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/test_exp_a3_rgbd_seed42
#   mAP50: 0.858, mAP50-95: 0.377
#
# Seed 123:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4371.1±1835.9 MB/s, size: 2250.6 KB)
# val: Scanning /kaggle/working/ffb_localization_rgbd/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 16.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         40        105      0.755       0.79      0.825      0.359
# Speed: 4.0ms preprocess, 3.6ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to /kaggle/working/runs/detect/test_exp_a3_rgbd_seed123
#   mAP50: 0.825, mAP50-95: 0.359
#
# Seed 456:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5201.7±1769.1 MB/s, size: 2183.9 KB)
# val: Scanning /kaggle/working/ffb_localization_rgbd/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 18.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         40        105      0.742      0.781      0.838      0.353
# Speed: 3.9ms preprocess, 3.2ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/test_exp_a3_rgbd_seed456
#   mAP50: 0.838, mAP50-95: 0.353
#
# Seed 789:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5123.5±1229.8 MB/s, size: 2297.8 KB)
# val: Scanning /kaggle/working/ffb_localization_rgbd/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 10.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         40        105      0.802      0.733      0.842       0.37
# Speed: 4.2ms preprocess, 3.7ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/test_exp_a3_rgbd_seed789
#   mAP50: 0.842, mAP50-95: 0.370
#
# Seed 101:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5157.3±1138.0 MB/s, size: 2288.2 KB)
# val: Scanning /kaggle/working/ffb_localization_rgbd/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 11.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.4s
#                    all         40        105      0.759      0.829      0.849      0.359
# Speed: 3.9ms preprocess, 4.2ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/test_exp_a3_rgbd_seed101
#   mAP50: 0.849, mAP50-95: 0.359

# %%
# ============================================================
# CELL 10: Summary & Save
# ============================================================
if results_dict:
    df = pd.DataFrame(results_dict).T
    df.index.name = 'Seed'
    avg = df.mean()
    std = df.std()

    print("\n" + "="*60)
    print("A.3 RGB+DEPTH - FINAL RESULTS")
    print("="*60 + "\n")
    print(df.to_string(float_format=lambda x: f"{x:.3f}"))

    print("\n" + "-"*60)
    print("SUMMARY (Mean ± Std)")
    print("-"*60)
    for col in df.columns:
        print(f"  {col}: {avg[col]:.3f} ± {std[col]:.3f}")

    output_file = KAGGLE_OUTPUT / 'a3_rgbd_results.txt'
    with open(output_file, 'w') as f:
        f.write("A.3 RGB+Depth Results\n")
        f.write(f"Generated: {datetime.now()}\n\n")
        f.write(df.to_string(float_format=lambda x: f"{x:.3f}"))
        f.write("\n\nSummary:\n")
        for col in df.columns:
            f.write(f"  {col}: {avg[col]:.3f} ± {std[col]:.3f}\n")
    print(f"\n✅ Saved: {output_file}")

if RUNS_PATH.exists():
    shutil.make_archive(str(BASE_PATH / 'a3_runs'), 'zip', RUNS_PATH)
    print("✅ a3_runs.zip created")
# Out:
# ============================================================
# A.3 RGB+DEPTH - FINAL RESULTS
# ============================================================
#
#       mAP50  mAP50-95  Precision  Recall
# Seed
# 42    0.858     0.377      0.842   0.762
# 123   0.825     0.359      0.755   0.790
# 456   0.838     0.353      0.742   0.781
# 789   0.842     0.370      0.802   0.733
# 101   0.849     0.359      0.759   0.829
#
# ------------------------------------------------------------
# SUMMARY (Mean ± Std)
# ------------------------------------------------------------
#   mAP50: 0.842 ± 0.013
#   mAP50-95: 0.363 ± 0.010
#   Precision: 0.780 ± 0.041
#   Recall: 0.779 ± 0.035
#
# ✅ Saved: /kaggle/working/kaggleoutput/a3_rgbd_results.txt
# ✅ a3_runs.zip created
