# %% [markdown]
# # A.4a - Synthetic Depth Only Training
#
# **Experiment:** A.4a
# **Input:** Synthetic depth maps (3-channel, generated by Depth-Anything-V2)
# **Objective:** Test if synthetic depth can replace real depth sensor
# **Classes:** 1 (fresh_fruit_bunch)
#
# ## Prerequisites
# 1. Run `generate_synthetic_depth.ipynb` first
# 2. Upload output as Kaggle dataset: `ffb-synthetic-depth`
#
# ## Workflow
# 1. Load synthetic depth dataset (already YOLO-ready)
# 2. Train YOLOv11n with 5 seeds (42, 123, 456, 789, 101)
# 3. Evaluate on test set
# 4. Calculate mean ± std deviation
#
# ## Training Config
# - Model: YOLOv11n
# - Epochs: 100
# - Patience: 30
# - Other parameters: default

# %%
# =============================================================================
# Cell 1: Setup
# =============================================================================
import os
import torch
import numpy as np
import shutil
from pathlib import Path
from datetime import datetime

IS_KAGGLE = os.path.exists('/kaggle/input')
print(f"Running on: {'Kaggle' if IS_KAGGLE else 'Local'}")

# Paths
DATASET_PATH = Path('/kaggle/input/ffb-synthetic-depth')
BASE_PATH = Path('/kaggle/working')
RUNS_PATH = BASE_PATH / 'runs' / 'detect'
KAGGLE_OUTPUT = BASE_PATH / 'kaggleoutput'
KAGGLE_OUTPUT.mkdir(parents=True, exist_ok=True)

print(f"Dataset: {DATASET_PATH} (exists: {DATASET_PATH.exists()})")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# Verify dataset
for split in ['train', 'val', 'test']:
    imgs = len(list((DATASET_PATH / 'images' / split).glob('*.png')))
    lbls = len(list((DATASET_PATH / 'labels' / split).glob('*.txt')))
    print(f"  {split}: {imgs} images, {lbls} labels")
# Out:
# Running on: Kaggle
# Dataset: /kaggle/input/ffb-synthetic-depth (exists: True)
# CUDA: True
# GPU: Tesla T4
#   train: 280 images, 280 labels
#   val: 80 images, 80 labels
#   test: 40 images, 40 labels

# %%
# %%writefile /kaggle/working/dataset_synthetic.yaml
# # A.4a Synthetic Depth Dataset
# path: /kaggle/input/ffb-synthetic-depth
# train: images/train
# val: images/val
# test: images/test
#
# nc: 1
# names: ['fresh_fruit_bunch']
# Out:
# Writing /kaggle/working/dataset_synthetic.yaml

# %%
# =============================================================================
# Cell 3: Verify YAML
# =============================================================================
config_path = Path('/kaggle/working/dataset_synthetic.yaml')
print(f"✅ YAML: {config_path}")
print(config_path.read_text())
# Out:
# ✅ YAML: /kaggle/working/dataset_synthetic.yaml
# # A.4a Synthetic Depth Dataset
# path: /kaggle/input/ffb-synthetic-depth
# train: images/train
# val: images/val
# test: images/test
#
# nc: 1
# names: ['fresh_fruit_bunch']

# %%
# =============================================================================
# Cell 4: Install Ultralytics
# =============================================================================
# !pip install -q ultralytics

from ultralytics import YOLO
import pandas as pd
print("✅ Ultralytics ready")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.5 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ Ultralytics ready

# %%
# =============================================================================
# Cell 5: Training Config
# =============================================================================
SEEDS = [42, 123, 456, 789, 101]
EXP_PREFIX = 'exp_a4a_synthetic'

print(f"Seeds: {SEEDS} ({len(SEEDS)} runs)")
print("Metrics: mean ± std deviation")
# Out:
# Seeds: [42, 123, 456, 789, 101] (5 runs)
# Metrics: mean ± std deviation

# %%
# =============================================================================
# Cell 6: Training Loop
# =============================================================================
for seed in SEEDS:
    print(f"\n{'='*60}")
    print(f"TRAINING A.4a SYNTHETIC DEPTH - Seed {seed} ({SEEDS.index(seed)+1}/{len(SEEDS)})")
    print(f"{'='*60}\n")
    
    torch.manual_seed(seed)
    np.random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
    
    model = YOLO('yolo11n.pt')
    
    results = model.train(
        data=str(config_path),
        epochs=100,
        patience=30,
        seed=seed,
        name=f"{EXP_PREFIX}_seed{seed}",
        exist_ok=True,
    )
    
    print(f"\n✅ Seed {seed} complete!")
    print(f"mAP50: {results.results_dict.get('metrics/mAP50(B)', 0):.3f}")
# Out:
# ...
# TRAINING A.4a SYNTHETIC DEPTH - Seed 42 (1/5)
# ...
#
# ...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# =============================================================================
# Cell 7: Evaluation on Test Set
# =============================================================================
results_dict = {}

print("="*60)
print("EVALUATION ON TEST SET")
print("="*60)

for seed in SEEDS:
    model_path = RUNS_PATH / f"{EXP_PREFIX}_seed{seed}" / 'weights' / 'best.pt'
    
    if not model_path.exists():
        print(f"⚠️ Not found: {model_path}")
        continue
    
    print(f"\nSeed {seed}:")
    model = YOLO(str(model_path))
    metrics = model.val(data=str(config_path), split='test')
    
    results_dict[seed] = {
        'mAP50': metrics.box.map50,
        'mAP50-95': metrics.box.map,
        'Precision': metrics.box.mp,
        'Recall': metrics.box.mr
    }
    
    print(f"  mAP50: {metrics.box.map50:.3f}")
    print(f"  mAP50-95: {metrics.box.map:.3f}")
    print(f"  Precision: {metrics.box.mp:.3f}")
    print(f"  Recall: {metrics.box.mr:.3f}")
# Out:
# ...
# EVALUATION ON TEST SET
# ...
#
# Seed 42:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.7 ms, read: 126.7±18.3 MB/s, size: 1175.0 KB)
# val: Scanning /kaggle/input/ffb-synthetic-depth/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 150.6it/s 0.3s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-synthetic-depth/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.4s
#                    all         40        105      0.652      0.625      0.673      0.271
# Speed: 2.9ms preprocess, 10.7ms inference, 0.0ms loss, 6.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
#   mAP50: 0.673
#   mAP50-95: 0.271
#   Precision: 0.652
#   Recall: 0.625
#
# Seed 123:
# ...

# %%
# =============================================================================
# Cell 8: Results Summary
# =============================================================================
df = pd.DataFrame(results_dict).T
df.index.name = 'Seed'

# Calculate mean and std
avg = df.mean()
std = df.std()

print("\n" + "="*60)
print("A.4a SYNTHETIC DEPTH - FINAL RESULTS")
print("="*60 + "\n")
print(df.to_string(float_format=lambda x: f"{x:.3f}"))

print("\n" + "-"*60)
print("SUMMARY (Mean ± Std)")
print("-"*60)
for col in df.columns:
    print(f"  {col}: {avg[col]:.3f} ± {std[col]:.3f}")
# Out:
# ...
# A.4a SYNTHETIC DEPTH - FINAL RESULTS
# ...
#
#       mAP50  mAP50-95  Precision  Recall
# Seed
# 42    0.673     0.271      0.652   0.625
# 123   0.699     0.263      0.701   0.647
# 456   0.705     0.265      0.805   0.629
# 789   0.753     0.285      0.680   0.748
# 101   0.710     0.278      0.741   0.657
#
# ------------------------------------------------------------
# SUMMARY (Mean ± Std)
# ------------------------------------------------------------
#   mAP50: 0.708 ± 0.029
#   mAP50-95: 0.273 ± 0.009
#   Precision: 0.716 ± 0.060
#   Recall: 0.661 ± 0.050

# %%
# =============================================================================
# Cell 9: Save Results
# =============================================================================
output_file = KAGGLE_OUTPUT / 'a4a_synthetic_depth_results.txt'

with open(output_file, 'w') as f:
    f.write("="*60 + "\n")
    f.write("A.4a Synthetic Depth Only Results\n")
    f.write(f"Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write("Training: epochs=100, patience=30, other=default\n")
    f.write(f"Seeds: {SEEDS}\n")
    f.write("="*60 + "\n\n")
    f.write("Per-Seed Results:\n")
    f.write(df.to_string(float_format=lambda x: f"{x:.3f}"))
    f.write("\n\n" + "-"*60 + "\n")
    f.write("Summary (Mean ± Std):\n")
    for col in df.columns:
        f.write(f"  {col}: {avg[col]:.3f} ± {std[col]:.3f}\n")

print(f"Results saved: {output_file}")
# Out:
# Results saved: /kaggle/working/kaggleoutput/a4a_synthetic_depth_results.txt

# %%
# =============================================================================
# Cell 10: Create Archives
# =============================================================================
if RUNS_PATH.exists():
    shutil.make_archive('/kaggle/working/a4a_runs', 'zip', RUNS_PATH)
    print(f"✅ a4a_runs.zip: {os.path.getsize('/kaggle/working/a4a_runs.zip')/1024/1024:.1f} MB")

shutil.make_archive('/kaggle/working/a4a_output', 'zip', KAGGLE_OUTPUT)
print("✅ a4a_output.zip created")

print("\n📥 Download from Output tab")
# Out:
# ✅ a4a_runs.zip: 80.5 MB
# ✅ a4a_output.zip created
#
# 📥 Download from Output tab
