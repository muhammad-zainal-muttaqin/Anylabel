# %% [markdown]
# # A.4b - RGB + Synthetic Depth (4-Channel) Training - FIXED
#
# **Experiment:** A.4b
# **Input:** RGB + Synthetic Depth (4-channel RGBD)
# **Objective:** Test fusion of RGB with synthetic depth (Depth-Anything-V2)
# **Classes:** 1 (fresh_fruit_bunch)
#
# ## FIX Applied
# This version includes proper 4-channel support:
# 1. Monkey-patch `imread` to read 4 channels
# 2. Custom `RGBD4ChTrainer` and `RGBD4ChValidator`
# 3. `channels: 4` in YAML config
#
# ## Prerequisites
# 1. Upload RGB dataset as: `ffb-localization-dataset`
# 2. Upload Synthetic Depth dataset as: `ffb-synthetic-depth`
#
# ## Training Config
# - Model: YOLOv11n
# - Epochs: 100
# - Patience: 30
# - Seeds: 42, 123, 456, 789, 101

# %%
# =============================================================================
# Cell 1: Setup & Install
# =============================================================================
# !pip install -q ultralytics

import os
import torch
import torch.nn as nn
import numpy as np
import cv2
import shutil
import pandas as pd
from pathlib import Path
from datetime import datetime
from tqdm.auto import tqdm

os.environ["WANDB_DISABLED"] = "true"

IS_KAGGLE = os.path.exists('/kaggle/input')
print(f"Running on: {'Kaggle' if IS_KAGGLE else 'Local'}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.4 MB/s eta 0:00:00
# Running on: Kaggle
# PyTorch: 2.8.0+cu126
# CUDA: True
# GPU: Tesla T4

# %%
# =============================================================================
# Cell 2: Path Setup
# =============================================================================
RGB_DATASET = Path('/kaggle/input/ffb-localization-dataset/ffb_localization')
DEPTH_DATASET = Path('/kaggle/input/ffb-synthetic-depth')
BASE_PATH = Path('/kaggle/working')
RUNS_PATH = BASE_PATH / 'runs' / 'detect'
RGBD_DATASET = BASE_PATH / 'rgbd_4ch'
KAGGLE_OUTPUT = BASE_PATH / 'kaggleoutput'
KAGGLE_OUTPUT.mkdir(parents=True, exist_ok=True)

print(f"RGB Dataset: {RGB_DATASET} (exists: {RGB_DATASET.exists()})")
print(f"Depth Dataset: {DEPTH_DATASET} (exists: {DEPTH_DATASET.exists()})")
print(f"Output RGBD: {RGBD_DATASET}")

# Verify datasets
for split in ['train', 'val', 'test']:
    rgb_imgs = len(list((RGB_DATASET / 'images' / split).glob('*.png')))
    depth_imgs = len(list((DEPTH_DATASET / 'images' / split).glob('*.png')))
    rgb_lbls = len(list((RGB_DATASET / 'labels' / split).glob('*.txt')))
    print(f"  {split}: RGB={rgb_imgs}, Depth={depth_imgs}, Labels={rgb_lbls}")
# Out:
# RGB Dataset: /kaggle/input/ffb-localization-dataset/ffb_localization (exists: True)
# Depth Dataset: /kaggle/input/ffb-synthetic-depth (exists: True)
# Output RGBD: /kaggle/working/rgbd_4ch
#   train: RGB=280, Depth=280, Labels=280
#   val: RGB=80, Depth=80, Labels=80
#   test: RGB=40, Depth=40, Labels=40

# %%
# =============================================================================
# Cell 3: Create 4-Channel RGBD Dataset
# =============================================================================
print("="*60)
print("CREATING 4-CHANNEL RGBD DATASET")
print("="*60)

for split in ['train', 'val', 'test']:
    print(f"\nProcessing {split.upper()}...")
    
    rgb_img_dir = RGB_DATASET / 'images' / split
    depth_img_dir = DEPTH_DATASET / 'images' / split
    rgb_lbl_dir = RGB_DATASET / 'labels' / split
    
    # Create output directories
    rgbd_img_dir = RGBD_DATASET / 'images' / split
    rgbd_lbl_dir = RGBD_DATASET / 'labels' / split
    rgbd_img_dir.mkdir(parents=True, exist_ok=True)
    rgbd_lbl_dir.mkdir(parents=True, exist_ok=True)
    
    # Get RGB files
    rgb_files = sorted(list(rgb_img_dir.glob('*.png')))
    
    for rgb_path in tqdm(rgb_files, desc=f"Creating 4-ch images ({split})"):
        # Load RGB (3 channels)
        rgb = cv2.imread(str(rgb_path))
        if rgb is None:
            print(f"  Warning: Could not read {rgb_path}")
            continue
        
        # Load synthetic depth (1 channel)
        depth_path = depth_img_dir / rgb_path.name
        depth = cv2.imread(str(depth_path), cv2.IMREAD_GRAYSCALE)
        if depth is None:
            print(f"  Warning: Could not read {depth_path}")
            continue
        
        # Resize depth if needed
        if depth.shape[:2] != rgb.shape[:2]:
            depth = cv2.resize(depth, (rgb.shape[1], rgb.shape[0]))
        
        # Combine RGB (3) + Depth (1) = 4 channels
        depth_expanded = depth[:, :, np.newaxis]
        rgbd_4ch = np.concatenate([rgb, depth_expanded], axis=2)
        
        # Save 4-channel image
        output_img_path = rgbd_img_dir / rgb_path.name
        cv2.imwrite(str(output_img_path), rgbd_4ch)
    
    # Copy labels
    label_files = list(rgb_lbl_dir.glob('*.txt'))
    for lbl_path in label_files:
        shutil.copy(str(lbl_path), str(rgbd_lbl_dir / lbl_path.name))
    
    img_count = len(list(rgbd_img_dir.glob('*.png')))
    lbl_count = len(list(rgbd_lbl_dir.glob('*.txt')))
    print(f"  Done: {img_count} images, {lbl_count} labels")

# Verify sample
sample_img = list((RGBD_DATASET / 'images' / 'train').glob('*.png'))[0]
img = cv2.imread(str(sample_img), cv2.IMREAD_UNCHANGED)
print(f"\nSample image shape: {img.shape} (should be H x W x 4)")
# Out:
# ============================================================
# CREATING 4-CHANNEL RGBD DATASET
# ============================================================
#
# Processing TRAIN...
# Creating 4-ch images (train):   0%|          | 0/280 [00:00<?, ?it/s]
#   Done: 280 images, 280 labels
#
# Processing VAL...
# Creating 4-ch images (val):   0%|          | 0/80 [00:00<?, ?it/s]
#   Done: 80 images, 80 labels
#
# Processing TEST...
# Creating 4-ch images (test):   0%|          | 0/40 [00:00<?, ?it/s]
#   Done: 40 images, 40 labels
#
# Sample image shape: (720, 1280, 4) (should be H x W x 4)

# %%
# =============================================================================
# Cell 4: Write YAML Config with channels: 4
# =============================================================================
config_content = f"""# A.4b RGB+Synthetic Depth 4-Channel Dataset
path: {RGBD_DATASET}
train: images/train
val: images/val
test: images/test

nc: 1
channels: 4

names:
  0: fresh_fruit_bunch
"""

config_path = RGBD_DATASET / 'dataset_rgbd_synthetic.yaml'
with open(config_path, 'w') as f:
    f.write(config_content)

print(f"YAML saved: {config_path}")
print("(includes channels: 4)")
print(config_content)
# Out:
# YAML saved: /kaggle/working/rgbd_4ch/dataset_rgbd_synthetic.yaml
# (includes channels: 4)
# # A.4b RGB+Synthetic Depth 4-Channel Dataset
# path: /kaggle/working/rgbd_4ch
# train: images/train
# val: images/val
# test: images/test
#
# nc: 1
# channels: 4
#
# names:
#   0: fresh_fruit_bunch

# %%
# =============================================================================
# Cell 5: Monkey-Patch Ultralytics imread for 4-Channel Support
# =============================================================================
import ultralytics.utils.patches as patches

_original_imread = patches.imread

def imread_4ch(filename, flags=cv2.IMREAD_UNCHANGED):
    """Always read with IMREAD_UNCHANGED to preserve 4 channels"""
    return _original_imread(filename, cv2.IMREAD_UNCHANGED)

patches.imread = imread_4ch
print("Patched imread for 4-channel support")

from ultralytics import YOLO
print("YOLO imported")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Patched imread for 4-channel support
# YOLO imported

# %%
# =============================================================================
# Cell 6: Custom Trainer & Validator with 4-Channel Support
# =============================================================================
from ultralytics.models.yolo.detect import DetectionTrainer, DetectionValidator

def convert_conv_to_4ch(conv_layer):
    """Convert a conv layer from 3ch to 4ch input"""
    if conv_layer.in_channels == 4:
        return conv_layer
    
    new_conv = nn.Conv2d(
        in_channels=4,
        out_channels=conv_layer.out_channels,
        kernel_size=conv_layer.kernel_size,
        stride=conv_layer.stride,
        padding=conv_layer.padding,
        bias=conv_layer.bias is not None
    )
    
    with torch.no_grad():
        # Copy RGB weights
        new_conv.weight[:, :3, :, :] = conv_layer.weight.clone()
        # Initialize depth channel as mean of RGB
        new_conv.weight[:, 3:4, :, :] = conv_layer.weight.mean(dim=1, keepdim=True)
        if conv_layer.bias is not None:
            new_conv.bias = nn.Parameter(conv_layer.bias.clone())
    
    return new_conv


def ensure_model_4ch(model):
    """Ensure model has 4-channel input"""
    try:
        # For AutoBackend wrapped models
        if hasattr(model, 'model') and hasattr(model.model, 'model'):
            first_conv = model.model.model[0].conv
            if first_conv.in_channels == 3:
                print("[4ch] Converting AutoBackend model...")
                model.model.model[0].conv = convert_conv_to_4ch(first_conv)
                return True
        # For direct DetectionModel
        elif hasattr(model, 'model') and hasattr(model.model[0], 'conv'):
            first_conv = model.model[0].conv
            if first_conv.in_channels == 3:
                print("[4ch] Converting DetectionModel...")
                model.model[0].conv = convert_conv_to_4ch(first_conv)
                return True
    except Exception as e:
        print(f"[4ch] Warning: {e}")
    return False


class RGBD4ChValidator(DetectionValidator):
    """Validator that converts model to 4ch before validation"""
    
    def setup_model(self):
        """Override: after model is loaded, convert to 4ch"""
        super().setup_model()
        if self.model is not None:
            ensure_model_4ch(self.model)
            print(f"[Validator] Model 4ch ready")


class RGBD4ChTrainer(DetectionTrainer):
    """Trainer that converts model to 4-channel"""
    
    def setup_model(self):
        """Setup model then convert to 4-channel"""
        super().setup_model()
        
        first_conv = self.model.model[0].conv
        
        if first_conv.in_channels == 4:
            print("[Trainer] Model already 4-channel")
            return
        
        print(f"[Trainer] Converting to 4-channel...")
        self.model.model[0].conv = convert_conv_to_4ch(first_conv)
        print(f"[Trainer] Converted! Shape: {self.model.model[0].conv.weight.shape}")
    
    def get_validator(self):
        """Return custom validator"""
        self.loss_names = "box_loss", "cls_loss", "dfl_loss"
        return RGBD4ChValidator(
            self.test_loader, 
            save_dir=self.save_dir, 
            args=self.args,
            _callbacks=self.callbacks
        )

print("Custom Trainer & Validator defined")
# Out:
# Custom Trainer & Validator defined

# %%
# =============================================================================
# Cell 7: Training Configuration
# =============================================================================
EXP_PREFIX = "exp_a4b_rgbd_synth"
SEEDS = [42, 123, 456, 789, 101]
EPOCHS = 100
IMGSZ = 640
BATCH_SIZE = 16
DEVICE = 0 if torch.cuda.is_available() else 'cpu'

print(f"Experiment: A.4b RGB+Synthetic Depth (4-Channel) - FIXED")
print(f"Seeds: {SEEDS}")
print(f"Epochs: {EPOCHS}")
print(f"Batch: {BATCH_SIZE}")
print(f"Device: {DEVICE}")
# Out:
# Experiment: A.4b RGB+Synthetic Depth (4-Channel) - FIXED
# Seeds: [42, 123, 456, 789, 101]
# Epochs: 100
# Batch: 16
# Device: 0

# %%
# =============================================================================
# Cell 8: Training Loop with Custom Trainer
# =============================================================================
results_all = {}

for seed in SEEDS:
    print(f"\n{'='*60}")
    print(f"TRAINING A.4b RGBD SYNTHETIC - Seed {seed} ({SEEDS.index(seed)+1}/{len(SEEDS)})")
    print(f"{'='*60}\n")
    
    # Use custom trainer for 4-channel support
    trainer = RGBD4ChTrainer(overrides={
        'model': 'yolo11n.pt',
        'data': str(config_path),
        'imgsz': IMGSZ,
        'epochs': EPOCHS,
        'batch': BATCH_SIZE,
        'device': DEVICE,
        'seed': seed,
        'name': f"{EXP_PREFIX}_seed{seed}",
        'project': str(RUNS_PATH),
        'exist_ok': True,
        'pretrained': True,
        'patience': 30,
        'val': True,
        # Disable HSV augmentation (not applicable for depth)
        'hsv_h': 0.0,
        'hsv_s': 0.0,
        'hsv_v': 0.0,
        'degrees': 0.0,
        'translate': 0.1,
        'scale': 0.5,
        'fliplr': 0.5,
        'mosaic': 1.0,
        'mixup': 0.0,
        'copy_paste': 0.0,
        'erasing': 0.0,
    })
    
    trainer.train()
    
    results_all[seed] = {
        'model_path': str(RUNS_PATH / f"{EXP_PREFIX}_seed{seed}" / "weights" / "best.pt"),
    }
    
    print(f"\nSeed {seed} completed!")
    
    del trainer
    torch.cuda.empty_cache()

print("\n" + "="*60)
print("ALL TRAINING COMPLETED!")
print("="*60)
# Out:
# ============================================================
# TRAINING A.4b RGBD SYNTHETIC - Seed 42 (1/5)
# ============================================================
#
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/rgbd_4ch/dataset_rgbd_synthetic.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.0, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_a4b_rgbd_synth_seed42, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/exp_a4b_rgbd_synth_seed42, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.1MB/s 0.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 57.8MB/s 0.1s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       608  ultralytics.nn.modules.conv.Conv             [4, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,179 parameters, 2,590,163 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# [Trainer] Model already 4-channel
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 70.4MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4078.8±836.2 MB/s, size: 2174.1 KB)
# train: Scanning /kaggle/working/rgbd_4ch/labels/train... 280 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 280/280 76.6it/s 3.7s
# train: New cache created: /kaggle/working/rgbd_4ch/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2935.2±1954.9 MB/s, size: 2411.0 KB)
# val: Scanning /kaggle/working/rgbd_4ch/labels/val... 80 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 86.8it/s 0.9s
# val: New cache created: /kaggle/working/rgbd_4ch/labels/val.cache
# Plotting labels to /kaggle/working/runs/detect/exp_a4b_rgbd_synth_seed42/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/exp_a4b_rgbd_synth_seed42
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.31G      2.485      3.787      1.998         19        640: 100% ━━━━━━━━━━━━ 18/18 1.2s/it 22.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.7s
#                    all         80        186    0.00646      0.833     0.0275    0.00661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.33G      2.031      2.357      1.561         44        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186    0.00758      0.978      0.202     0.0505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.35G      1.925      2.033       1.52         41        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        186    0.00762      0.984     0.0502     0.0178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.37G      1.939      1.936      1.528         34        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.216       0.26      0.179     0.0572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.38G      1.812      1.774      1.481         44        640: 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        186      0.561      0.426      0.473      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.39G      1.888      1.683      1.502         35        640: 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        186      0.291      0.151     0.0962     0.0215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.41G      1.844      1.603      1.461         43        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        186      0.646      0.634      0.666      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.42G      1.792       1.54      1.474         28        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.793      0.694      0.765       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.44G      1.841        1.5      1.488         41        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        186      0.694      0.602      0.667      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.45G      1.852      1.425      1.477         39        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        186      0.709      0.613      0.682      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.47G      1.743      1.333      1.427         43        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.785      0.707      0.778      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.48G      1.768      1.303      1.419         47        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186       0.73      0.726      0.787      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100       2.5G      1.752      1.288      1.447         25        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        186      0.843      0.694      0.805      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.51G      1.816      1.284      1.465         47        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.792      0.715      0.826      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.53G      1.747      1.269      1.421         36        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.757      0.812      0.851      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.54G      1.654      1.198      1.366         29        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        186      0.791      0.796      0.862      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.56G      1.707      1.136      1.388         46        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.745      0.667      0.731      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.57G      1.757      1.184       1.45         30        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        186      0.804      0.704      0.782      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.59G      1.701      1.168      1.389         30        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.801      0.713      0.833      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100       2.6G      1.634      1.081      1.376         36        640: 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.828      0.778      0.862      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.62G      1.647      1.072      1.375         45        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.787      0.812      0.858      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.63G      1.663      1.125      1.405         27        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.808      0.726      0.818      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.65G      1.669      1.063      1.374         49        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.792      0.756      0.836      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.66G      1.623      1.037       1.36         32        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        186       0.75      0.791      0.851      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.68G      1.612     0.9904      1.337         51        640: 100% ━━━━━━━━━━━━ 18/18 4.3it/s 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         80        186      0.761      0.787      0.834      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.69G      1.661      1.025      1.351         48        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.816      0.726      0.824      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.71G      1.583     0.9766      1.344         30        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.851      0.738      0.852       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.72G      1.612     0.9577      1.349         44        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.802      0.784      0.832      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.73G      1.569     0.9236      1.333         39        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        186      0.804      0.785      0.834      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.75G      1.588     0.9371      1.327         39        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.843      0.742      0.852      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.76G      1.555       0.92      1.317         41        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.804      0.769      0.873      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.78G      1.576     0.9118      1.324         32        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.833       0.78      0.859      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.79G      1.519      0.881      1.296         37        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.801      0.736      0.831      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.81G      1.514     0.8706      1.296         38        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186       0.78      0.774      0.811      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.82G      1.495     0.8555       1.26         44        640: 100% ━━━━━━━━━━━━ 18/18 4.4it/s 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        186       0.81      0.747      0.838      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.84G        1.5     0.8557      1.271         34        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        186        0.8      0.774      0.839       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.85G      1.468     0.8512       1.28         40        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        186      0.817      0.774      0.841      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.87G      1.497     0.8356      1.266         55        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.761      0.828      0.859      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.88G      1.539     0.8608      1.296         27        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.841      0.774      0.857       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100       2.9G      1.466     0.8465      1.267         44        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.838      0.777      0.871      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      2.91G      1.495     0.8205      1.276         37        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        186       0.83      0.787      0.844      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.93G      1.505     0.8265      1.307         30        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.845      0.828      0.879      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.94G      1.476     0.8098      1.271         26        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.796      0.837      0.858      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      2.96G      1.447     0.7927      1.247         41        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        186       0.84      0.844      0.877      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.97G      1.433     0.7886      1.243         57        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        186      0.857      0.839      0.867      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.99G       1.42     0.7803       1.23         43        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        186      0.846      0.774      0.861      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100         3G      1.419     0.7701      1.224         49        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.843      0.801      0.867      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      3.02G      1.416     0.7826      1.237         39        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.835       0.78      0.858      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      3.03G       1.39     0.7383      1.215         39        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186       0.79       0.79      0.803      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      3.04G      1.416     0.7644      1.234         49        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.837      0.758      0.837      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      3.06G       1.38     0.7283      1.207         48        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.807      0.785      0.812      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.08G      1.388     0.7433      1.197         24        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186       0.82      0.796      0.856       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      3.09G      1.374     0.7143      1.207         33        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.855       0.78      0.878      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      3.11G      1.375     0.7206      1.197         35        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.825      0.784      0.862      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      3.12G      1.338     0.7265      1.179         32        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        186      0.822      0.769      0.838      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      3.13G      1.341     0.7046      1.184         38        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.825      0.806      0.857      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      3.15G      1.338     0.7098      1.187         40        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        186      0.861      0.796      0.863      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      3.16G      1.306     0.7065       1.17         43        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        186       0.81      0.824      0.873      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      3.18G        1.3     0.6758      1.176         36        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.869      0.758      0.882      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      3.19G      1.316     0.6975      1.171         38        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.817      0.842      0.899      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      3.21G      1.286     0.6843      1.179         35        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.814      0.774      0.834      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      3.22G      1.254     0.6621      1.154         41        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.843       0.78      0.838      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      3.24G      1.329     0.6843      1.177         46        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.816      0.812      0.863      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      3.25G      1.261     0.6587      1.135         43        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186      0.863      0.817      0.872      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      3.27G      1.247      0.656      1.129         32        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.813      0.828      0.872      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      3.28G      1.247     0.6657      1.134         46        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.853      0.844      0.892      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100       3.3G      1.263     0.6548      1.128         40        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        186      0.837      0.803      0.854       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      3.31G      1.224     0.6513      1.122         37        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        186      0.858      0.782      0.871      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      3.33G       1.22     0.6403       1.14         38        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.866      0.766      0.859      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      3.34G      1.217     0.6298      1.125         34        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.851      0.785      0.856      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      3.36G      1.203     0.6292      1.124         33        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.838      0.836      0.872      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      3.37G      1.144     0.6048      1.082         41        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.817       0.79      0.873      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      3.39G      1.212     0.6206       1.14         28        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.897      0.749      0.879      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100       3.4G        1.2     0.6149      1.113         44        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.914      0.763       0.89      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      3.42G      1.194     0.6143      1.111         25        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.878      0.763      0.859      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      3.43G      1.153     0.6056      1.096         34        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        186      0.859      0.758      0.856      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      3.45G      1.142      0.595      1.084         36        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.851      0.753      0.824      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      3.46G      1.162     0.6034      1.084         34        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.863      0.747      0.824       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      3.47G      1.147     0.5923       1.09         39        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.823      0.822      0.853      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      3.49G      1.146     0.5915      1.101         36        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.846      0.747       0.82      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100       3.5G      1.115     0.5729      1.074         31        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.885      0.742      0.842      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      3.52G      1.112     0.5758      1.063         45        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.895      0.785      0.864      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      3.53G      1.108     0.5732      1.065         20        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        186      0.848      0.823       0.87      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      3.55G      1.092     0.5815      1.066         35        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.876      0.797      0.891      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      3.56G        1.1     0.5668      1.067         48        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        186      0.851        0.8      0.867       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      3.58G      1.115     0.5659      1.076         38        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.844      0.816       0.87      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      3.59G      1.081      0.552       1.06         34        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186       0.91      0.757      0.866      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      3.61G      1.091     0.5665       1.06         28        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        186      0.913      0.789      0.888      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      3.62G      1.066      0.552      1.045         25        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.865       0.83      0.891      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      3.64G      1.086     0.5645      1.052         34        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.871      0.801      0.889      0.405
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      3.65G      1.142      0.576       1.09         20        640: 100% ━━━━━━━━━━━━ 18/18 2.8it/s 6.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        186      0.898       0.78      0.884       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      3.67G      1.072     0.5318      1.068         17        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.871      0.774       0.85      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      3.68G      1.067     0.5247      1.053         17        640: 100% ━━━━━━━━━━━━ 18/18 4.3it/s 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.852      0.776      0.841      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100       3.7G      1.023       0.52      1.027         19        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.826      0.817      0.842       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      3.71G      1.012     0.4991       1.03         20        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.835      0.828      0.874      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      3.73G      1.002     0.5073       1.02         23        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.861      0.812      0.872      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      3.74G      0.998     0.4902      1.021         18        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        186      0.879       0.79      0.866      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      3.76G     0.9892     0.4809      1.026         23        640: 100% ━━━━━━━━━━━━ 18/18 4.4it/s 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.868      0.774      0.865       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      3.77G     0.9753     0.4755       1.01         17        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.832      0.801      0.854      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      3.79G     0.9581     0.4765      1.007         20        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.863      0.774      0.868      0.392
#
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      2.49G      1.258     0.6443      1.102         32        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.769      0.833      0.854      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      2.49G      1.242     0.6591      1.105         46        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.877      0.727      0.831      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      2.49G      1.228     0.6425      1.087         40        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186       0.77      0.828      0.856      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      2.49G      1.213     0.6417      1.082         37        640: 100% ━━━━━━━━━━━━ 18/18 4.4it/s 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186       0.87      0.755      0.863      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      2.49G      1.227      0.648      1.101         38        640: 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        186      0.806      0.781      0.845      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      2.49G      1.225     0.6348      1.089         34        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.765      0.828      0.838      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.49G      1.176     0.6338      1.074         33        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.834      0.785      0.847      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      2.49G      1.145     0.6076      1.052         41        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.814      0.839      0.872      0.411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      2.49G      1.194     0.6214      1.095         28        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186       0.83      0.833      0.879      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      2.49G      1.218     0.6316      1.093         44        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.791      0.812      0.864      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      2.49G      1.184     0.6208      1.076         25        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.828      0.833      0.886        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      2.49G      1.146     0.5924      1.062         34        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.847      0.776      0.882      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      2.49G      1.146       0.59      1.055         36        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.885      0.741      0.873      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.49G      1.177     0.5966      1.059         34        640: 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        186      0.842      0.753      0.856      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.49G      1.116     0.5859      1.049         39        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.869       0.72      0.839      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      2.49G      1.133     0.5891      1.057         36        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.834      0.763      0.846      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      2.49G      1.114     0.5709      1.042         31        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        186      0.791       0.78      0.831      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      2.49G      1.132      0.583      1.041         45        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.774      0.806      0.848      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      2.49G      1.102     0.5728      1.025         20        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.824      0.807      0.873      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.49G      1.104      0.578      1.035         35        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        186      0.787      0.817      0.863      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      2.49G      1.108     0.5809      1.038         48        640: 100% ━━━━━━━━━━━━ 18/18 4.4it/s 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.791      0.806      0.857      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.49G      1.117     0.5777      1.051         38        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.812      0.789      0.857      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      2.49G      1.081     0.5566      1.029         34        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.745      0.802       0.86      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      2.49G      1.078       0.56      1.025         28        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.766      0.845      0.874      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      2.49G      1.053     0.5361      1.014         25        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        186      0.851      0.767      0.871      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.49G      1.075     0.5511      1.021         34        640: 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.774       0.86      0.886      0.414
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.49G      1.132     0.5872      1.038         20        640: 100% ━━━━━━━━━━━━ 18/18 2.7it/s 6.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186       0.78      0.812       0.87      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.49G      1.046      0.514      1.016         17        640: 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.873      0.742      0.846      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.49G       1.02     0.4923      1.002         17        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.819      0.781      0.863      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.49G     0.9972     0.4854     0.9904         19        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         80        186      0.854      0.769      0.872      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.49G     0.9746     0.4806     0.9847         20        640: 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.794      0.828      0.866      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.49G     0.9943     0.4881     0.9859         23        640: 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.824      0.778      0.863      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.49G     0.9356     0.4655     0.9688         18        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         80        186      0.834      0.774      0.863      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.49G     0.9607     0.4727     0.9813         23        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        186      0.836      0.768      0.858      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.49G     0.9648     0.4611     0.9767         17        640: 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.837      0.763      0.864      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.49G     0.9366     0.4568     0.9757         20        640: 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        186      0.774       0.83      0.864      0.394
#
# 100 epochs completed in 0.165 hours.
# Optimizer stripped from /kaggle/working/runs/detect/exp_a4b_rgbd_synth_seed101/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/exp_a4b_rgbd_synth_seed101/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/exp_a4b_rgbd_synth_seed101/weights/best.pt...
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.7it/s 1.1s
#                    all         80        186      0.886      0.742      0.873      0.419
# Speed: 0.2ms preprocess, 1.9ms inference, 0.0ms loss, 3.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/exp_a4b_rgbd_synth_seed101
#
# Seed 101 completed!
#
# ============================================================
# ALL TRAINING COMPLETED!
# ============================================================

# %%
# =============================================================================
# Cell 9: Evaluation on Test Set
# =============================================================================
results_dict = {}

print("\n" + "="*60)
print("EVALUATION ON TEST SET")
print("="*60)

for seed in SEEDS:
    model_path = RUNS_PATH / f"{EXP_PREFIX}_seed{seed}" / "weights" / "best.pt"
    
    if not model_path.exists():
        print(f"Model not found: {model_path}")
        continue
    
    print(f"\nSeed {seed}:")
    
    model = YOLO(str(model_path))
    
    # Convert to 4ch if needed
    first_conv = model.model.model[0].conv
    if first_conv.in_channels == 3:
        print("  Converting to 4ch...")
        model.model.model[0].conv = convert_conv_to_4ch(first_conv)
    
    # Verify 4-channel
    print(f"  Model input channels: {model.model.model[0].conv.in_channels}")
    
    metrics = model.val(
        data=str(config_path),
        split="test",
        device=DEVICE,
        name=f"test_{EXP_PREFIX}_seed{seed}",
        exist_ok=True,
    )
    
    results_dict[seed] = {
        'mAP50': metrics.box.map50,
        'mAP50-95': metrics.box.map,
        'Precision': metrics.box.mp,
        'Recall': metrics.box.mr
    }
    
    print(f"  mAP50: {metrics.box.map50:.3f}, mAP50-95: {metrics.box.map:.3f}")
    
    del model
    torch.cuda.empty_cache()
# Out:
# ============================================================
# EVALUATION ON TEST SET
# ============================================================
#
# Seed 42:
#   Model input channels: 4
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4620.9±1142.0 MB/s, size: 2286.6 KB)
# val: Scanning /kaggle/working/rgbd_4ch/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 76.0it/s 0.5s
# val: New cache created: /kaggle/working/rgbd_4ch/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.6it/s 1.8s
#                    all         40        105      0.826      0.768       0.83      0.359
# Speed: 4.4ms preprocess, 12.1ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to /kaggle/working/runs/detect/test_exp_a4b_rgbd_synth_seed42
#   mAP50: 0.830, mAP50-95: 0.359
#
# Seed 123:
#   Model input channels: 4
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4485.8±791.7 MB/s, size: 2318.6 KB)
# val: Scanning /kaggle/working/rgbd_4ch/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 14.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.8s
#                    all         40        105      0.777      0.762      0.836      0.375
# Speed: 4.1ms preprocess, 8.8ms inference, 0.0ms loss, 5.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/test_exp_a4b_rgbd_synth_seed123
#   mAP50: 0.836, mAP50-95: 0.375
#
# Seed 456:
#   Model input channels: 4
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4151.2±1275.3 MB/s, size: 2257.4 KB)
# val: Scanning /kaggle/working/rgbd_4ch/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 12.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.6it/s 1.8s
#                    all         40        105      0.806      0.714      0.801      0.371
# Speed: 4.5ms preprocess, 5.5ms inference, 0.0ms loss, 3.6ms postprocess per image
# Results saved to /kaggle/working/runs/detect/test_exp_a4b_rgbd_synth_seed456
#   mAP50: 0.801, mAP50-95: 0.371
#
# Seed 789:
#   Model input channels: 4
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4779.0±978.9 MB/s, size: 2379.1 KB)
# val: Scanning /kaggle/working/rgbd_4ch/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 16.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.6it/s 1.8s
#                    all         40        105      0.758      0.686      0.779      0.337
# Speed: 4.5ms preprocess, 7.7ms inference, 0.0ms loss, 5.4ms postprocess per image
# Results saved to /kaggle/working/runs/detect/test_exp_a4b_rgbd_synth_seed789
#   mAP50: 0.779, mAP50-95: 0.337
#
# Seed 101:
#   Model input channels: 4
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4625.0±1051.5 MB/s, size: 2375.8 KB)
# val: Scanning /kaggle/working/rgbd_4ch/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 10.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.6it/s 1.8s
#                    all         40        105      0.758      0.714       0.82      0.362
# Speed: 4.6ms preprocess, 6.2ms inference, 0.0ms loss, 4.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/test_exp_a4b_rgbd_synth_seed101
#   mAP50: 0.820, mAP50-95: 0.362

# %%
# =============================================================================
# Cell 10: Results Summary
# =============================================================================
if results_dict:
    df = pd.DataFrame(results_dict).T
    df.index.name = 'Seed'
    avg = df.mean()
    std = df.std()

    print("\n" + "="*60)
    print("A.4b RGB+SYNTHETIC DEPTH (4-CH) - FINAL RESULTS")
    print("="*60 + "\n")
    print(df.to_string(float_format=lambda x: f"{x:.3f}"))

    print("\n" + "-"*60)
    print("SUMMARY (Mean +/- Std)")
    print("-"*60)
    for col in df.columns:
        print(f"  {col}: {avg[col]:.3f} +/- {std[col]:.3f}")
# Out:
# ============================================================
# A.4b RGB+SYNTHETIC DEPTH (4-CH) - FINAL RESULTS
# ============================================================
#
#       mAP50  mAP50-95  Precision  Recall
# Seed
# 42    0.830     0.359      0.826   0.768
# 123   0.836     0.375      0.777   0.762
# 456   0.801     0.371      0.806   0.714
# 789   0.779     0.337      0.758   0.686
# 101   0.820     0.362      0.758   0.714
#
# ------------------------------------------------------------
# SUMMARY (Mean +/- Std)
# ------------------------------------------------------------
#   mAP50: 0.813 +/- 0.023
#   mAP50-95: 0.361 +/- 0.015
#   Precision: 0.785 +/- 0.030
#   Recall: 0.729 +/- 0.035

# %%
# =============================================================================
# Cell 11: Save Results
# =============================================================================
output_file = KAGGLE_OUTPUT / 'a4b_rgbd_synthetic_results.txt'

with open(output_file, 'w') as f:
    f.write("="*60 + "\n")
    f.write("A.4b RGB+Synthetic Depth (4-Channel) Results - FIXED\n")
    f.write(f"Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write("Training: epochs=100, patience=30, other=default\n")
    f.write(f"Seeds: {SEEDS}\n")
    f.write("4-Channel Support: YES (Custom Trainer)\n")
    f.write("="*60 + "\n\n")
    f.write("Per-Seed Results:\n")
    f.write(df.to_string(float_format=lambda x: f"{x:.3f}"))
    f.write("\n\n" + "-"*60 + "\n")
    f.write("Summary (Mean +/- Std):\n")
    for col in df.columns:
        f.write(f"  {col}: {avg[col]:.3f} +/- {std[col]:.3f}\n")

print(f"Results saved: {output_file}")
# Out:
# Results saved: /kaggle/working/kaggleoutput/a4b_rgbd_synthetic_results.txt

# %%
# =============================================================================
# Cell 12: Create Archives
# =============================================================================
if RUNS_PATH.exists():
    shutil.make_archive(str(BASE_PATH / 'a4b_runs'), 'zip', RUNS_PATH)
    print(f"a4b_runs.zip: {os.path.getsize(str(BASE_PATH / 'a4b_runs.zip'))/1024/1024:.1f} MB")

shutil.make_archive(str(BASE_PATH / 'a4b_output'), 'zip', KAGGLE_OUTPUT)
print("a4b_output.zip created")

print("\nDownload from Output tab:")
print("  - a4b_runs.zip (training runs)")
print("  - a4b_output.zip (results)")
# Out:
# a4b_runs.zip: 105.9 MB
# a4b_output.zip created
#
# Download from Output tab:
#   - a4b_runs.zip (training runs)
#   - a4b_output.zip (results)
