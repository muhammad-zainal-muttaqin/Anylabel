# %% [markdown]
# # B.1 - Ripeness Detection (2 Classes)
#
# **Experiment:** B.1
# **Input:** RGB images (3-channel)
# **Objective:** End-to-end detection with ripeness classification
# **Classes:** 2 (ripe, unripe)
#
# ## Workflow
# 1. Load ripeness dataset (2-class YOLO format)
# 2. Train YOLOv11n with 5 seeds (42, 123, 456, 789, 101)
# 3. Evaluate on test set
# 4. Calculate mean ± std deviation
#
# ## Training Config
# - Model: YOLOv11n
# - Epochs: 100
# - Patience: 30
# - Other parameters: default

# %%
# =============================================================================
# Cell 1: Setup
# =============================================================================
import os
import torch
import numpy as np
import shutil
from pathlib import Path
from datetime import datetime

IS_KAGGLE = os.path.exists('/kaggle/input')
print(f"Running on: {'Kaggle' if IS_KAGGLE else 'Local'}")

# Paths
DATASET_PATH = Path('/kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect')
BASE_PATH = Path('/kaggle/working')
RUNS_PATH = BASE_PATH / 'runs' / 'detect'
KAGGLE_OUTPUT = BASE_PATH / 'kaggleoutput'
KAGGLE_OUTPUT.mkdir(parents=True, exist_ok=True)

print(f"Dataset: {DATASET_PATH} (exists: {DATASET_PATH.exists()})")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# Verify dataset
for split in ['train', 'val', 'test']:
    imgs = len(list((DATASET_PATH / 'images' / split).glob('*.png')))
    lbls = len(list((DATASET_PATH / 'labels' / split).glob('*.txt')))
    print(f"  {split}: {imgs} images, {lbls} labels")
# Out:
# Running on: Kaggle
# Dataset: /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect (exists: True)
# CUDA: True
# GPU: Tesla T4
#   train: 0 images, 280 labels
#   val: 0 images, 80 labels
#   test: 0 images, 40 labels

# %%
# %%writefile /kaggle/working/dataset_ripeness.yaml
# # B.1 Ripeness Detection Dataset (2 Classes)
# path: /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect
# train: images/train
# val: images/val
# test: images/test
#
# nc: 2
# names: ['ripe', 'unripe']
# Out:
# Writing /kaggle/working/dataset_ripeness.yaml

# %%
# =============================================================================
# Cell 3: Verify YAML
# =============================================================================
config_path = Path('/kaggle/working/dataset_ripeness.yaml')
print(f"YAML: {config_path}")
print(config_path.read_text())
# Out:
# YAML: /kaggle/working/dataset_ripeness.yaml
# # B.1 Ripeness Detection Dataset (2 Classes)
# path: /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect
# train: images/train
# val: images/val
# test: images/test
#
# nc: 2
# names: ['ripe', 'unripe']

# %%
# =============================================================================
# Cell 4: Install Ultralytics
# =============================================================================
# !pip install -q ultralytics

from ultralytics import YOLO
import pandas as pd
print("Ultralytics ready")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.8 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics ready

# %%
# =============================================================================
# Cell 5: Training Config
# =============================================================================
SEEDS = [42, 123, 456, 789, 101]
EXP_PREFIX = 'exp_b1_ripeness'

print(f"Seeds: {SEEDS} ({len(SEEDS)} runs)")
print("Metrics: mean ± std deviation")
print("Note: 2-class detection (ripe/unripe)")
# Out:
# Seeds: [42, 123, 456, 789, 101] (5 runs)
# Metrics: mean ± std deviation
# Note: 2-class detection (ripe/unripe)

# %%
# =============================================================================
# Cell 6: Training Loop
# =============================================================================
for seed in SEEDS:
    print(f"\n{'='*60}")
    print(f"TRAINING B.1 RIPENESS DETECTION - Seed {seed} ({SEEDS.index(seed)+1}/{len(SEEDS)})")
    print(f"{'='*60}\n")
    
    torch.manual_seed(seed)
    np.random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
    
    model = YOLO('yolo11n.pt')
    
    results = model.train(
        data=str(config_path),
        epochs=100,
        patience=30,
        seed=seed,
        name=f"{EXP_PREFIX}_seed{seed}",
        exist_ok=True,
    )
    
    print(f"\nSeed {seed} complete!")
    print(f"mAP50: {results.results_dict.get('metrics/mAP50(B)', 0):.3f}")
# Out:
# ============================================================
# TRAINING B.1 RIPENESS DETECTION - Seed 42 (1/5)
# ============================================================
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 68.6MB/s 0.1s
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/dataset_ripeness.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_b1_ripeness_seed42, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/exp_b1_ripeness_seed42, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 69.6MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 2.1±3.2 ms, read: 49.5±28.2 MB/s, size: 3171.9 KB)
# train: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/train... 280 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 280/280 134.4it/s 2.1s
# WARNING ⚠️ train: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 1.2±1.4 ms, read: 100.0±57.6 MB/s, size: 3146.0 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/val... 80 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 175.3it/s 0.5s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
# Plotting labels to /kaggle/working/runs/detect/exp_b1_ripeness_seed42/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/exp_b1_ripeness_seed42
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.23G      1.882       4.05       1.67         29        640: 100% ━━━━━━━━━━━━ 18/18 2.0s/it 36.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.3s
#                    all         80        299    0.00205       0.14    0.00253   0.000774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.38G       1.51      3.667      1.393         53        640: 100% ━━━━━━━━━━━━ 18/18 2.0it/s 8.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.6it/s 0.7s
#                    all         80        299     0.0049      0.333    0.00458    0.00244
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100       2.4G      1.465      2.803      1.374         62        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         80        299    0.00778      0.602     0.0198    0.00824
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.41G      1.396      2.095      1.354         54        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.7it/s 0.6s
#                    all         80        299     0.0096      0.808      0.134     0.0609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.43G        1.3      1.831       1.29         41        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.318      0.078      0.302      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.44G      1.259       1.73       1.21         47        640: 100% ━━━━━━━━━━━━ 18/18 1.1it/s 16.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        299      0.395      0.476      0.345      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.46G      1.221      1.602      1.176         60        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        299      0.393       0.61      0.415      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.47G      1.179      1.535       1.16         30        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.437       0.59      0.489      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.49G      1.163      1.428       1.13         58        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        299      0.643      0.651      0.686      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100       2.5G      1.126      1.357      1.116         35        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        299      0.686      0.671      0.741      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.52G      1.164      1.332      1.134         42        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.8it/s 0.6s
#                    all         80        299      0.763      0.634      0.748      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.53G      1.136      1.269      1.117         52        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.798      0.692       0.78       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.54G      1.116      1.228      1.106         48        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        299      0.804      0.703      0.797      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.56G      1.086      1.181       1.09         50        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        299      0.824      0.766      0.815      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.57G      1.043      1.152       1.07         57        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        299      0.817      0.745      0.814      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.59G      1.085      1.129      1.075         34        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        299      0.712      0.771      0.812      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100       2.6G      1.059      1.079      1.043         56        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9it/s 0.6s
#                    all         80        299      0.732      0.757      0.803      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.62G      1.042      1.072      1.057         43        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.767      0.733      0.822      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.63G       1.02      1.026      1.028         34        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.723      0.763      0.821       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.65G       1.03      1.015      1.037         37        640: 100% ━━━━━━━━━━━━ 18/18 1.1it/s 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        299      0.751      0.803      0.841      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.66G      1.009     0.9854      1.024         42        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        299      0.785       0.76      0.829      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.68G      1.017       1.02      1.028         33        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        299      0.824      0.768      0.837      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.69G     0.9967     0.9292       1.02         57        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 13.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        299      0.823      0.771      0.837      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.71G     0.9912     0.9665       1.02         34        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        299      0.817      0.764       0.81      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.72G     0.9933     0.9142      1.021         54        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        299      0.804      0.749      0.826      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.73G     0.9913     0.9059      1.008         79        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        299      0.826      0.719      0.821      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.75G     0.9597     0.8857      1.018         32        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299       0.76      0.793      0.817      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.77G     0.9944     0.8779      1.029         62        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        299      0.872      0.705      0.837      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.78G      0.925     0.8343     0.9959         46        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        299      0.783      0.781      0.824      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.79G     0.9704       0.87     0.9978         41        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.807      0.751      0.835      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.81G     0.9537     0.8394     0.9925         35        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.8it/s 0.6s
#                    all         80        299      0.778      0.801       0.84       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.82G     0.9339     0.8002     0.9974         42        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.783      0.752      0.802      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2
0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      3.04G     0.8492     0.7004     0.9448         85        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        299      0.805      0.773      0.847      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      3.05G     0.8868     0.7129     0.9447         58        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9it/s 0.6s
#                    all         80        299      0.824      0.784      0.853      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      3.07G      0.858     0.6808     0.9381         62        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         80        299      0.807      0.788      0.853       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      3.08G      0.859     0.6859     0.9502         58        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.6s
#                    all         80        299      0.798      0.798      0.857      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100       3.1G     0.8561     0.6935     0.9462         63        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        299      0.806      0.765      0.847      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      3.11G     0.8569     0.6698     0.9401         60        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        299      0.775      0.786      0.843      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      3.12G     0.8612     0.6709     0.9337         58        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        299      0.805      0.762      0.841      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.14G     0.8652     0.6572     0.9346         36        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.7it/s 0.6s
#                    all         80        299       0.74      0.784      0.818      0.569
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 22, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 52 epochs completed in 0.183 hours.
# Optimizer stripped from /kaggle/working/runs/detect/exp_b1_ripeness_seed101/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/exp_b1_ripeness_seed101/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/exp_b1_ripeness_seed101/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.8it/s 1.1s
#                    all         80        299      0.833      0.751      0.849      0.599
#                   ripe         48         64      0.805      0.766      0.851      0.621
#                 unripe         75        235      0.861      0.736      0.847      0.577
# Speed: 0.2ms preprocess, 2.4ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/exp_b1_ripeness_seed101
#
# Seed 101 complete!
# mAP50: 0.849

# %%
# =============================================================================
# Cell 7: Evaluation on Test Set
# =============================================================================
results_dict = {}

print("="*60)
print("EVALUATION ON TEST SET")
print("="*60)

for seed in SEEDS:
    model_path = RUNS_PATH / f"{EXP_PREFIX}_seed{seed}" / 'weights' / 'best.pt'
    
    if not model_path.exists():
        print(f"Not found: {model_path}")
        continue
    
    print(f"\nSeed {seed}:")
    model = YOLO(str(model_path))
    metrics = model.val(data=str(config_path), split='test')
    
    results_dict[seed] = {
        'mAP50': metrics.box.map50,
        'mAP50-95': metrics.box.map,
        'Precision': metrics.box.mp,
        'Recall': metrics.box.mr
    }
    
    print(f"  mAP50: {metrics.box.map50:.3f}")
    print(f"  mAP50-95: {metrics.box.map:.3f}")
    print(f"  Precision: {metrics.box.mp:.3f}")
    print(f"  Recall: {metrics.box.mr:.3f}")
# Out:
# ============================================================
# EVALUATION ON TEST SET
# ============================================================
#
# Seed 42:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 1.9±0.4 ms, read: 116.0±48.1 MB/s, size: 3110.6 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 177.0it/s 0.2s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.4s
#                    all         40        140      0.861       0.78      0.846      0.554
#                   ripe         17         22      0.809      0.773      0.787      0.496
#                 unripe         38        118      0.913      0.788      0.904      0.612
# Speed: 2.8ms preprocess, 5.3ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
#   mAP50: 0.846
#   mAP50-95: 0.554
#   Precision: 0.861
#   Recall: 0.780
#
# Seed 123:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1893.5±491.4 MB/s, size: 3169.3 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 864.4it/s 0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.3s
#                    all         40        140      0.718      0.806      0.805      0.538
#                   ripe         17         22      0.584      0.765      0.686      0.455
#                 unripe         38        118      0.853      0.847      0.924      0.622
# Speed: 2.7ms preprocess, 6.8ms inference, 0.0ms loss, 5.9ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val2
#   mAP50: 0.805
#   mAP50-95: 0.538
#   Precision: 0.718
#   Recall: 0.806
#
# Seed 456:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1879.0±600.9 MB/s, size: 3064.8 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 1.1Kit/s 0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.2s
#                    all         40        140      0.797      0.712      0.807      0.549
#                   ripe         17         22      0.691      0.636      0.718      0.476
#                 unripe         38        118      0.903      0.787      0.896      0.622
# Speed: 3.2ms preprocess, 7.0ms inference, 0.0ms loss, 2.9ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val3
#   mAP50: 0.807
#   mAP50-95: 0.549
#   Precision: 0.797
#   Recall: 0.712
#
# Seed 789:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2105.7±642.3 MB/s, size: 3024.8 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 829.7it/s 0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.2s
#                    all         40        140      0.784      0.734      0.811      0.504
#                   ripe         17         22      0.612      0.727      0.701      0.392
#                 unripe         38        118      0.956      0.741      0.921      0.615
# Speed: 3.1ms preprocess, 6.4ms inference, 0.0ms loss, 7.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val4
#   mAP50: 0.811
#   mAP50-95: 0.504
#   Precision: 0.784
#   Recall: 0.734
#
# Seed 101:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1926.7±785.5 MB/s, size: 3132.3 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 1.0Kit/s 0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.2s
#                    all         40        140      0.732      0.799        0.8      0.518
#                   ripe         17         22      0.674      0.751      0.703      0.425
#                 unripe         38        118       0.79      0.847      0.896      0.611
# Speed: 3.1ms preprocess, 4.7ms inference, 0.0ms loss, 9.4ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val5
#   mAP50: 0.800
#   mAP50-95: 0.518
#   Precision: 0.732
#   Recall: 0.799

# %%
# =============================================================================
# Cell 8: Results Summary
# =============================================================================
df = pd.DataFrame(results_dict).T
df.index.name = 'Seed'

# Calculate mean and std
avg = df.mean()
std = df.std()

print("\n" + "="*60)
print("B.1 RIPENESS DETECTION - FINAL RESULTS")
print("="*60 + "\n")
print(df.to_string(float_format=lambda x: f"{x:.3f}"))

print("\n" + "-"*60)
print("SUMMARY (Mean ± Std)")
print("-"*60)
for col in df.columns:
    print(f"  {col}: {avg[col]:.3f} ± {std[col]:.3f}")
# Out:
# ============================================================
# B.1 RIPENESS DETECTION - FINAL RESULTS
# ============================================================
#
#       mAP50  mAP50-95  Precision  Recall
# Seed
# 42    0.846     0.554      0.861   0.780
# 123   0.805     0.538      0.718   0.806
# 456   0.807     0.549      0.797   0.712
# 789   0.811     0.504      0.784   0.734
# 101   0.800     0.518      0.732   0.799
#
# ------------------------------------------------------------
# SUMMARY (Mean ± Std)
# ------------------------------------------------------------
#   mAP50: 0.814 ± 0.018
#   mAP50-95: 0.532 ± 0.021
#   Precision: 0.779 ± 0.057
#   Recall: 0.766 ± 0.042

# %%
# =============================================================================
# Cell 9: Save Results
# =============================================================================
output_file = KAGGLE_OUTPUT / 'b1_ripeness_results.txt'

with open(output_file, 'w') as f:
    f.write("="*60 + "\n")
    f.write("B.1 Ripeness Detection (2 Classes) Results\n")
    f.write(f"Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write("Training: epochs=100, patience=30, other=default\n")
    f.write(f"Seeds: {SEEDS}\n")
    f.write("="*60 + "\n\n")
    f.write("Per-Seed Results:\n")
    f.write(df.to_string(float_format=lambda x: f"{x:.3f}"))
    f.write("\n\n" + "-"*60 + "\n")
    f.write("Summary (Mean ± Std):\n")
    for col in df.columns:
        f.write(f"  {col}: {avg[col]:.3f} ± {std[col]:.3f}\n")

print(f"Results saved: {output_file}")
# Out:
# Results saved: /kaggle/working/kaggleoutput/b1_ripeness_results.txt

# %%
# =============================================================================
# Cell 10: Create Archives
# =============================================================================
if RUNS_PATH.exists():
    shutil.make_archive('/kaggle/working/b1_runs', 'zip', RUNS_PATH)
    print(f"b1_runs.zip: {os.path.getsize('/kaggle/working/b1_runs.zip')/1024/1024:.1f} MB")

shutil.make_archive('/kaggle/working/b1_output', 'zip', KAGGLE_OUTPUT)
print("b1_output.zip created")

print("\nDownload from Output tab")
# Out:
# b1_runs.zip: 126.9 MB
# b1_output.zip created
#
# Download from Output tab
