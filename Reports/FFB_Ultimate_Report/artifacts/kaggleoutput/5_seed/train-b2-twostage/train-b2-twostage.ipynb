# %% [markdown]
# # B.2 - Two-Stage Ripeness Classification
#
# **Experiment:** B.2
# **Approach:** Detect → Crop → Classify (2 stages)
# **Objective:** Test if separating detection and classification improves accuracy
# **Classes:** 2 (ripe, unripe)
#
# ## Pipeline
# 1. **Stage 1**: Detector - Detect all FFBs (ripe/unripe)
# 2. **Crop**: Extract bounding boxes with 10% margin
# 3. **Stage 2**: Classifier - Classify crops
# 4. **Evaluation**: End-to-end pipeline on test set
#
# ## Training Config
# - Stage 1 (Detection): YOLOv11n, epochs=100, patience=30
# - Stage 2 (Classification): YOLOv11n-cls, epochs=100, patience=30
# - Seeds: 5 (42, 123, 456, 789, 101)
# - Other parameters: default

# %%
# =============================================================================
# Cell 1: Setup
# =============================================================================
import os
import torch
import numpy as np
import cv2
import shutil
from pathlib import Path
from datetime import datetime
from tqdm.auto import tqdm

IS_KAGGLE = os.path.exists('/kaggle/input')
print(f"Running on: {'Kaggle' if IS_KAGGLE else 'Local'}")

# Paths
DATASET_PATH = Path('/kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect')
BASE_PATH = Path('/kaggle/working')
RUNS_PATH = BASE_PATH / 'runs'
CROPS_PATH = BASE_PATH / 'crops'
KAGGLE_OUTPUT = BASE_PATH / 'kaggleoutput'
KAGGLE_OUTPUT.mkdir(parents=True, exist_ok=True)

print(f"Dataset: {DATASET_PATH} (exists: {DATASET_PATH.exists()})")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# Verify dataset
for split in ['train', 'val', 'test']:
    imgs = len(list((DATASET_PATH / 'images' / split).glob('*.jpg')))
    lbls = len(list((DATASET_PATH / 'labels' / split).glob('*.txt')))
    print(f"  {split}: {imgs} images, {lbls} labels")
# Out:
# Running on: Kaggle
# Dataset: /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect (exists: True)
# CUDA: True
# GPU: Tesla T4
#   train: 280 images, 280 labels
#   val: 80 images, 80 labels
#   test: 40 images, 40 labels

# %%
# %%writefile /kaggle/working/dataset_stage1.yaml
# # B.2 Stage 1 - Detection (2 Classes)
# path: /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect
# train: images/train
# val: images/val
# test: images/test
#
# nc: 2
# names: ['ripe', 'unripe']
# Out:
# Writing /kaggle/working/dataset_stage1.yaml

# %%
# =============================================================================
# Cell 3: Install Dependencies
# =============================================================================
# !pip install -q ultralytics

from ultralytics import YOLO
import pandas as pd
print("Ultralytics ready")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.2 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics ready

# %%
# =============================================================================
# Cell 4: Training Config
# =============================================================================
SEEDS = [42, 123, 456, 789, 101]
STAGE1_PREFIX = 'exp_b2_stage1'
STAGE2_PREFIX = 'exp_b2_stage2'

stage1_config_path = Path('/kaggle/working/dataset_stage1.yaml')

print(f"Seeds: {SEEDS} ({len(SEEDS)} runs)")
print("Pipeline: Detect -> Crop -> Classify")
# Out:
# Seeds: [42, 123, 456, 789, 101] (5 runs)
# Pipeline: Detect -> Crop -> Classify

# %%
# =============================================================================
# Cell 5: Stage 1 - Train Detector (5 seeds)
# =============================================================================
stage1_models = {}

for seed in SEEDS:
    print(f"\n{'='*60}")
    print(f"STAGE 1 (DETECTOR) - Seed {seed} ({SEEDS.index(seed)+1}/{len(SEEDS)})")
    print(f"{'='*60}\n")
    
    torch.manual_seed(seed)
    np.random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
    
    model = YOLO('yolo11n.pt')
    
    results = model.train(
        data=str(stage1_config_path),
        epochs=100,
        patience=30,
        seed=seed,
        name=f"{STAGE1_PREFIX}_seed{seed}",
        exist_ok=True,
    )
    
    model_path = RUNS_PATH / 'detect' / f"{STAGE1_PREFIX}_seed{seed}" / 'weights' / 'best.pt'
    stage1_models[seed] = str(model_path)
    
    print(f"\nSeed {seed} complete! Model: {model_path}")
# Out:
# ============================================================
# STAGE 1 (DETECTOR) - Seed 42 (1/5)
# ============================================================
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 65.9MB/s 0.1s
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/dataset_stage1.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_b2_stage1_seed42, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/exp_b2_stage1_seed42, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.7MB/s 0.0s
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 69.2MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.6±0.2 ms, read: 97.1±56.3 MB/s, size: 3171.9 KB)
# train: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/train... 280 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 280/280 182.8it/s 1.5s
# WARNING ⚠️ train: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 126.7±23.5 MB/s, size: 3146.0 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/val... 80 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 178.2it/s 0.4s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
# Plotting labels to /kaggle/working/runs/detect/exp_b2_stage1_seed42/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/exp_b2_stage1_seed42
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.18G      1.882       4.05       1.67         29        640: 100% ━━━━━━━━━━━━ 18/18 2.0s/it 36.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.5s/it 7.5s
#                    all         80        299    0.00205       0.14    0.00253   0.000774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.32G       1.51      3.667      1.393         53        640: 100% ━━━━━━━━━━━━ 18/18 2.0it/s 9.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299     0.0049      0.333    0.00458    0.00244
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.35G      1.465      2.803      1.374         62        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9it/s 0.6s
#                    all         80        299    0.00778      0.602     0.0198    0.00824
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.36G      1.396      2.095      1.354         54        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299     0.0096      0.808      0.134     0.0609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.38G        1.3      1.831       1.29         41        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 15.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        299      0.318      0.078      0.302      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.39G      1.259       1.73       1.21         47        640: 100% ━━━━━━━━━━━━ 18/18 1.1it/s 16.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        299      0.395      0.476      0.345      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100       2.4G      1.221      1.602      1.176         60        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.393       0.61      0.415      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.42G      1.179      1.535       1.16         30        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        299      0.437       0.59      0.489      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.44G      1.163      1.428       1.13         58        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.8it/s 0.6s
#                    all         80        299      0.643      0.651      0.686      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.45G      1.126      1.357      1.116         35        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.686      0.671      0.741      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.46G      1.164      1.332      1.134         42        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        299      0.763      0.634      0.748      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.48G      1.136      1.269      1.117         52        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        299      0.798      0.692       0.78       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.49G      1.116      1.228      1.106         48        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.804      0.703      0.797      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.51G      1.086      1.181       1.09         50        640: 100% ━━━━━━━━━━━━ 18/18 1.1it/s 16.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        299      0.824      0.766      0.815      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.52G      1.043      1.152       1.07         57        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 11.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.817      0.745      0.814      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.54G      1.085      1.129      1.075         34        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.712      0.771      0.812      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.55G      1.059      1.079      1.043         56        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 13.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.732      0.757      0.803      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.57G      1.042      1.072      1.057         43        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        299      0.767      0.733      0.822      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.58G       1.02      1.026      1.028         34        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 13.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.723      0.763      0.821       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100       2.6G       1.03      1.015      1.037         37        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        299      0.751      0.803      0.841      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.61G      1.009     0.9854      1.024         42        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        299      0.785       0.76      0.829      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.62G      1.017       1.02      1.028         33        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        299      0.824      0.768      0.837      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.64G     0.9967     0.9292       1.02         57        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        299      0.823      0.771      0.837      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.66G     0.9912     0.9665       1.02         34        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 15.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.817      0.764       0.81      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.67G     0.9933     0.9142      1.021         54        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 13.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.804      0.749      0.826      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.69G     0.9913     0.9059      1.008         79        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.8it/s 0.6s
#                    all         80        299      0.826      0.719      0.821      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100       2.7G     0.9597     0.8857      1.018         32        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        299       0.76      0.793      0.817      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.71G     0.9944     0.8779      1.029         62        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        299      0.872      0.705      0.837      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.73G      0.925     0.8343     0.9959         46        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        299      0.783      0.781      0.824      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.74G     0.9704       0.87     0.9978         41        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        299      0.807      0.751      0.835      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.76G     0.9537     0.8394     0.9925         35        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        299      0.778      0.801       0.84       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.77G     0.9339     0.8002     0.9974         42        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.783      0.752      0.802      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.79G     0.9341     0.8109     0.9988         51        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        299      0.763      0.742      0.798      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100       2.8G     0.9266     0.8002      0.992         51        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         80        299       0.77      0.778       0.81      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.82G     0.9495     0.7917     0.9828         57        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        299      0.781      0.779      0.831      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.83G     0.8842     0.7581     0.9653         49        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        299      0.775      0.744      0.814      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.85G     0.9015     0.7702     0.9829         65        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.817       0.72      0.819      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.86G     0.9014     0.7443     0.9787         59        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.848      0.713      0.815       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.88G     0.8926     0.7607     0.9731         48        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.799      0.727      0.806      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      2.89G     0.8729      0.726     0.9632         56        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        299      0.839      0.737      0.807      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100       2.9G     0.8793     0.7321     0.9585         44        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        299      0.769      0.796      0.829      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.92G     0.9049     0.7622     0.9778         52        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        299      0.851      0.728      0.834      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.94G     0.8923      0.737     0.9668         31        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        299      0.869      0.703      0.816      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      2.95G     0.8834     0.7328     0.9695         65        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        299      0.822      0.713      0.798      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.96G     0.8624     0.6967      0.964         85        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 13.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299       0.83      0.725      0.807      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.98G     0.8767      0.711     0.9586         58        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        299       0.77      0.757      0.829      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      2.99G     0.8514     0.6892     0.9483         62        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.806      0.722      0.816      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      3.01G     0.8686     0.7013     0.9655         58        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 11.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        299      0.836      0.738      0.826      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      3.02G     0.8655     0.7094     0.9609         63        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        299      0.845      0.701      0.815      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      3.04G     0.8671     0.6855     0.9568         60        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        299      0.774      0.759      0.809       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      3.05G     0.8725     0.6899      0.952         58        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.797       0.73      0.809      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.07G     0.8758     0.6746     0.9539         36        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.782      0.757      0.789      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      3.08G     0.8383     0.6762     0.9518         38        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        299      0.786      0.737      0.791      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100       3.1G      0.833     0.6583     0.9451         47        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 13.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        299      0.804      0.755      0.816      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      3.11G     0.8441     0.6536     0.9634         41        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        299      0.777      0.749      0.803      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      3.13G     0.8489     0.6591     0.9594         36        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.835      0.737      0.804      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      3.14G     0.8144     0.6295     0.9374         58        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.798       0.78      0.816      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      3.16G     0.8284     0.6449     0.9385         56        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.828      0.755      0.812      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      3.17G     0.8536     0.6582     0.9523         49        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.832      0.731       0.81      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      3.19G     0.8248     0.6293     0.9346         41        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        299      0.843      0.765      0.828      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100       3.2G     0.7945     0.6218     0.9344         64        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.832      0.784      0.844      0.576
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 31, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 61 epochs completed in 0.256 hours.
# Optimizer stripped from /kaggle/working/runs/detect/exp_b2_stage1_seed42/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/exp_b2_stage1_seed42/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/exp_b2_stage1_seed42/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.4s
#                    all         80        299      0.777      0.802       0.84      0.578
#                   ripe         48         64      0.755      0.844      0.836      0.599
#                 unripe         75        235      0.799      0.759      0.844      0.557
# Speed: 0.2ms preprocess, 2.1ms inference, 0.0ms loss, 2.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/exp_b2_stage1_seed42
#
# Seed 42 complete! Model: /kaggle/working/runs/detect/exp_b2_stage1_seed42/weights/best.pt
#
# ============================================================
# STAGE 1 (DETECTOR) - Seed 123 (2/5)
# ============================================================
#
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/dataset_stage1.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_b2_stage1_seed123, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/exp_b2_stage1_seed123, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=123, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2823.3±348.0 MB/s, size: 3094.0 KB)
# train: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/train... 280 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 280/280 666.5it/s 0.4s
# WARNING ⚠️ train: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1815.1±1121.8 MB/s, size: 3246.6 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/val... 80 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 463.8it/s 0.2s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
# Plotting labels to /kaggle/working/runs/detect/exp_b2_stage1_seed123/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/exp_b2_stage1_seed123
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       2.5G      1.904      4.174      1.655         29        640: 100% ━━━━━━━━━━━━ 18/18 1.3s/it 23.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        299    0.00447      0.419    0.00389     0.0018
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.62G      1.477      3.806      1.302         53        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.8it/s 0.6s
#                    all         80        299    0.00774      0.671     0.0122    0.00516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.62G      1.366      3.227      1.167         62        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9it/s 0.6s
#                    all         80        299    0.00891      0.751     0.0381     0.0187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.62G      1.392      2.299       1.19         54        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        299      0.413      0.221      0.342      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.62G       1.27      1.814      1.144         41        640: 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        299      0.363      0.506      0.373      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.62G      1.263      1.711      1.072         47        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.382      0.574      0.434      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.62G      1.214      1.602      1.062         60        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 13.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         80        299      0.508      0.608      0.525      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.62G      1.143      1.503      1.065         30        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        299        0.6      0.643      0.623      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.62G      1.145      1.426      1.038         58        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        299      0.637      0.673      0.672      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.62G      1.126      1.354      1.044         35        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        299      0.743      0.698      0.758       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.62G      1.136      1.311      1.052         42        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.739      0.715       0.76      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.62G      1.109      1.236      1.036         52        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9it/s 0.6s
#                    all         80        299      0.742      0.732      0.772      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.62G      1.096      1.194      1.035         48        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.774      0.732      0.798      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.62G      1.076      1.115      1.026         50        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.8it/s 0.6s
#                    all         80        299        0.8      0.698      0.822      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.62G      1.033      1.114      1.015         57        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 13.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         80        299      0.775      0.735      0.815      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.62G      1.066      1.076      1.018         34        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 13.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        299       0.84      0.753      0.842      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.63G      1.046      1.022     0.9926         56        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        299       0.82      0.699        0.8      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.64G      1.014      1.012      1.012         43        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 11.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        299      0.752      0.778      0.823      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.66G      1.007     0.9847     0.9892         34        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         80        299      0.804      0.738      0.829      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.67G      1.016     0.9518      1.001         37        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        299      0.825      0.704      0.824      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.85G          1      1.004      1.008         43        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        299      0.798      0.727      0.815      0.536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.85G      1.007      0.992     0.9892         34        640: 100% ━━━━━━━━━━━━ 18/18 1.8it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        299      0.761      0.764      0.835      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.85G      1.003     0.9633     0.9944         37        640: 100% ━━━━━━━━━━━━ 18/18 1.3it/s 14.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.863      0.739      0.851       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.85G     0.9913     0.9481     0.9887         42        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        299      0.905      0.737      0.842      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.85G      1.006     0.9698     0.9981         33        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.833      0.751      0.849      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.85G     0.9668     0.8851     0.9836         57        640: 100% ━━━━━━━━━━━━ 18/18 1.8it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        299      0.838      0.745      0.848      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.85G     0.9685      0.916     0.9788         34        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 11.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.814      0.754      0.844      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.85G     0.9834     0.8839     0.9902         54        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.807      0.741      0.849      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.85G     0.9733     0.8738     0.9764         79        640: 100% ━━━━━━━━━━━━ 18/18 1.4it/s 12.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         80        299      0.853      0.759      0.855      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.85G      0.936     0.8495     0.9814         32        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        299      0.797      0.769      0.844      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.85G       0.96     0.8545     0.9852         62        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.774      0.766      0.838      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.85G     0.9127     0.8136     0.9692         46        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        299      0.714      0.806      0.835      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.85G     0.9734     0.8522     0.9759         41        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 11.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        299      0.788      0.763      0.839      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.85G      0.947     0.8057     0.9757         35        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.3it/s 0.7s
#                    all         80        299      0.779      0.754       0.84       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.85G     0.9247      0.769     0.9756         42        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 11.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        299      0.853      0.758      0.851      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.86G     0.9212     0.7814      0.969         51        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299       0.84      0.746      0.846      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.87G     0.9131     0.7931     0.9636         51        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        299      0.834      0.737      0.843      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.89G     0.9335     0.7737     0.9647         57        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        299      0.831      0.748      0.846      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100       2.9G     0.8803     0.7567     0.9506         49        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299      0.808      0.775      0.845       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.92G     0.8894     0.7445     0.9596         65        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        299      0.851       0.73      0.838      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.93G      0.905       0.74     0.9665         59        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        299      0.813      0.786      0.857      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.95G     0.8753     0.7399     0.9495         48        640: 100% ━━━━━━━━━━━━ 18/18 1.8it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        299      0.808      0.781      0.856      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      2.96G     0.8636     0.7112     0.9435         56        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        299      0.799      0.762      0.852      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      2.98G     0.8675     0.7228     0.9397         44        640: 100% ━━━━━━━━━━━━ 18/18 1.8it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        299      0.826      0.754      0.851      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.99G     0.8801     0.7364     0.9487         52        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 11.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        299      0.818      0.803      0.854      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      3.01G      0.905     0.7372     0.9573         31        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3it/s 0.6s
#                    all         80        299      0.839      0.766      0.844      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      3.02G     0.8802     0.7176      0.951         65        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        299      0.826      0.763      0.842      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      3.04G     0.8492     0.7004     0.9448         85        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        299      0.805      0.773      0.847      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      3.05G     0.8868     0.7129     0.9447         58        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        299      0.824      0.784      0.853      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      3.07G      0.858     0.6808     0.9381         62        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        299      0.807      0.788      0.853       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      3.08G      0.859     0.6859     0.9502         58        640: 100% ━━━━━━━━━━━━ 18/18 1.6it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        299      0.798      0.798      0.857      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100       3.1G     0.8561     0.6935     0.9462         63        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        299      0.806      0.765      0.847      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      3.11G     0.8569     0.6698     0.9401         60        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 11.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        299      0.775      0.786      0.843      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      3.12G     0.8612     0.6709     0.9337         58        640: 100% ━━━━━━━━━━━━ 18/18 1.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        299      0.805      0.762      0.841      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.14G     0.8652     0.6572     0.9346         36        640: 100% ━━━━━━━━━━━━ 18/18 1.5it/s 11.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        299       0.74      0.784      0.818      0.569
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 22, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 52 epochs completed in 0.182 hours.
# Optimizer stripped from /kaggle/working/runs/detect/exp_b2_stage1_seed101/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/exp_b2_stage1_seed101/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/exp_b2_stage1_seed101/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         80        299      0.833      0.751      0.849      0.599
#                   ripe         48         64      0.805      0.766      0.851      0.621
#                 unripe         75        235      0.861      0.736      0.847      0.577
# Speed: 0.3ms preprocess, 2.3ms inference, 0.0ms loss, 5.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/exp_b2_stage1_seed101
#
# Seed 101 complete! Model: /kaggle/working/runs/detect/exp_b2_stage1_seed101/weights/best.pt

# %%
# =============================================================================
# Cell 6: Crop Extraction Function
# =============================================================================
def extract_crops_with_margin(image_dir, label_dir, output_dir, margin=0.1):
    """Extract crops from ground truth labels with margin."""
    output_dir = Path(output_dir)
    
    # Create output dirs
    for class_name in ['ripe', 'unripe']:
        (output_dir / class_name).mkdir(parents=True, exist_ok=True)
    
    image_files = list(Path(image_dir).glob('*.png')) + list(Path(image_dir).glob('*.jpg'))
    stats = {'ripe': 0, 'unripe': 0}
    
    for img_path in tqdm(image_files, desc="Extracting crops"):
        img = cv2.imread(str(img_path))
        if img is None:
            continue
        h, w = img.shape[:2]
        
        # Get GT labels
        label_path = Path(label_dir) / f"{img_path.stem}.txt"
        if not label_path.exists():
            continue
        
        with open(label_path, 'r') as f:
            lines = f.readlines()
        
        for i, line in enumerate(lines):
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            class_id = int(parts[0])
            x_center, y_center, width, height = map(float, parts[1:5])
            
            # Convert to pixel coords
            x_center *= w
            y_center *= h
            width *= w
            height *= h
            
            # Add margin
            width_margin = width * margin
            height_margin = height * margin
            x1 = int(max(0, x_center - (width + width_margin) / 2))
            y1 = int(max(0, y_center - (height + height_margin) / 2))
            x2 = int(min(w, x_center + (width + width_margin) / 2))
            y2 = int(min(h, y_center + (height + height_margin) / 2))
            
            # Crop
            crop = img[y1:y2, x1:x2]
            if crop.size == 0:
                continue
            
            # Save
            class_name = 'ripe' if class_id == 0 else 'unripe'
            crop_filename = f"{img_path.stem}_crop{i}.png"
            crop_path = output_dir / class_name / crop_filename
            cv2.imwrite(str(crop_path), crop)
            stats[class_name] += 1
    
    return stats

print("Crop extraction function defined")
# Out:
# Crop extraction function defined

# %%
# =============================================================================
# Cell 7: Extract Crops for All Splits
# =============================================================================
print("Extracting crops from ground truth labels...\n")

for split in ['train', 'val', 'test']:
    print(f"{'='*40}")
    print(f"Processing {split.upper()}")
    print(f"{'='*40}")
    
    img_dir = DATASET_PATH / 'images' / split
    label_dir = DATASET_PATH / 'labels' / split
    output_dir = CROPS_PATH / split
    
    stats = extract_crops_with_margin(img_dir, label_dir, output_dir, margin=0.1)
    
    print(f"  Ripe: {stats['ripe']}")
    print(f"  Unripe: {stats['unripe']}")
    print(f"  Total: {sum(stats.values())}\n")

print(f"All crops saved to: {CROPS_PATH}")
# Out:
# Extracting crops from ground truth labels...
#
# ========================================
# Processing TRAIN
# ========================================
# Extracting crops:   0%|          | 0/280 [00:00<?, ?it/s]
#   Ripe: 190
#   Unripe: 787
#   Total: 977
#
# ========================================
# Processing VAL
# ========================================
# Extracting crops:   0%|          | 0/80 [00:00<?, ?it/s]
#   Ripe: 64
#   Unripe: 235
#   Total: 299
#
# ========================================
# Processing TEST
# ========================================
# Extracting crops:   0%|          | 0/40 [00:00<?, ?it/s]
#   Ripe: 22
#   Unripe: 118
#   Total: 140
#
# All crops saved to: /kaggle/working/crops

# %%
# =============================================================================
# Cell 8: Stage 2 - Train Classifier (5 seeds)
# =============================================================================
stage2_models = {}

for seed in SEEDS:
    print(f"\n{'='*60}")
    print(f"STAGE 2 (CLASSIFIER) - Seed {seed} ({SEEDS.index(seed)+1}/{len(SEEDS)})")
    print(f"{'='*60}\n")
    
    torch.manual_seed(seed)
    np.random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
    
    model = YOLO('yolo11n-cls.pt')
    
    results = model.train(
        data=str(CROPS_PATH),
        epochs=100,
        patience=30,
        seed=seed,
        imgsz=224,
        name=f"{STAGE2_PREFIX}_seed{seed}",
        exist_ok=True,
    )
    
    model_path = RUNS_PATH / 'classify' / f"{STAGE2_PREFIX}_seed{seed}" / 'weights' / 'best.pt'
    stage2_models[seed] = str(model_path)
    
    print(f"\nSeed {seed} complete! Model: {model_path}")
# Out:
# ============================================================
# STAGE 2 (CLASSIFIER) - Seed 42 (1/5)
# ============================================================
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n-cls.pt to 'yolo11n-cls.pt': 100% ━━━━━━━━━━━━ 5.5MB 73.1MB/s 0.1s
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/crops, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_b2_stage2_seed42, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/classify/exp_b2_stage2_seed42, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLO11n-cls summary: 86 layers, 1,533,666 parameters, 1,533,666 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2340.0±1181.7 MB/s, size: 675.5 KB)
# train: Scanning /kaggle/working/crops/train... 976 images, 1 corrupt: 100% ━━━━━━━━━━━━ 977/977 420.9it/s 2.3s
# train: /kaggle/working/crops/train/ripe/IMG_20241009_121225_jpg.rf.7d7481d4cfb2a3dc024ce431af3531a0_crop3.png: ignoring corrupt image/label: image size (27, 9) <10 pixels
# train: New cache created: /kaggle/working/crops/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 690.3±319.2 MB/s, size: 1613.0 KB)
# val: Scanning /kaggle/working/crops/val... 299 images, 0 corrupt: 100% ━━━━━━━━━━━━ 299/299 458.7it/s 0.7s
# val: New cache created: /kaggle/working/crops/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001667, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/classify/exp_b2_stage2_seed42
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100     0.797G     0.4597         16        224: 100% ━━━━━━━━━━━━ 61/61 6.4it/s 9.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 8.8it/s 1.1s
#                    all       0.91          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100     0.797G     0.2478         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.4it/s 0.6s
#                    all       0.94          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100     0.797G     0.1641         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.9it/s 0.5s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100     0.797G     0.1476         16        224: 100% ━━━━━━━━━━━━ 61/61 9.2it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 25.9it/s 0.4s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100     0.797G     0.1438         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.3it/s 0.6s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100     0.797G     0.1334         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 14.5it/s 0.7s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100     0.797G     0.1035         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 23.2it/s 0.4s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100     0.797G     0.1134         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 16.8it/s 0.6s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100     0.797G    0.09747         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 15.6it/s 0.6s
#                    all      0.987          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100     0.797G    0.07429         16        224: 100% ━━━━━━━━━━━━ 61/61 10.0it/s 6.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.8it/s 0.6s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100     0.797G    0.08843         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.2it/s 0.5s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100     0.797G    0.06373         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 25.4it/s 0.4s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100     0.797G    0.04779         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.4it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100     0.797G    0.04887         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 21.8it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100     0.797G    0.06378         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.7it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100     0.797G    0.06432         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.1it/s 0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100     0.797G    0.05143         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.3it/s 0.5s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100     0.797G    0.04267         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.0it/s 0.6s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100     0.797G    0.06137         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.8it/s 0.6s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      20/100     0.797G     0.0367         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 21.3it/s 0.5s
#                    all      0.953          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      21/100     0.797G    0.04624         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.2it/s 0.5s
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      22/100     0.797G    0.03677         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 16.6it/s 0.6s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      23/100     0.797G    0.03378         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.9it/s 0.6s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      24/100     0.797G    0.03388         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 25.8it/s 0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      25/100     0.797G     0.0315         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.6it/s 0.6s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      26/100     0.797G    0.03825         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.5it/s 0.5s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      27/100     0.797G     0.0425         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.6it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      28/100     0.797G    0.03538         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.3it/s 0.5s
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      29/100     0.797G    0.02735         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.8it/s 0.6s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      30/100     0.797G    0.01946         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 26.1it/s 0.4s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      31/100     0.797G    0.02662         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.2it/s 0.6s
#                    all      0.983          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      32/100     0.797G    0.02783         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 23.3it/s 0.4s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      33/100     0.797G    0.02153         16        224: 100% ━━━━━━━━━━━━ 61/61 9.4it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.1it/s 0.5s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      34/100     0.797G    0.03674         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.1it/s 0.6s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      35/100     0.797G    0.02761         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 28.1it/s 0.4s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      36/100     0.797G    0.02689         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 22.8it/s 0.4s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      37/100     0.797G    0.04261         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.3it/s 0.6s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      38/100     0.797G    0.01291         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 21.6it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      39/100     0.797G    0.02785         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 22.3it/s 0.4s
#                    all      0.967          1
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 9, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 39 epochs completed in 0.079 hours.
# Optimizer stripped from /kaggle/working/runs/classify/exp_b2_stage2_seed42/weights/last.pt, 3.2MB
# Optimizer stripped from /kaggle/working/runs/classify/exp_b2_stage2_seed42/weights/best.pt, 3.2MB
#
# Validating /kaggle/working/runs/classify/exp_b2_stage2_seed42/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 11.4it/s 0.9s
#                    all      0.987          1
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/runs/classify/exp_b2_stage2_seed42
#
# Seed 42 complete! Model: /kaggle/working/runs/classify/exp_b2_stage2_seed42/weights/best.pt
#
# ============================================================
# STAGE 2 (CLASSIFIER) - Seed 123 (2/5)
# ============================================================
#
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/crops, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_b2_stage2_seed123, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/classify/exp_b2_stage2_seed123, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=123, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLO11n-cls summary: 86 layers, 1,533,666 parameters, 1,533,666 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2547.9±1256.2 MB/s, size: 675.5 KB)
# train: Scanning /kaggle/working/crops/train... 976 images, 1 corrupt: 100% ━━━━━━━━━━━━ 976/976 454.8Mit/s 0.0s
# train: /kaggle/working/crops/train/ripe/IMG_20241009_121225_jpg.rf.7d7481d4cfb2a3dc024ce431af3531a0_crop3.png: ignoring corrupt image/label: image size (27, 9) <10 pixels
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 956.6±397.2 MB/s, size: 1613.0 KB)
# val: Scanning /kaggle/working/crops/val... 299 images, 0 corrupt: 100% ━━━━━━━━━━━━ 299/299 10.1Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001667, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/classify/exp_b2_stage2_seed123
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100     0.604G     0.5843         16        224: 100% ━━━━━━━━━━━━ 61/61 7.1it/s 8.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 26.5it/s 0.4s
#                    all       0.89          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100     0.604G     0.2635         16        224: 100% ━━━━━━━━━━━━ 61/61 9.2it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.3it/s 0.6s
#                    all      0.943          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100     0.604G     0.1649         16        224: 100% ━━━━━━━━━━━━ 61/61 9.4it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 24.9it/s 0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100     0.604G     0.1393         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 24.4it/s 0.4s
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100     0.604G     0.1473         16        224: 100% ━━━━━━━━━━━━ 61/61 9.4it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.5it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100     0.604G     0.1306         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 15.0it/s 0.7s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100     0.604G     0.1062         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.6it/s 0.5s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100     0.604G     0.1097         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.3it/s 0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100     0.604G    0.09321         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 16.8it/s 0.6s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100     0.604G    0.08122         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 21.2it/s 0.5s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100     0.604G     0.0819         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.0it/s 0.6s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100     0.604G    0.07037         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 28.5it/s 0.4s
#                    all      0.983          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100     0.604G    0.04916         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.4it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100     0.604G    0.05074         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.9it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100     0.604G    0.05581         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 14.0it/s 0.7s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100     0.604G    0.05469         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.2it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100     0.604G    0.06207         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 23.3it/s 0.4s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100     0.604G    0.04138         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 22.7it/s 0.4s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100     0.604G    0.05842         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.0it/s 0.6s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      20/100     0.604G    0.03142         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.6it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      21/100     0.604G    0.05576         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.5it/s 0.5s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      22/100     0.604G    0.04516         16        224: 100% ━━━━━━━━━━━━ 61/61 10.1it/s 6.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.3it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      23/100     0.604G    0.03531         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.0it/s 0.5s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      24/100     0.604G       0.03         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.2it/s 0.5s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      25/100     0.604G    0.03521         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 22.1it/s 0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      26/100     0.604G    0.03045         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.6it/s 0.5s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      27/100     0.604G    0.04262         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.7it/s 0.5s
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      28/100     0.604G    0.03917         16        224: 100% ━━━━━━━━━━━━ 61/61 10.2it/s 6.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.8it/s 0.5s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      29/100     0.604G    0.03327         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.5it/s 0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      30/100     0.604G    0.02172         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.6it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      31/100     0.604G    0.02366         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 22.8it/s 0.4s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      32/100     0.604G    0.03886         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 23.6it/s 0.4s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      33/100     0.604G    0.02599         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.6it/s 0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      34/100     0.604G    0.03735         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 16.7it/s 0.6s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      35/100     0.604G    0.02396         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 26.6it/s 0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      36/100     0.604G    0.03532         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 25.7it/s 0.4s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      37/100     0.604G    0.03745         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.1it/s 0.5s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      38/100     0.604G    0.02585         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.4it/s 0.5s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      39/100     0.604G    0.02883         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 16.5it/s 0.6s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      40/100     0.604G    0.02076         16        224: 100% ━━━━━━━━━━━━ 61/61 10.1it/s 6.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.9it/s 0.5s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      41/100     0.604G    0.02259         16        224: 100% ━━━━━━━━━━━━ 61/61 10.0it/s 6.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.2it/s 0.5s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      42/100     0.604G    0.01752         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.3it/s 0.5s
#                    all      0.973          1
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 12, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 42 epochs completed in 0.083 hours.
# Optimizer stripped from /kaggle/working/runs/classify/exp_b2_stage2_seed123/weights/last.pt, 3.2MB
# Optimizer stripped from /kaggle/working/runs/classify/exp_b2_stage2_seed123/weights/best.pt, 3.2MB
#
# Validating /kaggle/working/runs/classify/exp_b2_stage2_seed123/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 9.3it/s 1.1s
#                    all      0.983          1
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/runs/classify/exp_b2_stage2_seed123
#
# Seed 123 complete! Model: /kaggle/working/runs/classify/exp_b2_stage2_seed123/weights/best.pt
#
# ============================================================
# STAGE 2 (CLASSIFIER) - Seed 456 (3/5)
# ============================================================
#
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/crops, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_b2_stage2_seed456, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/classify/exp_b2_stage2_seed456, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=456, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLO11n-cls summary: 86 layers, 1,533,666 parameters, 1,533,666 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2335.0±1268.3 MB/s, size: 675.5 KB)
# train: Scanning /kaggle/working/crops/train... 976 images, 1 corrupt: 100% ━━━━━━━━━━━━ 976/976 372.1Mit/s 0.0s
# train: /kaggle/working/crops/train/ripe/IMG_20241009_121225_jpg.rf.7d7481d4cfb2a3dc024ce431af3531a0_crop3.png: ignoring corrupt image/label: image size (27, 9) <10 pixels
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 602.9±88.1 MB/s, size: 1613.0 KB)
# val: Scanning /kaggle/working/crops/val... 299 images, 0 corrupt: 100% ━━━━━━━━━━━━ 299/299 9.2Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001667, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/classify/exp_b2_stage2_seed456
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100     0.504G     0.5611         16        224: 100% ━━━━━━━━━━━━ 61/61 7.5it/s 8.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 25.4it/s 0.4s
#                    all        0.9          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100     0.504G     0.2535         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.7it/s 0.5s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100     0.504G     0.1579         16        224: 100% ━━━━━━━━━━━━ 61/61 9.4it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.2it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100     0.504G     0.1355         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 24.4it/s 0.4s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100     0.504G      0.153         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.9it/s 0.6s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100     0.504G     0.1259         16        224: 100% ━━━━━━━━━━━━ 61/61 10.1it/s 6.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 16.5it/s 0.6s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100     0.504G    0.09899         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.2it/s 0.5s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100     0.504G     0.0961         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.4it/s 0.6s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100     0.504G    0.08944         16        224: 100% ━━━━━━━━━━━━ 61/61 10.3it/s 5.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 16.1it/s 0.6s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100     0.504G    0.07572         16        224: 100% ━━━━━━━━━━━━ 61/61 10.2it/s 6.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.7it/s 0.6s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100     0.504G    0.07818         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.8it/s 0.6s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100     0.504G    0.05743         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.3it/s 0.6s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100     0.504G    0.05457         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.1it/s 0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100     0.504G    0.04556         16        224: 100% ━━━━━━━━━━━━ 61/61 10.2it/s 6.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.9it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100     0.504G     0.0531         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 23.0it/s 0.4s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100     0.504G     0.0588         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.4it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100     0.504G     0.0534         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.1it/s 0.6s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100     0.504G     0.0509         16        224: 100% ━━━━━━━━━━━━ 61/61 10.1it/s 6.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.5it/s 0.5s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100     0.504G    0.05499         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 28.6it/s 0.3s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      20/100     0.504G    0.03687         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.6it/s 0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      21/100     0.504G    0.03987         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.8it/s 0.5s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      22/100     0.504G     0.0396         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.3it/s 0.5s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      23/100     0.504G    0.03914         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 25.4it/s 0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      24/100     0.504G    0.04076         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 23.5it/s 0.4s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      25/100     0.504G     0.0332         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.8it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      26/100     0.504G    0.03798         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.2it/s 0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      27/100     0.504G    0.04795         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.3it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      28/100     0.504G    0.04805         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 21.5it/s 0.5s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      29/100     0.504G    0.03412         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.5it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      30/100     0.504G    0.02334         16        224: 100% ━━━━━━━━━━━━ 61/61 9.4it/s 6.5s
# ...
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLO11n-cls summary: 86 layers, 1,533,666 parameters, 1,533,666 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2538.1±1362.1 MB/s, size: 675.5 KB)
# train: Scanning /kaggle/working/crops/train... 976 images, 1 corrupt: 100% ━━━━━━━━━━━━ 976/976 409.4Mit/s 0.0s
# train: /kaggle/working/crops/train/ripe/IMG_20241009_121225_jpg.rf.7d7481d4cfb2a3dc024ce431af3531a0_crop3.png: ignoring corrupt image/label: image size (27, 9) <10 pixels
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 622.1±63.6 MB/s, size: 1613.0 KB)
# val: Scanning /kaggle/working/crops/val... 299 images, 0 corrupt: 100% ━━━━━━━━━━━━ 299/299 10.7Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001667, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/classify/exp_b2_stage2_seed101
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100     0.355G     0.5786         16        224: 100% ━━━━━━━━━━━━ 61/61 7.3it/s 8.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 13.6it/s 0.7s
#                    all      0.876          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100     0.355G     0.2759         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 22.5it/s 0.4s
#                    all      0.943          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100     0.355G      0.171         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 23.9it/s 0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100     0.355G     0.1426         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.6it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100     0.355G     0.1452         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.4it/s 0.6s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100     0.355G     0.1314         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 14.8it/s 0.7s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100     0.355G     0.1011         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 21.5it/s 0.5s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100     0.355G     0.1126         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.3it/s 0.6s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100     0.355G    0.09944         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 15.7it/s 0.6s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100     0.355G    0.08804         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.9it/s 0.6s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100     0.355G    0.08615         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.6it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100     0.355G    0.07302         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 24.1it/s 0.4s
#                    all      0.987          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100     0.355G    0.04941         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 23.4it/s 0.4s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100     0.355G    0.05022         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.8it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100     0.355G    0.06292         16        224: 100% ━━━━━━━━━━━━ 61/61 9.2it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.3it/s 0.5s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100     0.355G    0.06744         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.2it/s 0.5s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100     0.355G    0.05783         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.1it/s 0.6s
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100     0.355G    0.05005         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 21.7it/s 0.5s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100     0.355G      0.076         16        224: 100% ━━━━━━━━━━━━ 61/61 9.0it/s 6.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.4it/s 0.5s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      20/100     0.355G    0.03593         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.0it/s 0.6s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      21/100     0.355G    0.04439         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 21.4it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      22/100     0.355G    0.04847         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.8it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      23/100     0.355G    0.04166         16        224: 100% ━━━━━━━━━━━━ 61/61 9.1it/s 6.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.0it/s 0.6s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      24/100     0.355G    0.04337         16        224: 100% ━━━━━━━━━━━━ 61/61 9.6it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.8it/s 0.5s
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      25/100     0.355G    0.04592         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.3it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      26/100     0.355G      0.037         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.3it/s 0.5s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      27/100     0.355G    0.04307         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 21.7it/s 0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      28/100     0.355G    0.04465         16        224: 100% ━━━━━━━━━━━━ 61/61 9.4it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.8it/s 0.5s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      29/100     0.355G    0.03438         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.1it/s 0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      30/100     0.355G     0.0193         16        224: 100% ━━━━━━━━━━━━ 61/61 10.1it/s 6.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 18.5it/s 0.5s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      31/100     0.355G    0.02691         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 17.7it/s 0.6s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      32/100     0.355G    0.03309         16        224: 100% ━━━━━━━━━━━━ 61/61 9.4it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.1it/s 0.5s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      33/100     0.355G    0.01848         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.1it/s 0.5s
#                    all      0.983          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      34/100     0.355G    0.02731         16        224: 100% ━━━━━━━━━━━━ 61/61 9.9it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 16.6it/s 0.6s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      35/100     0.355G    0.01781         16        224: 100% ━━━━━━━━━━━━ 61/61 9.8it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.2it/s 0.5s
#                    all      0.983          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      36/100     0.355G    0.02887         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 21.7it/s 0.5s
#                    all      0.983          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      37/100     0.355G    0.04738         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.9it/s 0.5s
#                    all      0.987          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      38/100     0.355G    0.02645         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.6it/s 0.5s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      39/100     0.355G    0.04223         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 16.9it/s 0.6s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      40/100     0.355G    0.02679         16        224: 100% ━━━━━━━━━━━━ 61/61 9.7it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 20.8it/s 0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      41/100     0.355G    0.02725         16        224: 100% ━━━━━━━━━━━━ 61/61 9.3it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 22.5it/s 0.4s
#                    all       0.97          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      42/100     0.355G    0.01547         16        224: 100% ━━━━━━━━━━━━ 61/61 9.5it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 19.6it/s 0.5s
#                    all      0.973          1
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 12, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 42 epochs completed in 0.084 hours.
# Optimizer stripped from /kaggle/working/runs/classify/exp_b2_stage2_seed101/weights/last.pt, 3.2MB
# Optimizer stripped from /kaggle/working/runs/classify/exp_b2_stage2_seed101/weights/best.pt, 3.2MB
#
# Validating /kaggle/working/runs/classify/exp_b2_stage2_seed101/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 10/10 9.3it/s 1.1s
#                    all      0.987          1
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/runs/classify/exp_b2_stage2_seed101
#
# Seed 101 complete! Model: /kaggle/working/runs/classify/exp_b2_stage2_seed101/weights/best.pt

# %%
# =============================================================================
# Cell 9: Evaluate Stage 1 (Detection) on Test Set
# =============================================================================
stage1_results = {}

print("="*60)
print("STAGE 1 EVALUATION ON TEST SET")
print("="*60)

for seed in SEEDS:
    model_path = stage1_models.get(seed)
    if not model_path or not Path(model_path).exists():
        print(f"Not found: seed {seed}")
        continue
    
    print(f"\nSeed {seed}:")
    model = YOLO(model_path)
    metrics = model.val(data=str(stage1_config_path), split='test')
    
    stage1_results[seed] = {
        'mAP50': metrics.box.map50,
        'mAP50-95': metrics.box.map,
        'Precision': metrics.box.mp,
        'Recall': metrics.box.mr
    }
    
    print(f"  mAP50: {metrics.box.map50:.3f}")
    print(f"  mAP50-95: {metrics.box.map:.3f}")
# Out:
# ============================================================
# STAGE 1 EVALUATION ON TEST SET
# ============================================================
#
# Seed 42:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 1.2±0.2 ms, read: 2264.6±507.8 MB/s, size: 3110.6 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 558.2it/s 0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.8s
#                    all         40        140      0.861       0.78      0.846      0.554
#                   ripe         17         22      0.809      0.773      0.787      0.496
#                 unripe         38        118      0.913      0.788      0.904      0.612
# Speed: 4.6ms preprocess, 14.8ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
#   mAP50: 0.846
#   mAP50-95: 0.554
#
# Seed 123:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2623.0±712.9 MB/s, size: 3169.3 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 784.5it/s 0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.2s
#                    all         40        140      0.718      0.806      0.805      0.538
#                   ripe         17         22      0.584      0.765      0.686      0.455
#                 unripe         38        118      0.853      0.847      0.924      0.622
# Speed: 3.2ms preprocess, 5.3ms inference, 0.0ms loss, 6.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val2
#   mAP50: 0.805
#   mAP50-95: 0.538
#
# Seed 456:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1997.3±1027.8 MB/s, size: 3064.8 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 1.0Kit/s 0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.2s
#                    all         40        140      0.797      0.712      0.807      0.549
#                   ripe         17         22      0.691      0.636      0.718      0.476
#                 unripe         38        118      0.903      0.787      0.896      0.622
# Speed: 3.6ms preprocess, 6.3ms inference, 0.0ms loss, 4.3ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val3
#   mAP50: 0.807
#   mAP50-95: 0.549
#
# Seed 789:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2108.2±984.9 MB/s, size: 3024.8 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 1.1Kit/s 0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.3s
#                    all         40        140      0.784      0.734      0.811      0.504
#                   ripe         17         22      0.612      0.727      0.701      0.392
#                 unripe         38        118      0.956      0.741      0.921      0.615
# Speed: 2.9ms preprocess, 6.6ms inference, 0.0ms loss, 5.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val4
#   mAP50: 0.811
#   mAP50-95: 0.504
#
# Seed 101:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2212.5±1112.3 MB/s, size: 3132.3 KB)
# val: Scanning /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 1.0Kit/s 0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-ripeness-detect-dataset/ffb_ripeness_detect/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.5s
#                    all         40        140      0.732      0.799        0.8      0.518
#                   ripe         17         22      0.674      0.751      0.703      0.425
#                 unripe         38        118       0.79      0.847      0.896      0.611
# Speed: 3.2ms preprocess, 4.1ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val5
#   mAP50: 0.800
#   mAP50-95: 0.518

# %%
# =============================================================================
# Cell 10: Evaluate Stage 2 (Classification) on Test Crops
# =============================================================================
stage2_results = {}

print("="*60)
print("STAGE 2 EVALUATION ON TEST CROPS")
print("="*60)

for seed in SEEDS:
    model_path = stage2_models.get(seed)
    if not model_path or not Path(model_path).exists():
        print(f"Not found: seed {seed}")
        continue
    
    print(f"\nSeed {seed}:")
    model = YOLO(model_path)
    metrics = model.val(data=str(CROPS_PATH), split='test')
    
    stage2_results[seed] = {
        'Top1_Acc': metrics.top1,
        'Top5_Acc': metrics.top5
    }
    
    print(f"  Top-1 Accuracy: {metrics.top1:.3f}")
    print(f"  Top-5 Accuracy: {metrics.top5:.3f}")
# Out:
# ============================================================
# STAGE 2 EVALUATION ON TEST CROPS
# ============================================================
#
# Seed 42:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2966.1±1151.5 MB/s, size: 352.8 KB)
# test: Scanning /kaggle/working/crops/test... 140 images, 0 corrupt: 100% ━━━━━━━━━━━━ 140/140 442.4it/s 0.3s
# test: New cache created: /kaggle/working/crops/test.cache
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 9/9 12.2it/s 0.7s
#                    all      0.964          1
# Speed: 0.5ms preprocess, 1.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/runs/classify/val
#   Top-1 Accuracy: 0.964
#   Top-5 Accuracy: 1.000
#
# Seed 123:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3222.5±1501.0 MB/s, size: 352.8 KB)
# test: Scanning /kaggle/working/crops/test... 140 images, 0 corrupt: 100% ━━━━━━━━━━━━ 140/140 53.4Mit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 9/9 11.4it/s 0.8s
#                    all      0.971          1
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/runs/classify/val2
#   Top-1 Accuracy: 0.971
#   Top-5 Accuracy: 1.000
#
# Seed 456:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1910.5±441.6 MB/s, size: 352.8 KB)
# test: Scanning /kaggle/working/crops/test... 140 images, 0 corrupt: 100% ━━━━━━━━━━━━ 140/140 58.7Mit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 9/9 11.9it/s 0.8s
#                    all      0.957          1
# Speed: 0.1ms preprocess, 1.0ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/runs/classify/val3
#   Top-1 Accuracy: 0.957
#   Top-5 Accuracy: 1.000
#
# Seed 789:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1937.2±316.8 MB/s, size: 352.8 KB)
# test: Scanning /kaggle/working/crops/test... 140 images, 0 corrupt: 100% ━━━━━━━━━━━━ 140/140 53.4Mit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 9/9 12.0it/s 0.8s
#                    all      0.957          1
# Speed: 0.1ms preprocess, 1.0ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/runs/classify/val4
#   Top-1 Accuracy: 0.957
#   Top-5 Accuracy: 1.000
#
# Seed 101:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: /kaggle/working/crops/train... found 977 images in 2 classes ✅
# val: /kaggle/working/crops/val... found 299 images in 2 classes ✅
# test: /kaggle/working/crops/test... found 140 images in 2 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2140.1±685.6 MB/s, size: 352.8 KB)
# test: Scanning /kaggle/working/crops/test... 140 images, 0 corrupt: 100% ━━━━━━━━━━━━ 140/140 48.9Mit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 9/9 11.6it/s 0.8s
#                    all      0.957          1
# Speed: 0.2ms preprocess, 1.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/runs/classify/val5
#   Top-1 Accuracy: 0.957
#   Top-5 Accuracy: 1.000

# %%
# =============================================================================
# Cell 11: Results Summary
# =============================================================================
# Stage 1 Results
df_stage1 = pd.DataFrame(stage1_results).T
df_stage1.index.name = 'Seed'
avg_stage1 = df_stage1.mean()
std_stage1 = df_stage1.std()

# Stage 2 Results
df_stage2 = pd.DataFrame(stage2_results).T
df_stage2.index.name = 'Seed'
avg_stage2 = df_stage2.mean()
std_stage2 = df_stage2.std()

print("\n" + "="*60)
print("B.2 TWO-STAGE - STAGE 1 (DETECTION) RESULTS")
print("="*60 + "\n")
print(df_stage1.to_string(float_format=lambda x: f"{x:.3f}"))
print("\nSUMMARY (Mean ± Std):")
for col in df_stage1.columns:
    print(f"  {col}: {avg_stage1[col]:.3f} ± {std_stage1[col]:.3f}")

print("\n" + "="*60)
print("B.2 TWO-STAGE - STAGE 2 (CLASSIFICATION) RESULTS")
print("="*60 + "\n")
print(df_stage2.to_string(float_format=lambda x: f"{x:.3f}"))
print("\nSUMMARY (Mean ± Std):")
for col in df_stage2.columns:
    print(f"  {col}: {avg_stage2[col]:.3f} ± {std_stage2[col]:.3f}")
# Out:
# ============================================================
# B.2 TWO-STAGE - STAGE 1 (DETECTION) RESULTS
# ============================================================
#
#       mAP50  mAP50-95  Precision  Recall
# Seed
# 42    0.846     0.554      0.861   0.780
# 123   0.805     0.538      0.718   0.806
# 456   0.807     0.549      0.797   0.712
# 789   0.811     0.504      0.784   0.734
# 101   0.800     0.518      0.732   0.799
#
# SUMMARY (Mean ± Std):
#   mAP50: 0.814 ± 0.018
#   mAP50-95: 0.532 ± 0.021
#   Precision: 0.779 ± 0.057
#   Recall: 0.766 ± 0.042
#
# ============================================================
# B.2 TWO-STAGE - STAGE 2 (CLASSIFICATION) RESULTS
# ============================================================
#
#       Top1_Acc  Top5_Acc
# Seed
# 42       0.964     1.000
# 123      0.971     1.000
# 456      0.957     1.000
# 789      0.957     1.000
# 101      0.957     1.000
#
# SUMMARY (Mean ± Std):
#   Top1_Acc: 0.961 ± 0.006
#   Top5_Acc: 1.000 ± 0.000

# %%
# =============================================================================
# Cell 12: Save Results
# =============================================================================
output_file = KAGGLE_OUTPUT / 'b2_twostage_results.txt'

with open(output_file, 'w') as f:
    f.write("="*60 + "\n")
    f.write("B.2 Two-Stage Ripeness Classification Results\n")
    f.write(f"Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write("Training: epochs=100, patience=30, other=default\n")
    f.write(f"Seeds: {SEEDS}\n")
    f.write("="*60 + "\n\n")
    
    f.write("STAGE 1 (Detection) Results:\n")
    f.write(df_stage1.to_string(float_format=lambda x: f"{x:.3f}"))
    f.write("\n\nStage 1 Summary (Mean ± Std):\n")
    for col in df_stage1.columns:
        f.write(f"  {col}: {avg_stage1[col]:.3f} ± {std_stage1[col]:.3f}\n")
    
    f.write("\n" + "="*60 + "\n")
    f.write("STAGE 2 (Classification) Results:\n")
    f.write(df_stage2.to_string(float_format=lambda x: f"{x:.3f}"))
    f.write("\n\nStage 2 Summary (Mean ± Std):\n")
    for col in df_stage2.columns:
        f.write(f"  {col}: {avg_stage2[col]:.3f} ± {std_stage2[col]:.3f}\n")

print(f"Results saved: {output_file}")
# Out:
# Results saved: /kaggle/working/kaggleoutput/b2_twostage_results.txt

# %%
# =============================================================================
# Cell 13: Create Archives
# =============================================================================
if (RUNS_PATH / 'detect').exists():
    shutil.make_archive('/kaggle/working/b2_stage1_runs', 'zip', RUNS_PATH / 'detect')
    print(f"b2_stage1_runs.zip created")

if (RUNS_PATH / 'classify').exists():
    shutil.make_archive('/kaggle/working/b2_stage2_runs', 'zip', RUNS_PATH / 'classify')
    print(f"b2_stage2_runs.zip created")

shutil.make_archive('/kaggle/working/b2_output', 'zip', KAGGLE_OUTPUT)
print("b2_output.zip created")

print("\nDownload from Output tab")
# Out:
# b2_stage1_runs.zip created
# b2_stage2_runs.zip created
# b2_output.zip created
#
# Download from Output tab
