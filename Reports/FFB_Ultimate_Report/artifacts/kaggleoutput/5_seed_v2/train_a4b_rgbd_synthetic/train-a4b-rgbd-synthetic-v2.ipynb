# %% [markdown]
# # A.4b RGB + Synthetic Depth 4-Channel with Reset BN
#
# **Experiment:** A.4b - RGB+Synthetic Depth Fusion
# **Input:** RGB + Synthetic Depth (4-channel RGBD)
# **Objective:** Test fusion of RGB with synthetic depth (Depth-Anything-V2)
# **Classes:** 1 (fresh_fruit_bunch)
#
# ## Key Features
# 1. **4-Channel Input**: RGB (3) + Synthetic Depth (1) = 4 channels
# 2. **Custom Trainer**: RGBD4ChTrainer with 4-channel support
# 3. **Monkey-Patch**: Modified imread for 4-channel image loading
# 4. **First Conv Adaptation**: Convert 3ch to 4ch input layer
# 5. **Reset BN**: Domain adaptation for RGBD input
#
# ## Prerequisites
# - Upload RGB dataset as: `ffb-localization-dataset`
# - Upload Synthetic Depth dataset as: `ffb-synthetic-depth`
#
# ## Uniform Augmentation (All Experiments)
# - translate: 0.1
# - scale: 0.5
# - fliplr: 0.5
# - hsv_h: 0.0 (disabled for uniformity)
# - hsv_s: 0.0 (disabled for uniformity)
# - hsv_v: 0.0 (disabled for uniformity)
# - erasing: 0.0
# - mosaic: 0.0
# - mixup: 0.0

# %%
# =============================================================================
# Cell 1: Setup & Install
# =============================================================================
# !pip install -q ultralytics

import os
import sys
import torch
import torch.nn as nn
import numpy as np
import cv2
import shutil
import gc
import time
import json
from pathlib import Path
from datetime import datetime
from tqdm.auto import tqdm

os.environ["WANDB_DISABLED"] = "true"

# Auto-detect environment
IS_KAGGLE = os.path.exists('/kaggle/input') or os.path.exists('/kaggle')

if IS_KAGGLE:
    BASE_PATH = Path('/kaggle/working')
    RGB_DATASET = Path('/kaggle/input/ffb-localization-dataset/ffb_localization')
    DEPTH_DATASET = Path('/kaggle/input/ffb-synthetic-depth')
else:
    BASE_PATH = Path('D:/Work/Assisten Dosen/Anylabel/Experiments')
    RGB_DATASET = BASE_PATH / 'datasets' / 'ffb_localization'
    DEPTH_DATASET = BASE_PATH / 'datasets' / 'ffb_localization_depth_synthetic'

RUNS_PATH = BASE_PATH / 'runs' / 'detect'
RGBD_DATASET = BASE_PATH / 'rgbd_synthetic_4ch'
KAGGLE_OUTPUT = BASE_PATH / 'kaggleoutput'
KAGGLE_OUTPUT.mkdir(parents=True, exist_ok=True)

print("="*60)
print("A.4b RGB+SYNTHETIC DEPTH (4-CH) - ENVIRONMENT SETUP")
print("="*60)
print(f"Running on: {'Kaggle' if IS_KAGGLE else 'Local'}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    torch.cuda.empty_cache()
print(f"RGB Dataset: {RGB_DATASET}")
print(f"Depth Dataset: {DEPTH_DATASET}")
print(f"Output RGBD: {RGBD_DATASET}")
print("="*60)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.3 MB/s eta 0:00:00
# ============================================================
# A.4b RGB+SYNTHETIC DEPTH (4-CH) - ENVIRONMENT SETUP
# ============================================================
# Running on: Kaggle
# PyTorch: 2.8.0+cu126
# CUDA: True
# GPU: Tesla T4
# RGB Dataset: /kaggle/input/ffb-localization-dataset/ffb_localization
# Depth Dataset: /kaggle/input/ffb-synthetic-depth
# Output RGBD: /kaggle/working/rgbd_synthetic_4ch
# ============================================================

# %%
# =============================================================================
# Cell 2: Configuration AUGMENT_PARAMS
# =============================================================================
# Uniform augmentation parameters (consistent across all experiments)
AUGMENT_PARAMS = {
    'translate': 0.1,
    'scale': 0.5,
    'fliplr': 0.5,
    'hsv_h': 0.0,  # Disabled for uniformity
    'hsv_s': 0.0,  # Disabled for uniformity
    'hsv_v': 0.0,  # Disabled for uniformity
    'erasing': 0.0,
    'mosaic': 0.0,
    'mixup': 0.0,
    'degrees': 0.0,
    'copy_paste': 0.0,
}

# Training configuration
SEEDS = [42, 123, 456, 789, 101]
EXP_PREFIX = 'exp_a4b_rgbd_synth_v2'
EPOCHS = 100
PATIENCE = 30
IMGSZ = 640
BATCH_SIZE = 16
DEVICE = 0 if torch.cuda.is_available() else 'cpu'

print("="*60)
print("TRAINING CONFIGURATION")
print("="*60)
print(f"Experiment: A.4b RGB+Synthetic Depth (4-CH) (V2)")
print(f"Model: YOLOv11n")
print(f"Seeds: {SEEDS} ({len(SEEDS)} runs)")
print(f"Epochs: {EPOCHS} (patience: {PATIENCE})")
print(f"Image Size: {IMGSZ}")
print(f"Batch Size: {BATCH_SIZE}")
print(f"Device: {DEVICE}")
print("\nUniform Augmentation:")
for key, value in AUGMENT_PARAMS.items():
    print(f"  {key}: {value}")
print("\nSpecial Features:")
print("  - 4-Channel input (RGB+Synthetic Depth)")
print("  - Custom 4-channel trainer")
print("  - Reset BatchNorm for domain adaptation")
print("="*60)
# Out:
# ============================================================
# TRAINING CONFIGURATION
# ============================================================
# Experiment: A.4b RGB+Synthetic Depth (4-CH) (V2)
# Model: YOLOv11n
# Seeds: [42, 123, 456, 789, 101] (5 runs)
# Epochs: 100 (patience: 30)
# Image Size: 640
# Batch Size: 16
# Device: 0
#
# Uniform Augmentation:
#   translate: 0.1
#   scale: 0.5
#   fliplr: 0.5
#   hsv_h: 0.0
#   hsv_s: 0.0
#   hsv_v: 0.0
#   erasing: 0.0
#   mosaic: 0.0
#   mixup: 0.0
#   degrees: 0.0
#   copy_paste: 0.0
#
# Special Features:
#   - 4-Channel input (RGB+Synthetic Depth)
#   - Custom 4-channel trainer
#   - Reset BatchNorm for domain adaptation
# ============================================================

# %%
# =============================================================================
# Cell 3: Helper functions - convert_conv_to_4ch() and reset_bn_stats()
# =============================================================================
def convert_conv_to_4ch(conv_layer):
    """
    Convert a conv layer from 3ch to 4ch input.
    Copies RGB weights and initializes depth channel as mean of RGB.
    """
    if conv_layer.in_channels == 4:
        return conv_layer
    
    new_conv = nn.Conv2d(
        in_channels=4,
        out_channels=conv_layer.out_channels,
        kernel_size=conv_layer.kernel_size,
        stride=conv_layer.stride,
        padding=conv_layer.padding,
        bias=conv_layer.bias is not None
    )
    
    with torch.no_grad():
        new_conv.weight[:, :3, :, :] = conv_layer.weight.clone()
        new_conv.weight[:, 3:4, :, :] = conv_layer.weight.mean(dim=1, keepdim=True)
        if conv_layer.bias is not None:
            new_conv.bias = nn.Parameter(conv_layer.bias.clone())
    
    return new_conv


def reset_bn_stats(model, train_loader, num_batches=100, device='cuda'):
    """Reset running stats BatchNorm dengan 100 batch training data."""
    model.train()
    
    for module in model.modules():
        if isinstance(module, nn.BatchNorm2d):
            module.reset_running_stats()
            module.momentum = 0.1
    
    with torch.no_grad():
        for i, batch in enumerate(train_loader):
            if i >= num_batches:
                break
            imgs = batch['img'].to(device) if isinstance(batch, dict) else batch[0].to(device)
            _ = model(imgs)
    
    return model


def ensure_model_4ch(model):
    """Ensure model has 4-channel input."""
    try:
        if hasattr(model, 'model') and hasattr(model.model, 'model'):
            first_conv = model.model.model[0].conv
            if first_conv.in_channels == 3:
                print("[4ch] Converting model...")
                model.model.model[0].conv = convert_conv_to_4ch(first_conv)
                return True
        elif hasattr(model, 'model') and hasattr(model.model[0], 'conv'):
            first_conv = model.model[0].conv
            if first_conv.in_channels == 3:
                print("[4ch] Converting model...")
                model.model[0].conv = convert_conv_to_4ch(first_conv)
                return True
    except Exception as e:
        print(f"[4ch] Warning: {e}")
    return False

print("✓ Helper functions defined")
# Out:
# ✓ Helper functions defined

# %%
# =============================================================================
# Cell 4: Create 4-Channel RGBD Dataset for Synthetic Depth
# =============================================================================
print("="*60)
print("CREATING 4-CHANNEL RGBD DATASET")
print("="*60)

for split in ['train', 'val', 'test']:
    print(f"\nProcessing {split.upper()}...")
    
    rgb_img_dir = RGB_DATASET / 'images' / split
    depth_img_dir = DEPTH_DATASET / 'images' / split
    rgb_lbl_dir = RGB_DATASET / 'labels' / split
    
    # Create output directories
    rgbd_img_dir = RGBD_DATASET / 'images' / split
    rgbd_lbl_dir = RGBD_DATASET / 'labels' / split
    rgbd_img_dir.mkdir(parents=True, exist_ok=True)
    rgbd_lbl_dir.mkdir(parents=True, exist_ok=True)
    
    # Get RGB files
    rgb_files = sorted(list(rgb_img_dir.glob('*.png')))
    
    for rgb_path in tqdm(rgb_files, desc=f"Creating 4-ch ({split})"):
        # Load RGB (3 channels)
        rgb = cv2.imread(str(rgb_path))
        if rgb is None:
            print(f"  Warning: Could not read {rgb_path}")
            continue
        
        # Load synthetic depth (1 channel)
        depth_path = depth_img_dir / rgb_path.name
        depth = cv2.imread(str(depth_path), cv2.IMREAD_GRAYSCALE)
        if depth is None:
            print(f"  Warning: Could not read {depth_path}")
            continue
        
        # Resize depth if needed
        if depth.shape[:2] != rgb.shape[:2]:
            depth = cv2.resize(depth, (rgb.shape[1], rgb.shape[0]))
        
        # Combine RGB (3) + Depth (1) = 4 channels
        depth_expanded = depth[:, :, np.newaxis]
        rgbd_4ch = np.concatenate([rgb, depth_expanded], axis=2)
        
        # Save 4-channel image
        output_img_path = rgbd_img_dir / rgb_path.name
        cv2.imwrite(str(output_img_path), rgbd_4ch)
    
    # Copy labels
    label_files = list(rgb_lbl_dir.glob('*.txt'))
    for lbl_path in label_files:
        shutil.copy(str(lbl_path), str(rgbd_lbl_dir / lbl_path.name))
    
    img_count = len(list(rgbd_img_dir.glob('*.png')))
    lbl_count = len(list(rgbd_lbl_dir.glob('*.txt')))
    print(f"  Done: {img_count} images, {lbl_count} labels")

# Verify sample
sample_img = list((RGBD_DATASET / 'images' / 'train').glob('*.png'))[0]
img = cv2.imread(str(sample_img), cv2.IMREAD_UNCHANGED)
print(f"\n✓ Sample image shape: {img.shape} (should be H x W x 4)")
# Out:
# ============================================================
# CREATING 4-CHANNEL RGBD DATASET
# ============================================================
#
# Processing TRAIN...
# Creating 4-ch (train):   0%|          | 0/280 [00:00<?, ?it/s]
#   Done: 280 images, 280 labels
#
# Processing VAL...
# Creating 4-ch (val):   0%|          | 0/80 [00:00<?, ?it/s]
#   Done: 80 images, 80 labels
#
# Processing TEST...
# Creating 4-ch (test):   0%|          | 0/40 [00:00<?, ?it/s]
#   Done: 40 images, 40 labels
#
# ✓ Sample image shape: (720, 1280, 4) (should be H x W x 4)

# %%
# =============================================================================
# Cell 5: Custom RGBD4ChTrainer and RGBD4ChValidator classes
# =============================================================================
import ultralytics.utils.patches as patches

_original_imread = patches.imread

def imread_4ch(filename, flags=cv2.IMREAD_UNCHANGED):
    """Always read with IMREAD_UNCHANGED to preserve 4 channels"""
    return _original_imread(filename, cv2.IMREAD_UNCHANGED)

patches.imread = imread_4ch
print("✓ Patched imread for 4-channel support")

from ultralytics import YOLO
from ultralytics.models.yolo.detect import DetectionTrainer, DetectionValidator
from ultralytics.nn.tasks import DetectionModel
import torch
print("✓ YOLO imported")


class RGBD4ChTrainer(DetectionTrainer):
    """
    Trainer khusus untuk 4-channel RGBD dengan BN reset menggunakan gambar training asli.
    Sesuai catatan dosen: forward pass 100 gambar training sebelum mulai training.
    """
    def __init__(self, overrides=None):
        super().__init__(overrides=overrides)  # Fix: explicit keyword argument
        # Register callback untuk BN reset setelah setup selesai
        self.add_callback("on_train_start", self._bn_reset_callback)
        self._bn_reset_done = False
    
    def get_model(self, cfg=None, weights=None, verbose=True):
        """Load model dan modifikasi first conv layer untuk 4 channels."""
        model = super().get_model(cfg, weights, verbose)

        # Modifikasi first conv layer dari 3ch ke 4ch
        first_conv = model.model[0].conv
        if first_conv.in_channels == 3:
            print("[Trainer] Converting first conv: 3ch → 4ch...")
            model.model[0].conv = convert_conv_to_4ch(first_conv)
            print(f"[Trainer] ✅ Converted! Shape: {model.model[0].conv.weight.shape}")
        else:
            print("[Trainer] Model sudah 4-channel")

        return model
    
    def build_dataset(self, img_path, mode="train", batch=None):
        """Override: gunakan RGBDDataset yang load 4 channel."""
        from ultralytics.data.dataset import YOLODataset
        import cv2
        import numpy as np
        from pathlib import Path
        
        class RGBDDataset(YOLODataset):
            """Dataset yang load 4-channel RGBD images."""
            def load_image(self, i):
                """Load 4-channel image."""
                im = cv2.imread(self.im_files[i], cv2.IMREAD_UNCHANGED)
                if im is None:
                    raise FileNotFoundError(f"Image Not Found {self.im_files[i]}")
                
                # Ensure 4 channels
                if len(im.shape) == 2:
                    # Grayscale - convert to 4ch by replicating
                    im = cv2.cvtColor(im, cv2.COLOR_GRAY2BGR)
                    im = np.dstack([im, im[:,:,0]])
                elif im.shape[2] == 3:
                    # RGB - need depth channel
                    # Try to load depth from separate file or use zeros
                    depth_channel = np.zeros((im.shape[0], im.shape[1], 1), dtype=np.uint8)
                    im = np.dstack([im, depth_channel])
                
                h0, w0 = im.shape[:2]
                r = self.imgsz / max(h0, w0)
                if r != 1:
                    interp = cv2.INTER_LINEAR if r > 1 else cv2.INTER_AREA
                    im = cv2.resize(im, (int(w0 * r), int(h0 * r)), interpolation=interp)
                
                return im, (h0, w0), im.shape[:2]
        
        return RGBDDataset(
            img_path=img_path,
            imgsz=self.args.imgsz,
            batch_size=batch,
            augment=mode == "train",
            hyp=self.args,
            rect=mode == "val",
            cache=self.args.cache,
            single_cls=self.args.single_cls,
            stride=int(self.model.stride.max()) if hasattr(self.model, 'stride') else 32,
            pad=0.0 if mode == "train" else 0.5,
            prefix=f"{mode}: ",
            data=self.data,
        )
    
    def _bn_reset_callback(self, trainer):
        """
        Callback: Reset BatchNorm dengan forward pass 100 gambar training.
        Dipanggil otomatis saat on_train_start.
        """
        if self._bn_reset_done:
            return
            
        print(f"\n[BN Reset] Resetting BatchNorm dengan 100 gambar training...")
        
        # 1. Reset running stats
        bn_layers = []
        for module in self.model.modules():
            if isinstance(module, nn.BatchNorm2d):
                module.reset_running_stats()
                module.momentum = 0.1
                bn_layers.append(module)
        print(f"[BN Reset] Found {len(bn_layers)} BatchNorm layers")
        
        # 2. Set model to train mode
        self.model.train()
        
        # 3. Forward pass dengan 100 gambar training asli
        device = next(self.model.parameters()).device
        images_processed = 0
        n_images = 100
        
        with torch.no_grad():
            for batch in self.train_loader:
                if images_processed >= n_images:
                    break
                
                images = batch['img'].to(device, non_blocking=True)
                
                # Fix: Normalize uint8 to float32
                if images.dtype == torch.uint8:
                    images = images.float() / 255.0
                
                print(f"[BN Reset] Batch shape: {images.shape}, dtype: {images.dtype}")
                
                # Forward pass - update BN running stats
                _ = self.model(images)
                
                images_processed += len(images)
        
        print(f"[BN Reset] ✅ Completed forward pass pada {images_processed} gambar")
        
        # 4. Verify BN stats
        if bn_layers:
            sample_bn = bn_layers[0]
            print(f"[BN Reset] Sample BN running_mean: [{sample_bn.running_mean.min():.4f}, {sample_bn.running_mean.max():.4f}]")
        
        self._bn_reset_done = True

    def get_validator(self):
        self.loss_names = "box_loss", "cls_loss", "dfl_loss"
        return RGBD4ChValidator(
            self.test_loader,
            save_dir=self.save_dir,
            args=self.args,
            _callbacks=self.callbacks
        )


class RGBD4ChValidator(DetectionValidator):
    """Validator yang convert model ke 4ch dan pakai RGBDDataset."""
    
    def build_dataset(self, img_path, mode="val", batch=None):
        """Override: gunakan RGBDDataset yang load 4 channel."""
        from ultralytics.data.dataset import YOLODataset
        import cv2
        import numpy as np
        
        class RGBDDataset(YOLODataset):
            """Dataset yang load 4-channel RGBD images."""
            def load_image(self, i):
                """Load 4-channel image."""
                im = cv2.imread(self.im_files[i], cv2.IMREAD_UNCHANGED)
                if im is None:
                    raise FileNotFoundError(f"Image Not Found {self.im_files[i]}")
                
                # Ensure 4 channels
                if len(im.shape) == 2:
                    im = cv2.cvtColor(im, cv2.COLOR_GRAY2BGR)
                    im = np.dstack([im, im[:,:,0]])
                elif im.shape[2] == 3:
                    depth_channel = np.zeros((im.shape[0], im.shape[1], 1), dtype=np.uint8)
                    im = np.dstack([im, depth_channel])
                
                h0, w0 = im.shape[:2]
                r = self.imgsz / max(h0, w0)
                if r != 1:
                    interp = cv2.INTER_LINEAR if r > 1 else cv2.INTER_AREA
                    im = cv2.resize(im, (int(w0 * r), int(h0 * r)), interpolation=interp)
                
                return im, (h0, w0), im.shape[:2]
        
        return RGBDDataset(
            img_path=img_path,
            imgsz=self.args.imgsz,
            batch_size=batch,
            augment=False,
            hyp=self.args,
            rect=True,
            cache=self.args.cache if hasattr(self.args, 'cache') else False,
            single_cls=self.args.single_cls if hasattr(self.args, 'single_cls') else False,
            stride=int(self.stride.max()) if hasattr(self, 'stride') and hasattr(self.stride, 'max') else int(self.stride) if hasattr(self, 'stride') else 32,
            pad=0.5,
            prefix=f"{mode}: ",
            data=self.data,
        )
    
    def setup_model(self):
        super().setup_model()
        if self.model is not None:
            ensure_model_4ch(self.model)
            print("[Validator] Model 4ch ready")


print("✅ Custom Trainer & Validator defined")
print("   - Auto-convert 3ch → 4ch di get_model()")
print("   - build_dataset() override untuk 4-channel RGBDDataset")
print("   - BN reset dengan 100 gambar training asli via callback on_train_start")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✓ Patched imread for 4-channel support
# ✓ YOLO imported
# ✅ Custom Trainer & Validator defined
#    - Auto-convert 3ch → 4ch di get_model()
#    - build_dataset() override untuk 4-channel RGBDDataset
#    - BN reset dengan 100 gambar training asli via callback on_train_start

# %%
# =============================================================================
# Cell 6: Create 4ch dataset and YAML
# =============================================================================
yaml_content = f"""
# A.4b RGB+Synthetic Depth 4-Channel Dataset Configuration
path: {RGBD_DATASET}
train: images/train
val: images/val
test: images/test

nc: 1
channels: 4

names:
  0: fresh_fruit_bunch
"""

config_path = RGBD_DATASET / 'dataset_rgbd_synthetic_v2.yaml'
with open(config_path, 'w') as f:
    f.write(yaml_content)

print(f"✅ Config saved: {config_path}")
print("\nConfig contents:")
print("-"*40)
print(yaml_content)
# Out:
# ✅ Config saved: /kaggle/working/rgbd_synthetic_4ch/dataset_rgbd_synthetic_v2.yaml
#
# Config contents:
# ----------------------------------------
#
# # A.4b RGB+Synthetic Depth 4-Channel Dataset Configuration
# path: /kaggle/working/rgbd_synthetic_4ch
# train: images/train
# val: images/val
# test: images/test
#
# nc: 1
# channels: 4
#
# names:
#   0: fresh_fruit_bunch

# %%
# =============================================================================
# Cell 7: Training loop (Simplified - BN reset handled in trainer)
# =============================================================================
results_all = {}
training_times = {}

print("\n" + "="*60)
print("STARTING TRAINING LOOP")
print("="*60)

for idx, seed in enumerate(SEEDS, 1):
    start_time = time.time()
    
    print(f"\n{'='*60}")
    print(f"TRAINING A.4b RGBD SYNTHETIC - Seed {seed} ({idx}/{len(SEEDS)})")
    print(f"{'='*60}")
    
    # Set seeds
    torch.manual_seed(seed)
    np.random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    
    try:
        # Create trainer - 4ch conversion dan BN reset otomatis di get_model()
        trainer = RGBD4ChTrainer(overrides={
            'model': 'yolo11n.pt',
            'data': str(config_path),
            'imgsz': IMGSZ,
            'epochs': EPOCHS,
            'batch': BATCH_SIZE,
            'device': DEVICE,
            'seed': seed,
            'name': f"{EXP_PREFIX}_seed{seed}",
            'project': str(RUNS_PATH),
            'exist_ok': True,
            'pretrained': True,
            'patience': PATIENCE,
            'val': True,
            **AUGMENT_PARAMS,
        })
        
        # Train - conversion 4ch dan BN reset sudah dilakukan di get_model()
        trainer.train()
        
        elapsed = time.time() - start_time
        training_times[seed] = elapsed
        
        results_all[seed] = {
            'model_path': str(RUNS_PATH / f"{EXP_PREFIX}_seed{seed}" / "weights" / "best.pt"),
            'epochs_trained': EPOCHS,
            'completed': True,
        }
        
        print(f"\n✓ Seed {seed} completed!")
        print(f"  Time: {elapsed/60:.1f} minutes")
        
    except Exception as e:
        print(f"\n✗ Seed {seed} failed: {e}")
        import traceback
        traceback.print_exc()
        results_all[seed] = {'error': str(e), 'completed': False}
    
    # Cleanup
    if 'trainer' in locals():
        del trainer
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

print("\n" + "="*60)
print("TRAINING LOOP COMPLETED")
print("="*60)

# Print summary
print("\n📊 RESULTS SUMMARY:")
successful = sum(1 for r in results_all.values() if r.get('completed', False))
print(f"Successful: {successful}/{len(SEEDS)}")
for seed, res in results_all.items():
    if res.get('completed', False):
        print(f"  Seed {seed}: ✓ Completed")
    else:
        print(f"  Seed {seed}: ✗ FAILED - {res.get('error', 'Unknown')[:50]}...")
# Out:
# ============================================================
# STARTING TRAINING LOOP
# ============================================================
#
# ============================================================
# TRAINING A.4b RGBD SYNTHETIC - Seed 42 (1/5)
# ============================================================
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/rgbd_synthetic_4ch/dataset_rgbd_synthetic_v2.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.0, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=exp_a4b_rgbd_synth_v2_seed42, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed42, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.6MB/s 0.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 66.3MB/s 0.1s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       608  ultralytics.nn.modules.conv.Conv             [4, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,179 parameters, 2,590,163 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# [Trainer] Model sudah 4-channel
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 65.9MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4407.1±1127.4 MB/s, size: 2174.1 KB)
# train: Scanning /kaggle/working/rgbd_synthetic_4ch/labels/train... 280 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 280/280 76.1it/s 3.7s
# train: New cache created: /kaggle/working/rgbd_synthetic_4ch/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2578.3±2168.8 MB/s, size: 2411.0 KB)
# val: Scanning /kaggle/working/rgbd_synthetic_4ch/labels/val... 80 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 77.0it/s 1.0s
# val: New cache created: /kaggle/working/rgbd_synthetic_4ch/labels/val.cache
# Plotting labels to /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed42/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
#
# [BN Reset] Resetting BatchNorm dengan 100 gambar training...
# [BN Reset] Found 81 BatchNorm layers
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] ✅ Completed forward pass pada 112 gambar
# [BN Reset] Sample BN running_mean: [-0.1181, 0.0675]
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed42
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.26G      2.493      4.228      2.108         40        640: 100% ━━━━━━━━━━━━ 18/18 1.3s/it 22.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.3s/it 6.8s
#                    all         80        186   0.000208     0.0269   0.000108   2.14e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.27G      1.975      2.836      1.642         40        640: 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186    0.00433      0.559      0.011    0.00207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.29G      1.919      2.437      1.644         39        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186       0.85      0.344      0.604      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100       2.3G      1.856      2.195      1.664         41        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.748      0.688       0.76      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.31G       1.87      2.098      1.644         44        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186       0.69      0.681       0.68      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.34G      1.879      2.015      1.662         34        640: 100% ━━━━━━━━━━━━ 18/18 2.9it/s 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.737      0.688      0.751       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.36G      1.831       1.83      1.643         36        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        186      0.649      0.645      0.707      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.37G      1.842       1.81      1.581         38        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        186      0.787       0.71      0.791      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.38G      1.799      1.647      1.629         37        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.694      0.758      0.779      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100       2.4G      1.768      1.507      1.549         32        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.742      0.743      0.774      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.41G      1.785      1.444      1.583         39        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.753      0.753      0.776       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.43G       1.79      1.407      1.584         41        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.827      0.726       0.82      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.44G      1.784      1.371      1.571         34        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.788      0.739      0.832      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.46G      1.759      1.301      1.574         38        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.789      0.763      0.827      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.47G      1.698      1.296      1.543         40        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.903      0.751      0.862      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.49G      1.697      1.234      1.489         35        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.732      0.801      0.825      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100       2.5G      1.741      1.225      1.552         39        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.816       0.72      0.824      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.52G      1.686      1.209      1.535         44        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.874      0.743      0.863      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.54G      1.711      1.144      1.533         37        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.875      0.753      0.863      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.54G      1.788      1.194      1.541         41        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.819      0.728      0.853      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.56G      1.646      1.126      1.498         41        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.881       0.71      0.842      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.58G      1.686      1.088      1.498         38        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.799       0.78      0.844      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.59G       1.67      1.096      1.505         44        640: 100% ━━━━━━━━━━━━ 18/18 3.3it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.789      0.743      0.844       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.61G      1.642       1.06      1.475         44        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.813      0.763      0.852      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.62G       1.69      1.046      1.474         43        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.831      0.685      0.796      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.63G      1.587      1.023      1.449         41        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.821       0.78      0.858      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.65G       1.64       1.03      1.469         38        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.809      0.753      0.824      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.66G      1.644      1.031      1.481         38        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.844      0.725      0.843      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.68G      1.559     0.9548      1.412         35        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.803      0.817      0.865      0.422
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100       2.7G      1.615      0.947      1.466         37        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.735      0.833      0.854      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.71G      1.561     0.9113       1.41         34        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.7it/s 0.4s
#                    all         80        186      0.793       0.78      0.853      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.73G      1.547     0.9041      1.421         38        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        186      0.882      0.704      0.852        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.74G      1.603     0.9188      1.407         37        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.833      0.753      0.846      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.75G      1.534     0.9208      1.413         39        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.787      0.823      0.865      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.77G      1.555     0.9059      1.423         42        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.0it/s 0.5s
#                    all         80        186      0.815       0.78      0.868      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.78G      1.525     0.8787      1.377         41        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.837      0.785      0.893      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100       2.8G       1.54      0.883      1.393         43        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.828      0.806      0.851      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.81G      1.555     0.8819       1.37         31        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.4it/s 0.4s
#                    all         80        186      0.831      0.767      0.857      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.83G      1.509     0.8433      1.379         39        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.856      0.738      0.836      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      2.84G      1.476     0.8528      1.364         42        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.9it/s 0.4s
#                    all         80        186      0.837      0.806      0.878      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      2.86G      1.477     0.8258      1.369         46        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.835       0.79      0.847      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.88G      1.494     0.7973      1.366         35        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.818      0.773      0.842       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.88G      1.484     0.8123      1.374         38        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.4it/s 0.4s
#                    all         80        186      0.848      0.783      0.861      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100       2.9G      1.464     0.7862      1.339         43        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.6it/s 0.4s
#                    all         80        186      0.806      0.801      0.842        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.91G      1.409     0.7601      1.298         34        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.799      0.774      0.842      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.93G       1.48     0.7857      1.341         31        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.756      0.758      0.797      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      2.95G      1.427     0.7553      1.332         38        640: 100% ━━━━━━━━━━━━ 18/18 3.3it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        186      0.786       0.78      0.853      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      2.96G      1.424     0.7877      1.303         43        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.7it/s 0.4s
#                    all         80        186      0.776      0.784      0.812      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      2.97G      1.425     0.7873      1.314         34        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.7it/s 0.4s
#                    all         80        186      0.818      0.773      0.849       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      2.99G      1.404     0.7723      1.311         38        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.847      0.758      0.839      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100         3G      1.459     0.7805      1.318         34        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         80        186      0.829      0.806      0.858      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.02G      1.444     0.7473      1.325         41        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.842      0.758      0.865      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      3.03G      1.419     0.7538       1.31         29        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.5it/s 0.4s
#                    all         80        186      0.832       0.77      0.863      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      3.05G      1.371     0.7332      1.283         38        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.9it/s 0.4s
#                    all         80        186      0.891      0.742      0.853       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      3.06G      1.379     0.7376      1.293         33        640: 100% ━━━━━━━━━━━━ 18/18 3.3it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.807      0.774      0.839      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      3.08G      1.358     0.7034      1.285         43        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.5it/s 0.4s
#                    all         80        186      0.829      0.783      0.847      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100       3.1G      1.365     0.7173      1.291         45        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.835      0.731      0.857       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      3.11G       1.36     0.7193      1.264         40        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186       0.85      0.742      0.835       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      3.12G      1.343     0.7082      1.264         43        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.865      0.763      0.854      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      3.14G      1.335     0.6906      1.249         47        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.5it/s 0.4s
#                    all         80        186      0.851      0.766       0.85      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      3.16G      1.315     0.6794      1.247         41        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.6it/s 0.4s
#                    all         80        186      0.871      0.753      0.848      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      3.17G      1.303     0.6501      1.243         43        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.785      0.806      0.845      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      3.18G      1.242     0.6424      1.205         35        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.6it/s 0.4s
#                    all         80        186      0.802      0.739      0.821      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100       3.2G      1.333     0.6651      1.248         38        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.6it/s 0.4s
#                    all         80        186      0.813      0.737      0.827      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      3.21G      1.305      0.651       1.24         40        640: 100% ━━━━━━━━━━━━ 18/18 3.3it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.819      0.763      0.831      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      3.23G      1.275     0.6495      1.227         42        640: 100% ━━━━━━━━━━━━ 18/18 3.3it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.801       0.78      0.838      0.385
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 36, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 66 epochs completed in 0.130 hours.
# Optimizer stripped from /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed42/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed42/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed42/weights/best.pt...
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.2it/s 0.9s
#                    all         80        186      0.835      0.785      0.893      0.432
# Speed: 0.2ms preprocess, 1.8ms inference, 0.0ms loss, 2.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed42
#
# ✓ Seed 42 completed!
#   Time: 8.4 minutes
#
# ============================================================
# TRAINING A.4b RGBD SYNTHETIC - Seed 123 (2/5)
# ============================================================
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/rgbd_synthetic_4ch/dataset_rgbd_synthetic_v2.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.0, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=exp_a4b_rgbd_synth_v2_seed123, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed123, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=123, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       608  ultralytics.nn.modules.conv.Conv             [4, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,179 parameters, 2,590,163 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# [Trainer] Model sudah 4-channel
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5065.9±1064.8 MB/s, size: 2263.5 KB)
# train: Scanning /kaggle/working/rgbd_synthetic_4ch/labels/train.cache... 280 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 280/280 130.5Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1861.8±1642.7 MB/s, size: 2416.1 KB)
# val: Scanning /kaggle/working/rgbd_synthetic_4ch/labels/val.cache... 80 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 2.9Mit/s 0.0s
# Plotting labels to /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed123/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
#
# [BN Reset] Resetting BatchNorm dengan 100 gambar training...
# [BN Reset] Found 81 BatchNorm layers
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] Batch shape: torch.Size([16, 4, 640, 640]), dtype: torch.float32
# [BN Reset] ✅ Completed forward pass pada 112 gambar
# [BN Reset] Sample BN running_mean: [-0.1420, 0.1223]
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed123
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.21G      2.427      4.212      2.188         40        640: 100% ━━━━━━━━━━━━ 18/18 2.5it/s 7.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        186    0.00025     0.0323   0.000129   2.79e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.23G      2.006      2.712      1.749         40        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        186    0.00233      0.301    0.00203   0.000527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.24G      1.926      2.261      1.582         39        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.7it/s 0.5s
#                    all         80        186      0.825      0.478      0.649      0.252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.25G      1.987      2.143      1.609         41        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         80        186      0.491      0.473      0.465      0.142
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.26G      1.851      1.991      1.507         44        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.704      0.652      0.718      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.27G      1.855      1.939      1.576         34        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.8it/s 0.5s
#                    all         80        186      0.521      0.597      0.575      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.28G      1.854      1.823      1.546         36        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.831       0.72      0.804      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.29G      1.868      1.792       1.47         38        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        186      0.751      0.677      0.754      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.29G      1.879      1.635      1.509         37        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.816      0.656      0.786      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100       2.3G      1.776      1.541      1.454         32        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.792      0.747      0.828      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.31G      1.861      1.492      1.496         39        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.718        0.7      0.762      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.31G      1.748      1.411      1.422         41        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         80        186      0.775      0.759      0.822      0.381
#
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.787      0.828      0.865      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      2.37G      1.268     0.6429      1.123         42        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        186      0.764      0.855      0.855      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      2.37G      1.251     0.6378      1.118         37        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.793      0.801       0.86      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      2.37G      1.271     0.6332      1.125         35        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.803      0.832      0.859      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      2.37G      1.233     0.6155      1.105         38        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.832      0.798      0.853       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      2.37G      1.242     0.6086      1.112         39        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.856      0.797      0.874      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.37G      1.223     0.5974      1.097         41        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186      0.792      0.842      0.845      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      2.37G      1.215     0.5939      1.103         41        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186       0.81      0.825      0.846      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      2.37G      1.209     0.5931      1.088         37        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.801      0.822      0.847      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      2.37G      1.233     0.6043      1.094         40        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.816      0.801      0.848       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      2.37G      1.161      0.577      1.072         29        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.798      0.823      0.846      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      2.37G      1.182     0.5859      1.074         38        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.2it/s 0.5s
#                    all         80        186      0.843       0.81      0.871      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      2.37G      1.141     0.5596      1.065         38        640: 100% ━━━━━━━━━━━━ 18/18 3.3it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.812      0.817      0.852      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.37G      1.171     0.5733      1.085         37        640: 100% ━━━━━━━━━━━━ 18/18 2.9it/s 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.811      0.879       0.89      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.37G      1.136     0.5653       1.06         33        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186       0.85      0.794      0.877      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      2.37G      1.129      0.546      1.055         46        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        186      0.817      0.816      0.868      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      2.37G      1.129     0.5537      1.055         42        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186       0.86      0.792      0.862      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      2.37G      1.135     0.5664      1.059         35        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.793      0.823      0.858      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      2.37G      1.105     0.5391      1.043         34        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.799      0.852      0.871       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.37G      1.141     0.5679      1.047         38        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.7it/s 0.6s
#                    all         80        186      0.797      0.842      0.871      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      2.37G      1.077     0.5246      1.036         37        640: 100% ━━━━━━━━━━━━ 18/18 3.3it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.807      0.806      0.859      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.37G      1.104      0.549      1.039         40        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.807      0.812      0.862      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      2.37G      1.092     0.5379      1.034         36        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.837      0.796      0.859      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      2.37G      1.059     0.5242      1.024         39        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.1it/s 0.5s
#                    all         80        186      0.859      0.796      0.859      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      2.37G      1.054     0.5225      1.027         44        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.826      0.796      0.854      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.37G      1.064     0.5078      1.008         44        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.5it/s 0.4s
#                    all         80        186      0.837      0.798      0.849      0.398
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.37G      1.047     0.5136      1.004         20        640: 100% ━━━━━━━━━━━━ 18/18 2.9it/s 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         80        186      0.811      0.828      0.856        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.37G      1.044     0.5194      1.017         17        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6it/s 0.5s
#                    all         80        186       0.81      0.828      0.854      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.37G      1.028     0.5027      1.004         17        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.5it/s 0.5s
#                    all         80        186      0.823      0.833      0.869      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.37G      1.045     0.5061      1.006         19        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.877      0.763      0.855      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.37G      1.027     0.4985      1.005         20        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.832      0.801       0.86      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.37G       1.03      0.508      1.005         23        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.798      0.848      0.865      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.37G     0.9949     0.4876     0.9929         18        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.4it/s 0.4s
#                    all         80        186      0.839      0.769      0.854      0.411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.37G      1.001     0.4973     0.9954         23        640: 100% ━━━━━━━━━━━━ 18/18 3.0it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.4it/s 0.4s
#                    all         80        186      0.827      0.823      0.867       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.37G     0.9937      0.486     0.9844         17        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.4it/s 0.4s
#                    all         80        186       0.81      0.848      0.872      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.37G     0.9775     0.4905     0.9922         20        640: 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.804      0.844      0.873       0.42
#
# 100 epochs completed in 0.193 hours.
# Optimizer stripped from /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed101/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed101/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed101/weights/best.pt...
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.4it/s 1.2s
#                    all         80        186       0.85      0.794      0.876      0.419
# Speed: 0.5ms preprocess, 4.7ms inference, 0.0ms loss, 2.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/exp_a4b_rgbd_synth_v2_seed101
#
# ✓ Seed 101 completed!
#   Time: 11.7 minutes
#
# ============================================================
# TRAINING LOOP COMPLETED
# ============================================================
#
# 📊 RESULTS SUMMARY:
# Successful: 5/5
#   Seed 42: ✓ Completed
#   Seed 123: ✓ Completed
#   Seed 456: ✓ Completed
#   Seed 789: ✓ Completed
#   Seed 101: ✓ Completed

# %%
# =============================================================================
# Cell 8: Evaluation (FIXED)
# =============================================================================

def evaluate_rgbd_model(model_path, data_yaml, split="test", device=0):
    """Evaluasi model RGBD 4-channel dengan custom validator."""
    from ultralytics.cfg import get_cfg
    from ultralytics.data.utils import check_det_dataset
    
    # Load model
    model = YOLO(str(model_path))
    
    # Convert to 4ch if needed
    first_conv = model.model.model[0].conv
    if first_conv.in_channels == 3:
        model.model.model[0].conv = convert_conv_to_4ch(first_conv)
    
    # Setup validator
    args = get_cfg(overrides={
        'data': str(data_yaml),
        'split': split,
        'device': device,
        'batch': 16,
        'imgsz': 640,
    })
    args.task = 'detect'
    
    data_dict = check_det_dataset(args.data)
    
    validator = RGBD4ChValidator(args=args, _callbacks=None)
    validator.data = data_dict
    validator.stride = 32
    
    # Evaluate
    results = validator(model=model.model)
    
    del model
    torch.cuda.empty_cache()
    
    return validator.metrics  # <-- Ambil dari validator.metrics, bukan return value


# Run evaluation
results_dict = {}

print("\n" + "="*60)
print("EVALUATION ON TEST SET")
print("="*60)

for seed in SEEDS:
    model_path = RUNS_PATH / f"{EXP_PREFIX}_seed{seed}" / "weights" / "best.pt"
    
    if not model_path.exists():
        print(f"Model not found: {model_path}")
        continue
    
    print(f"\nSeed {seed}:")
    
    try:
        metrics = evaluate_rgbd_model(model_path, config_path, split="test", device=DEVICE)
        
        # Akses metrics dengan benar
        results_dict[seed] = {
            'mAP50': metrics.box.map50,
            'mAP50-95': metrics.box.map,
            'Precision': metrics.box.mp,
            'Recall': metrics.box.mr,
        }
        
        print(f"  mAP50: {metrics.box.map50:.4f}, mAP50-95: {metrics.box.map:.4f}")
        
    except Exception as e:
        import traceback
        print(f"  Evaluation failed: {e}")
        traceback.print_exc()

print("\n" + "="*60)
print("EVALUATION COMPLETED")
print("="*60)
# Out:
# ============================================================
# EVALUATION ON TEST SET
# ============================================================
#
# Seed 42:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3967.0±1080.0 MB/s, size: 2286.6 KB)
# val: Scanning /kaggle/working/rgbd_synthetic_4ch/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 81.2it/s 0.5s
# val: New cache created: /kaggle/working/rgbd_synthetic_4ch/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.6it/s 1.9s
#                    all         40        105      0.749      0.767      0.821      0.364
# Speed: 4.3ms preprocess, 15.2ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/train
#   mAP50: 0.8210, mAP50-95: 0.3636
#
# Seed 123:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4222.9±1840.4 MB/s, size: 2318.6 KB)
# val: Scanning /kaggle/working/rgbd_synthetic_4ch/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 14.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.7s
#                    all         40        105      0.802      0.714      0.815       0.37
# Speed: 4.4ms preprocess, 3.4ms inference, 0.2ms loss, 5.9ms postprocess per image
# Results saved to /kaggle/working/runs/detect/train2
#   mAP50: 0.8149, mAP50-95: 0.3704
#
# Seed 456:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5044.8±1653.9 MB/s, size: 2257.4 KB)
# val: Scanning /kaggle/working/rgbd_synthetic_4ch/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 14.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.6it/s 1.8s
#                    all         40        105      0.778      0.686       0.81      0.361
# Speed: 4.2ms preprocess, 7.1ms inference, 0.0ms loss, 7.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/train3
#   mAP50: 0.8103, mAP50-95: 0.3614
#
# Seed 789:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4320.1±1394.8 MB/s, size: 2379.1 KB)
# val: Scanning /kaggle/working/rgbd_synthetic_4ch/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 16.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.6it/s 1.9s
#                    all         40        105      0.838       0.74      0.841      0.379
# Speed: 4.2ms preprocess, 8.7ms inference, 0.0ms loss, 4.3ms postprocess per image
# Results saved to /kaggle/working/runs/detect/train4
#   mAP50: 0.8410, mAP50-95: 0.3793
#
# Seed 101:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,491 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5454.1±1157.3 MB/s, size: 2375.8 KB)
# val: Scanning /kaggle/working/rgbd_synthetic_4ch/labels/test.cache... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 12.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.7s
#                    all         40        105      0.813      0.787      0.829      0.363
# Speed: 4.1ms preprocess, 9.3ms inference, 0.0ms loss, 5.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/train5
#   mAP50: 0.8293, mAP50-95: 0.3632
#
# ============================================================
# EVALUATION COMPLETED
# ============================================================

# %%
# =============================================================================
# Cell 9: Summary
# =============================================================================
import pandas as pd

if results_dict:
    df = pd.DataFrame(results_dict).T
    df.index.name = 'Seed'
    
    avg = df.mean()
    std = df.std()
    min_vals = df.min()
    max_vals = df.max()
    
    print("\n" + "="*60)
    print("A.4b RGB+SYNTHETIC DEPTH (4-CH) (V2) - FINAL RESULTS")
    print("="*60 + "\n")
    print(df.to_string(float_format=lambda x: f"{x:.4f}"))
    
    print("\n" + "-"*60)
    print("STATISTICAL SUMMARY")
    print("-"*60)
    print(f"{'Metric':<15} {'Mean':>10} {'Std':>10} {'Min':>10} {'Max':>10}")
    print("-"*60)
    for col in df.columns:
        print(f"{col:<15} {avg[col]:>10.4f} {std[col]:>10.4f} {min_vals[col]:>10.4f} {max_vals[col]:>10.4f}")
    
    best_seed = df['mAP50'].idxmax()
    print(f"\n✓ Best Seed: {best_seed} (mAP50: {df.loc[best_seed, 'mAP50']:.4f})")
    
    print("="*60)
else:
    print("No results to display.")
# Out:
# ============================================================
# A.4b RGB+SYNTHETIC DEPTH (4-CH) (V2) - FINAL RESULTS
# ============================================================
#
#       mAP50  mAP50-95  Precision  Recall
# Seed
# 42   0.8210    0.3636     0.7489  0.7669
# 123  0.8149    0.3704     0.8019  0.7143
# 456  0.8103    0.3614     0.7775  0.6857
# 789  0.8410    0.3793     0.8381  0.7397
# 101  0.8293    0.3632     0.8130  0.7868
#
# ------------------------------------------------------------
# STATISTICAL SUMMARY
# ------------------------------------------------------------
# Metric                Mean        Std        Min        Max
# ------------------------------------------------------------
# mAP50               0.8233     0.0122     0.8103     0.8410
# mAP50-95            0.3676     0.0074     0.3614     0.3793
# Precision           0.7959     0.0341     0.7489     0.8381
# Recall              0.7387     0.0403     0.6857     0.7868
#
# ✓ Best Seed: 789 (mAP50: 0.8410)
# ============================================================

# %%
# =============================================================================
# Cell 10: Save results
# =============================================================================
output_file = KAGGLE_OUTPUT / 'a4b_rgbd_synthetic_v2_results.txt'

with open(output_file, 'w') as f:
    f.write("="*60 + "\n")
    f.write("A.4b RGB+Synthetic Depth (4-CH) (V2) Results\n")
    f.write(f"Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write(f"Environment: {'Kaggle' if IS_KAGGLE else 'Local'}\n")
    f.write("="*60 + "\n\n")
    
    f.write("Configuration:\n")
    f.write(f"  Model: YOLOv11n\n")
    f.write(f"  Input: 4-Channel (RGB+Synthetic Depth)\n")
    f.write(f"  Depth Source: Depth-Anything-V2\n")
    f.write(f"  Epochs: {EPOCHS} (patience: {PATIENCE})\n")
    f.write(f"  Image Size: {IMGSZ}\n")
    f.write(f"  Batch Size: {BATCH_SIZE}\n")
    f.write(f"  Seeds: {SEEDS}\n")
    f.write("\nUniform Augmentation:\n")
    for key, value in AUGMENT_PARAMS.items():
        f.write(f"  {key}: {value}\n")
    f.write("\nSpecial Features:\n")
    f.write("  - 4-Channel input (RGB+Synthetic Depth)\n")
    f.write("  - Custom RGBD4ChTrainer\n")
    f.write("  - Reset BatchNorm for domain adaptation\n")
    
    if results_dict:
        f.write("\n" + "="*60 + "\n")
        f.write("Per-Seed Results:\n")
        f.write("="*60 + "\n")
        f.write(df.to_string(float_format=lambda x: f"{x:.4f}"))
        
        f.write("\n\n" + "-"*60 + "\n")
        f.write("Summary (Mean ± Std):\n")
        f.write("-"*60 + "\n")
        for col in df.columns:
            f.write(f"  {col}: {avg[col]:.4f} ± {std[col]:.4f}\n")
        
        f.write(f"\nBest Seed: {best_seed}\n")

print(f"\n✓ Results saved: {output_file}")

# JSON output
json_output = {
    'experiment': 'A.4b',
    'variant': 'V2',
    'seeds': SEEDS,
    'config': {
        'model': 'yolo11n',
        'input_channels': 4,
        'depth_source': 'synthetic',
        'epochs': EPOCHS,
        'patience': PATIENCE,
        'imgsz': IMGSZ,
        'batch': BATCH_SIZE,
        'augmentation': AUGMENT_PARAMS,
        'reset_bn': True,
    },
    'results': {str(k): v for k, v in results_dict.items()},
    'summary': {
        'mean': {k: float(v) for k, v in avg.items()},
        'std': {k: float(v) for k, v in std.items()},
        'best_seed': int(best_seed) if results_dict else None,
    } if results_dict else None,
}

json_file = KAGGLE_OUTPUT / 'a4b_rgbd_synthetic_v2_results.json'
with open(json_file, 'w') as f:
    json.dump(json_output, f, indent=2)

print(f"✓ JSON saved: {json_file}")
# Out:
# ✓ Results saved: /kaggle/working/kaggleoutput/a4b_rgbd_synthetic_v2_results.txt
# ✓ JSON saved: /kaggle/working/kaggleoutput/a4b_rgbd_synthetic_v2_results.json

# %%
# =============================================================================
# Cell 11: Create archives
# =============================================================================
print("\n" + "="*60)
print("CREATING ARCHIVES")
print("="*60 + "\n")

if RUNS_PATH.exists():
    runs_zip = BASE_PATH / 'a4b_rgbd_synthetic_v2_runs.zip'
    shutil.make_archive(str(runs_zip.with_suffix('')), 'zip', RUNS_PATH)
    size_mb = runs_zip.stat().st_size / 1024 / 1024
    print(f"✓ a4b_rgbd_synthetic_v2_runs.zip: {size_mb:.1f} MB")

output_zip = BASE_PATH / 'a4b_rgbd_synthetic_v2_output.zip'
shutil.make_archive(str(output_zip.with_suffix('')), 'zip', KAGGLE_OUTPUT)
size_mb = output_zip.stat().st_size / 1024 / 1024
print(f"✓ a4b_rgbd_synthetic_v2_output.zip: {size_mb:.1f} MB")

print("\n" + "="*60)
print("ALL DONE!")
print("="*60)
print("\nDownload from Output tab:")
print("  - a4b_rgbd_synthetic_v2_runs.zip (training runs)")
print("  - a4b_rgbd_synthetic_v2_output.zip (results)")
# Out:
# ============================================================
# CREATING ARCHIVES
# ============================================================
#
# ✓ a4b_rgbd_synthetic_v2_runs.zip: 99.9 MB
# ✓ a4b_rgbd_synthetic_v2_output.zip: 0.0 MB
#
# ============================================================
# ALL DONE!
# ============================================================
#
# Download from Output tab:
#   - a4b_rgbd_synthetic_v2_runs.zip (training runs)
#   - a4b_rgbd_synthetic_v2_output.zip (results)
