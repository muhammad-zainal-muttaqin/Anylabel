# %% [markdown]
# # A.4a Synthetic Depth Only with Reset BN
#
# **Experiment:** A.4a - Synthetic Depth
# **Input:** Synthetic depth maps (3-channel, generated by Depth-Anything-V2)
# **Objective:** Test if synthetic depth can replace real depth sensor
# **Classes:** 1 (fresh_fruit_bunch)
#
# ## Workflow
# 1. Environment setup with auto-detection (Kaggle vs Local)
# 2. Install dependencies
# 3. Dataset preparation and verification
# 4. Training with 5 seeds (42, 123, 456, 789, 101)
# 5. Reset BatchNorm statistics for synthetic depth domain adaptation
# 6. Evaluation on test set
# 7. Results summary with mean ± std deviation
#
# ## Prerequisites
# - Run `generate_synthetic_depth.ipynb` first
# - Upload output as Kaggle dataset: `ffb-synthetic-depth`
#
# ## Uniform Augmentation (All Experiments)
# - translate: 0.1
# - scale: 0.5
# - fliplr: 0.5
# - hsv_h: 0.0 (disabled for uniformity)
# - hsv_s: 0.0 (disabled for uniformity)
# - hsv_v: 0.0 (disabled for uniformity)
# - erasing: 0.0
# - mosaic: 0.0
# - mixup: 0.0

# %%
# =============================================================================
# Cell 1: Environment Setup & Auto-Detection
# =============================================================================
import os
import sys
import torch
import torch.nn as nn
import numpy as np
import shutil
import gc
import time
from pathlib import Path
from datetime import datetime

# Auto-detect Kaggle vs Local environment
IS_KAGGLE = os.path.exists('/kaggle/input') or os.path.exists('/kaggle')

if IS_KAGGLE:
    BASE_PATH = Path('/kaggle/working')
    DATASET_PATH = Path('/kaggle/input/ffb-synthetic-depth')
else:
    BASE_PATH = Path('D:/Work/Assisten Dosen/Anylabel/Experiments')
    DATASET_PATH = BASE_PATH / 'datasets' / 'ffb_localization_depth_synthetic'

RUNS_PATH = BASE_PATH / 'runs' / 'detect'
KAGGLE_OUTPUT = BASE_PATH / 'kaggleoutput'
KAGGLE_OUTPUT.mkdir(parents=True, exist_ok=True)

print("="*60)
print("A.4a SYNTHETIC DEPTH ONLY - ENVIRONMENT SETUP")
print("="*60)
print(f"Running on: {'Kaggle' if IS_KAGGLE else 'Local'}")
print(f"Base Path: {BASE_PATH}")
print(f"Dataset Path: {DATASET_PATH}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"CUDA Version: {torch.version.cuda}")
    torch.cuda.empty_cache()

print(f"Python: {sys.version.split()[0]}")
print(f"PyTorch: {torch.__version__}")
print("="*60)
# Out:
# ============================================================
# A.4a SYNTHETIC DEPTH ONLY - ENVIRONMENT SETUP
# ============================================================
# Running on: Kaggle
# Base Path: /kaggle/working
# Dataset Path: /kaggle/input/ffb-synthetic-depth
# CUDA Available: True
# GPU: Tesla T4
# CUDA Version: 12.6
# Python: 3.12.12
# PyTorch: 2.8.0+cu126
# ============================================================

# %%
# =============================================================================
# Cell 2: Install and Imports
# =============================================================================
# !pip install -q ultralytics

# Import after installation
from ultralytics import YOLO
from ultralytics.data import build_dataloader
import pandas as pd
import json

print("\n✓ Ultralytics installed successfully")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.7 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# ✓ Ultralytics installed successfully

# %%
# =============================================================================
# Cell 3: Configuration with AUGMENT_PARAMS
# =============================================================================
# Uniform augmentation parameters (consistent across all experiments)
AUGMENT_PARAMS = {
    'translate': 0.1,
    'scale': 0.5,
    'fliplr': 0.5,
    'hsv_h': 0.0,  # Disabled for uniformity
    'hsv_s': 0.0,  # Disabled for uniformity
    'hsv_v': 0.0,  # Disabled for uniformity
    'erasing': 0.0,
    'mosaic': 0.0,
    'mixup': 0.0,
    'degrees': 0.0,
    'copy_paste': 0.0,
}

# Training configuration
SEEDS = [42, 123, 456, 789, 101]
EXP_PREFIX = 'exp_a4a_synthetic_v2'
EPOCHS = 100
PATIENCE = 30
IMGSZ = 640
BATCH_SIZE = 16
DEVICE = 0 if torch.cuda.is_available() else 'cpu'

print("="*60)
print("TRAINING CONFIGURATION")
print("="*60)
print(f"Experiment: A.4a Synthetic Depth Only (V2)")
print(f"Model: YOLOv11n")
print(f"Seeds: {SEEDS} ({len(SEEDS)} runs)")
print(f"Epochs: {EPOCHS} (patience: {PATIENCE})")
print(f"Image Size: {IMGSZ}")
print(f"Batch Size: {BATCH_SIZE}")
print(f"Device: {DEVICE}")
print("\nUniform Augmentation:")
for key, value in AUGMENT_PARAMS.items():
    print(f"  {key}: {value}")
print("\nSpecial: Reset BatchNorm for synthetic depth domain adaptation")
print("="*60)
# Out:
# ============================================================
# TRAINING CONFIGURATION
# ============================================================
# Experiment: A.4a Synthetic Depth Only (V2)
# Model: YOLOv11n
# Seeds: [42, 123, 456, 789, 101] (5 runs)
# Epochs: 100 (patience: 30)
# Image Size: 640
# Batch Size: 16
# Device: 0
#
# Uniform Augmentation:
#   translate: 0.1
#   scale: 0.5
#   fliplr: 0.5
#   hsv_h: 0.0
#   hsv_s: 0.0
#   hsv_v: 0.0
#   erasing: 0.0
#   mosaic: 0.0
#   mixup: 0.0
#   degrees: 0.0
#   copy_paste: 0.0
#
# Special: Reset BatchNorm for synthetic depth domain adaptation
# ============================================================

# %%
# =============================================================================
# Cell 4: Reset BN Helper Function (same as A.2)
# =============================================================================
def reset_bn_stats(model, train_loader, num_batches=100, device='cuda'):
    """
    Reset running stats BatchNorm dengan 100 batch training data.
    Dipanggil setelah load pretrained weights untuk domain adaptation.
    """
    model.train()
    
    # Reset running stats
    for module in model.modules():
        if isinstance(module, nn.BatchNorm2d):
            module.reset_running_stats()
            module.momentum = 0.1  # Higher momentum for faster adaptation
    
    # Forward pass untuk update running stats
    with torch.no_grad():
        for i, batch in enumerate(train_loader):
            if i >= num_batches:
                break
            imgs = batch['img'].to(device) if isinstance(batch, dict) else batch[0].to(device)
            _ = model(imgs)
    
    return model

print("✓ reset_bn_stats function defined")
# Out:
# ✓ reset_bn_stats function defined

# %%
# =============================================================================
# Cell 5: Dataset Verification and YAML
# =============================================================================
# Verify dataset structure
print("="*60)
print("DATASET VERIFICATION")
print("="*60)

for split in ['train', 'val', 'test']:
    img_dir = DATASET_PATH / 'images' / split
    lbl_dir = DATASET_PATH / 'labels' / split
    
    if img_dir.exists():
        imgs = len(list(img_dir.glob('*.png')))
    else:
        imgs = 0
        
    if lbl_dir.exists():
        lbls = len(list(lbl_dir.glob('*.txt')))
    else:
        lbls = 0
    
    status = "✓" if imgs > 0 and lbls > 0 else "✗"
    print(f"{status} {split:6}: {imgs:4} images, {lbls:4} labels")

# Create YAML config
yaml_content = f"""
# A.4a Synthetic Depth Only Dataset Configuration
path: {DATASET_PATH}
train: images/train
val: images/val
test: images/test

nc: 1
names: ['fresh_fruit_bunch']
"""

config_path = BASE_PATH / 'dataset_synthetic_v2.yaml'
with open(config_path, 'w') as f:
    f.write(yaml_content)

print(f"\n✓ YAML config created: {config_path}")
print("\nConfig contents:")
print("-"*40)
print(yaml_content)
# Out:
# ============================================================
# DATASET VERIFICATION
# ============================================================
# ✓ train :  280 images,  280 labels
# ✓ val   :   80 images,   80 labels
# ✓ test  :   40 images,   40 labels
#
# ✓ YAML config created: /kaggle/working/dataset_synthetic_v2.yaml
#
# Config contents:
# ----------------------------------------
#
# # A.4a Synthetic Depth Only Dataset Configuration
# path: /kaggle/input/ffb-synthetic-depth
# train: images/train
# val: images/val
# test: images/test
#
# nc: 1
# names: ['fresh_fruit_bunch']

# %%
# =============================================================================
# Cell 6: Training Loop with Reset BN using 100 REAL Training Images
# =============================================================================
import yaml
from PIL import Image
from torchvision import transforms

results_all = {}
training_times = {}

print("\n" + "="*60)
print("STARTING TRAINING LOOP")
print("="*60)

for idx, seed in enumerate(SEEDS, 1):
    start_time = time.time()
    
    print(f"\n{'='*60}")
    print(f"TRAINING A.4a SYNTHETIC DEPTH - Seed {seed} ({idx}/{len(SEEDS)})")
    print(f"{'='*60}")
    
    # Set seeds for reproducibility
    torch.manual_seed(seed)
    np.random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    
    try:
        # Load model
        model = YOLO('yolo11n.pt')
        
        # ============================================================
        # Reset BN stats using 100 REAL training images
        # ============================================================
        print("Resetting BatchNorm statistics with 100 real training images...")
        
        # Pindahkan model ke GPU
        model.model.to(DEVICE)
        model.model.train()
        
        # Reset running stats for all BN layers
        for module in model.model.modules():
            if isinstance(module, nn.BatchNorm2d):
                module.reset_running_stats()
                module.momentum = 0.1
        
        # Load data config untuk dapat path training images
        with open(config_path) as f:
            data_dict = yaml.safe_load(f)
        
        # Get training image paths
        train_path = Path(data_dict['path']) / data_dict['train']
        train_images = sorted(list(train_path.glob('*.png')) + list(train_path.glob('*.jpg')))
        
        # Ambil 100 gambar (atau semua jika kurang dari 100)
        num_images = min(100, len(train_images))
        selected_images = train_images[:num_images]
        
        print(f"  Loading {num_images} real training images from {train_path}...")
        
        # Transform untuk preprocessing
        transform = transforms.Compose([
            transforms.Resize((IMGSZ, IMGSZ)),
            transforms.ToTensor(),
        ])
        
        # Forward pass dengan real images (batch size 16)
        batch_size = 16
        with torch.no_grad():
            for i in range(0, num_images, batch_size):
                batch_paths = selected_images[i:i+batch_size]
                batch_tensors = []
                
                for img_path in batch_paths:
                    img = Image.open(img_path).convert('RGB')
                    img_tensor = transform(img)
                    batch_tensors.append(img_tensor)
                
                if batch_tensors:
                    batch = torch.stack(batch_tensors).to(DEVICE)
                    _ = model.model(batch)
        
        print(f"  ✓ BN reset complete with {num_images} real images")
        
        # ============================================================
        # Training
        # ============================================================
        results = model.train(
            data=str(config_path),
            epochs=EPOCHS,
            patience=PATIENCE,
            seed=seed,
            name=f"{EXP_PREFIX}_seed{seed}",
            project=str(RUNS_PATH),
            exist_ok=True,
            imgsz=IMGSZ,
            batch=BATCH_SIZE,
            device=DEVICE,
            **AUGMENT_PARAMS,
        )
        
        elapsed = time.time() - start_time
        training_times[seed] = elapsed
        
        # Store results
        results_all[seed] = {
            'model_path': str(RUNS_PATH / f"{EXP_PREFIX}_seed{seed}" / "weights" / "best.pt"),
            'epochs_trained': EPOCHS,
            'mAP50_val': results.box.map50 if hasattr(results, 'box') else 0,
            'mAP50_95_val': results.box.map if hasattr(results, 'box') else 0,
        }
        
        print(f"\n✓ Seed {seed} completed!")
        print(f"  Epochs: {EPOCHS}")
        print(f"  Val mAP50: {results_all[seed]['mAP50_val']:.4f}")
        print(f"  Val mAP50-95: {results_all[seed]['mAP50_95_val']:.4f}")
        print(f"  Time: {elapsed/60:.1f} minutes")
        
    except Exception as e:
        print(f"\n✗ Seed {seed} failed: {e}")
        import traceback
        traceback.print_exc()
        results_all[seed] = {'error': str(e)}
    
    # Memory cleanup
    del model
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

print("\n" + "="*60)
print("TRAINING LOOP COMPLETED")
print("="*60)

# Print summary
print("\n📊 RESULTS SUMMARY:")
for seed, res in results_all.items():
    if 'error' not in res:
        print(f"  Seed {seed}: mAP50={res['mAP50_val']:.4f}, mAP50-95={res['mAP50_95_val']:.4f}")
    else:
        print(f"  Seed {seed}: FAILED - {res['error'][:50]}...")
# Out:
# ============================================================
# STARTING TRAINING LOOP
# ============================================================
#
# ============================================================
# TRAINING A.4a SYNTHETIC DEPTH - Seed 42 (1/5)
# ============================================================
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 63.2MB/s 0.1s
# Resetting BatchNorm statistics with 100 real training images...
#   Loading 100 real training images from /kaggle/input/ffb-synthetic-depth/images/train...
#   ✓ BN reset complete with 100 real images
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/dataset_synthetic_v2.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.0, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=exp_a4a_synthetic_v2_seed42, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed42, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 58.9MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 323.3±386.7 MB/s, size: 1196.8 KB)
# train: Scanning /kaggle/input/ffb-synthetic-depth/labels/train... 280 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 280/280 110.8it/s 2.5s
# WARNING ⚠️ train: Cache directory /kaggle/input/ffb-synthetic-depth/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.7±1.5 ms, read: 50.4±34.4 MB/s, size: 1221.9 KB)
# val: Scanning /kaggle/input/ffb-synthetic-depth/labels/val... 80 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 96.8it/s 0.8s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-synthetic-depth/labels is not writable, cache not saved.
# Plotting labels to /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed42/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed42
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.22G      2.655      4.725      2.472         16        640: 100% ━━━━━━━━━━━━ 18/18 1.2s/it 21.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1s/it 6.4s
#                    all         80        186    0.00025     0.0323   0.000129   2.14e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.23G      2.152      3.197      1.907         25        640: 100% ━━━━━━━━━━━━ 18/18 6.1it/s 3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186   0.000333      0.043   0.000174   3.03e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.25G      2.088      2.617      1.848         18        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.27G      1.996      2.482      1.803         17        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.28G      2.019      2.291      1.825         20        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100       2.3G      1.976      2.144      1.853         17        640: 100% ━━━━━━━━━━━━ 18/18 4.6it/s 3.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186    0.00342      0.441    0.00262   0.000582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.32G      1.946      2.104      1.795         17        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186    0.00487      0.629    0.00816     0.0024
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.33G      1.921      2.009      1.697         20        640: 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186    0.00629      0.812      0.156     0.0537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.34G      1.973      1.928      1.761         20        640: 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.719     0.0269      0.313      0.122
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.36G      1.886      1.804      1.699         17        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.751      0.113      0.185     0.0698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.37G      1.858      1.732      1.717         24        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.709      0.532      0.568      0.252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.39G      1.882      1.656      1.805         21        640: 100% ━━━━━━━━━━━━ 18/18 5.6it/s 3.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186       0.69      0.575      0.626      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100       2.4G      1.902      1.625      1.795         19        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.667        0.5      0.583      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.42G      1.858      1.639      1.779         21        640: 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186      0.647     0.0914      0.259     0.0968
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.44G      1.875      1.595       1.72         17        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.623       0.43      0.491      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.45G      1.864      1.625      1.703         16        640: 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.499      0.457      0.453      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.46G       1.83      1.543      1.668         20        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.505      0.444      0.397      0.146
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.48G      1.829      1.501      1.706         17        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.643       0.57      0.619      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.49G      1.841      1.483      1.703         15        640: 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4it/s 0.5s
#                    all         80        186      0.608      0.608      0.605       0.24
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.51G      1.822      1.441      1.701         20        640: 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186       0.65      0.634      0.664      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.52G      1.795      1.437      1.678         22        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.768      0.588      0.687      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.54G      1.763      1.364      1.677         18        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9it/s 0.5s
#                    all         80        186      0.688      0.591      0.613      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.55G      1.805      1.394      1.683         20        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.664      0.691       0.71      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.57G        1.8      1.343      1.695         19        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.671      0.692      0.716      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.58G      1.826      1.363      1.702         14        640: 100% ━━━━━━━━━━━━ 18/18 5.6it/s 3.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.541      0.554      0.563      0.237
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.59G      1.801       1.36      1.677         17        640: 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.4it/s 0.4s
#                    all         80        186      0.686      0.613      0.672      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.61G       1.76      1.332      1.688         17        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.5it/s 0.4s
#                    all         80        186      0.667      0.608      0.666       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.62G      1.772      1.338      1.658         20        640: 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.664      0.586      0.653      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.64G      1.758      1.271      1.644         18        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.616      0.613      0.608      0.244
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.66G      1.808      1.288      1.665         20        640: 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.4it/s 0.4s
#                    all         80        186      0.728       0.64      0.716      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.67G      1.762      1.231      1.638         23        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.738      0.618      0.696      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.69G      1.718      1.215       1.63         16        640: 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.698      0.621      0.652      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100       2.7G      1.745      1.196      1.649         20        640: 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.6it/s 0.4s
#                    all         80        186      0.702      0.581      0.644      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.71G      1.701      1.195      1.596         19        640: 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.672      0.565      0.638      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.73G      1.719      1.203      1.636         17        640: 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186      0.684      0.532      0.638       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.74G      1.684      1.172      1.589         21        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186       0.54      0.559       0.56      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.76G      1.736      1.174      1.635         20        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.3it/s 0.5s
#                    all         80        186      0.661      0.554      0.602      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.77G      1.719       1.16      1.639         19        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186        0.7      0.672      0.694       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.79G      1.701      1.169      1.587         19        640: 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.5it/s 0.4s
#                    all         80        186      0.638      0.591      0.613      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100       2.8G       1.71      1.166      1.598         23        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186       0.68      0.613      0.672       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      2.82G      1.671       1.12      1.582         16        640: 100% ━━━━━━━━━━━━ 18/18 5.6it/s 3.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.693      0.657       0.69      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.83G      1.689      1.093      1.581         19        640: 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.664      0.595      0.639      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.85G      1.708      1.141      1.612         20        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.676      0.554      0.615      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      2.86G      1.677      1.122      1.606         21        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.7it/s 0.4s
#                    all         80        186        0.7      0.683      0.726      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.88G      1.592      1.027      1.542         21        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.707      0.672      0.736       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.89G      1.638       1.01      1.584         24        640: 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.739      0.629      0.705      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100       2.9G      1.605      1.014      1.573         25        640: 100% ━━━━━━━━━━━━ 18/18 5.7it/s 3.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186        0.7      0.645      0.713      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      2.92G      1.579       1.03      1.543         22        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.8it/s 0.4s
#                    all         80        186      0.805      0.586      0.708      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      2.93G      1.602      1.035      1.523         22        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.709      0.608      0.679      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      2.95G      1.618      1.016      1.572         22        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.701      0.669      0.715      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      2.96G      1.589      1.019      1.515         19        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.721      0.667      0.729      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      2.98G      1.553      1.006      1.523         16        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.689      0.677      0.686      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      2.99G      1.568     0.9921      1.501         18        640: 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.737      0.661      0.735      0.314
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 23, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 53 epochs completed in 0.072 hours.
# Optimizer stripped from /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed42/weights/last.pt, 5.4MB
# Optimizer stripped from /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed42/weights/best.pt, 5.4MB
#
# Validating /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed42/weights/best.pt...
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.6it/s 1.2s
#                    all         80        186      0.658      0.663      0.704      0.334
# Speed: 0.1ms preprocess, 1.9ms inference, 0.0ms loss, 2.9ms postprocess per image
# Results saved to /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed42
#
# ✓ Seed 42 completed!
#   Epochs: 100
#   Val mAP50: 0.7042
#   Val mAP50-95: 0.3336
#   Time: 5.0 minutes
#
# ============================================================
# TRAINING A.4a SYNTHETIC DEPTH - Seed 123 (2/5)
# ============================================================
# Resetting BatchNorm statistics with 100 real training images...
#   Loading 100 real training images from /kaggle/input/ffb-synthetic-depth/images/train...
#   ✓ BN reset complete with 100 real images
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/dataset_synthetic_v2.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.0, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=exp_a4a_synthetic_v2_seed123, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed123, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=123, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 739.2±268.7 MB/s, size: 1178.9 KB)
# train: Scanning /kaggle/input/ffb-synthetic-depth/labels/train... 280 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 280/280 262.7it/s 1.1s
# WARNING ⚠️ train: Cache directory /kaggle/input/ffb-synthetic-depth/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 697.8±248.6 MB/s, size: 1209.8 KB)
# val: Scanning /kaggle/input/ffb-synthetic-depth/labels/val... 80 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 252.0it/s 0.3s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-synthetic-depth/labels is not writable, cache not saved.
# Plotting labels to /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed123/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed123
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.24G      2.673       4.64      2.451         16        640: 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186   0.000333      0.043   0.000174   3.88e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.25G      2.202       3.26      1.714         25        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.27G      2.133      2.729      1.763         18        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186   0.000542     0.0699   0.000336   8.52e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.29G      2.017      2.484      1.726         17        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186    0.00133      0.172    0.00106    0.00024
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100       2.3G      2.023      2.312      1.683         20        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186    0.00133      0.172    0.00116   0.000248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.32G      2.079      2.286      1.684         17        640: 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186    0.00171       0.22    0.00243   0.000414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.34G      2.022       2.24      1.666         17        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186     0.0025      0.323    0.00965    0.00137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.35G       1.99      2.133      1.699         20        640: 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186    0.00492      0.634     0.0204    0.00936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.36G      2.012      1.998      1.712         20        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.941     0.0862      0.339      0.117
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.38G      1.932      1.837      1.616         17        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.645       0.43       0.49      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.39G      1.878      1.745       1.63         24        640: 100% ━━━━━━━━━━━━ 18/18 5.6it/s 3.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.699        0.5      0.565      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.41G      1.917      1.724      1.697         21        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186       0.85      0.247      0.462      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.42G      1.884      1.662      1.615         19        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.623      0.498      0.568      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.44G      1.858      1.611       1.63         21        640: 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186      0.578      0.548      0.587      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.46G      1.895      1.579      1.629         17        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.571      0.486      0.486      0.204
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.47G      1.919       1.55      1.625         16        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.693      0.522      0.569      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.48G      1.837      1.454      1.561         20        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.728       0.57      0.654      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100       2.5G       1.84      1.434      1.577         17        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.705      0.624       0.65      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.51G      1.869      1.419      1.585         15        640: 100% ━━━━━━━━━━━━ 18/18 5.7it/s 3.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.5it/s 0.5s
#                    all         80        186      0.679      0.547      0.608      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.53G      1.882       1.42      1.586         20        640: 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.522      0.457      0.481      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.54G      1.791      1.387      1.516         22        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.608      0.489       0.53      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.56G      1.839      1.371      1.555         18        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.668      0.505      0.584       0.24
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.57G      1.808      1.365      1.549         20        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.706      0.607      0.671      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.59G      1.785      1.307      1.548         19        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.4it/s 0.4s
#                    all         80        186      0.623      0.612      0.639      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100       2.6G      1.815      1.371      1.567         14        640: 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.665      0.624      0.695      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.61G      1.797      1.332      1.515         17        640: 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186       0.62      0.559      0.564      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.63G      1.781      1.352      1.521         17        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.631      0.548      0.602      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.83G      1.731      1.183      1.499         21        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186      0.683      0.618      0.668      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.85G      1.723      1.154      1.497         20        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.657        0.7      0.709      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.86G      1.732      1.189      1.502         19        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.735       0.64      0.705      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.88G      1.705      1.138      1.467         19        640: 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.577      0.601      0.591      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      2.89G       1.67      1.117      1.417         23        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.709      0.735      0.761      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100       2.9G      1.639      1.093      1.429         16        640: 100% ━━━━━━━━━━━━ 18/18 5.6it/s 3.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.741      0.634      0.735      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.92G      1.665      1.041       1.43         19        640: 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.719      0.581      0.647        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.93G      1.688      1.088      1.423         20        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186        0.7      0.613      0.675      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      2.95G      1.646      1.064      1.424         21        640: 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.5it/s 0.4s
#                    all         80        186      0.637      0.602      0.599      0.242
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.96G      1.607      1.029      1.394         21        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.699      0.667      0.688      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.98G      1.614      1.021      1.414         24        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.6it/s 0.5s
#                    all         80        186      0.648      0.672      0.654      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      2.99G      1.592     0.9953      1.393         25        640: 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.705      0.742      0.753      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      3.01G      1.583     0.9799      1.392         22        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.697      0.651      0.701      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      3.02G      1.577      1.014      1.379         22        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.597      0.645      0.647      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      3.04G      1.578      1.016      1.383         22        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.629      0.721      0.707      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      3.05G      1.549     0.9663      1.354         19        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.745      0.672       0.71      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.07G      1.543      0.947       1.35         16        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.729      0.704      0.729      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      3.08G      1.562      0.935      1.354         18        640: 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.723      0.715       0.74      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100       3.1G      1.566     0.9566      1.377         16        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.4it/s 0.4s
#                    all         80        186      0.729      0.704      0.759      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      3.11G       1.59     0.9701      1.359         27        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186      0.785      0.651      0.741      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      3.13G      1.528     0.9389      1.346         16        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.647      0.704      0.725      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      3.14G      1.553     0.9371      1.359         17        640: 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.704      0.656      0.713      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      3.16G      1.537     0.9153      1.333         17        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.709      0.699      0.735      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      3.17G      1.491     0.8947      1.315         20        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.5it/s 0.4s
#                    all         80        186       0.68      0.661      0.688      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      3.19G      1.476     0.8985      1.296         19        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.0it/s 0.4s
#                    all         80        186      0.593      0.624      0.605      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100       3.2G      1.496     0.9022      1.306         16        640: 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.7it/s 0.4s
#                    all         80        186      0.689      0.651       0.71      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      3.22G      1.473     0.9127      1.318         19        640: 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186      0.674      0.699      0.716      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      3.23G      1.466     0.8794      1.303         22        640: 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2it/s 0.4s
#                    all         80        186      0.693      0.704      0.721      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      3.24G       1.48      0.847      1.306         19        640: 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.707      0.618      0.682      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      3.26G       1.47     0.8661      1.317         16        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186      0.722      0.704      0.744      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      3.28G      1.451     0.8355      1.306         16        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.754      0.658      0.716       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      3.29G      1.419      0.839      1.284         21        640: 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.3it/s 0.4s
#                    all         80        186      0.775       0.64      0.725      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100       3.3G      1.396     0.8105      1.267         17        640: 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.9it/s 0.4s
#                    all         80        186      0.691      0.586       0.68      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      3.32G      1.443     0.8426      1.272         21        640: 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.1it/s 0.4s
#                    all         80        186      0.742      0.665      0.723      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      3.34G      1.413     0.7976      1.255         16        640: 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.8it/s 0.4s
#                    all         80        186       0.69      0.688      0.713      0.312
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 40, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 70 epochs completed in 0.087 hours.
# Optimizer stripped from /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed101/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed101/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed101/weights/best.pt...
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.6it/s 1.2s
#                    all         80        186      0.709      0.735      0.761      0.353
# Speed: 0.3ms preprocess, 2.6ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/exp_a4a_synthetic_v2_seed101
#
# ✓ Seed 101 completed!
#   Epochs: 100
#   Val mAP50: 0.7609
#   Val mAP50-95: 0.3532
#   Time: 5.4 minutes
#
# ============================================================
# TRAINING LOOP COMPLETED
# ============================================================
#
# 📊 RESULTS SUMMARY:
#   Seed 42: mAP50=0.7042, mAP50-95=0.3336
#   Seed 123: mAP50=0.7918, mAP50-95=0.3663
#   Seed 456: mAP50=0.7542, mAP50-95=0.3474
#   Seed 789: mAP50=0.7430, mAP50-95=0.3405
#   Seed 101: mAP50=0.7609, mAP50-95=0.3532

# %%
# =============================================================================
# Cell 7: Evaluation
# =============================================================================
results_dict = {}

print("\n" + "="*60)
print("EVALUATION ON TEST SET")
print("="*60)

for seed in SEEDS:
    model_path = RUNS_PATH / f"{EXP_PREFIX}_seed{seed}" / 'weights' / 'best.pt'
    
    if not model_path.exists():
        print(f"✗ Model not found: {model_path}")
        continue
    
    print(f"\nSeed {seed}:")
    
    try:
        model = YOLO(str(model_path))
        metrics = model.val(data=str(config_path), split='test', device=DEVICE)
        
        results_dict[seed] = {
            'mAP50': metrics.box.map50,
            'mAP50-95': metrics.box.map,
            'Precision': metrics.box.mp,
            'Recall': metrics.box.mr,
        }
        
        print(f"  mAP50:     {metrics.box.map50:.4f}")
        print(f"  mAP50-95:  {metrics.box.map:.4f}")
        print(f"  Precision: {metrics.box.mp:.4f}")
        print(f"  Recall:    {metrics.box.mr:.4f}")
        
        del model
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
            
    except Exception as e:
        print(f"  ✗ Evaluation failed: {e}")

print("\n" + "="*60)
print("EVALUATION COMPLETED")
print("="*60)
# Out:
# ============================================================
# EVALUATION ON TEST SET
# ============================================================
#
# Seed 42:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.7±1.0 ms, read: 32.1±18.3 MB/s, size: 1175.0 KB)
# val: Scanning /kaggle/input/ffb-synthetic-depth/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 79.6it/s 0.5s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-synthetic-depth/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.5s
#                    all         40        105      0.724      0.495      0.607      0.233
# Speed: 3.1ms preprocess, 10.2ms inference, 0.0ms loss, 4.9ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
#   mAP50:     0.6066
#   mAP50-95:  0.2333
#   Precision: 0.7244
#   Recall:    0.4952
#
# Seed 123:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 847.9±79.8 MB/s, size: 1166.4 KB)
# val: Scanning /kaggle/input/ffb-synthetic-depth/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 275.8it/s 0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-synthetic-depth/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         40        105      0.648      0.705      0.631      0.279
# Speed: 3.2ms preprocess, 3.2ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val2
#   mAP50:     0.6309
#   mAP50-95:  0.2789
#   Precision: 0.6483
#   Recall:    0.7048
#
# Seed 456:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 834.7±63.6 MB/s, size: 1177.7 KB)
# val: Scanning /kaggle/input/ffb-synthetic-depth/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 250.7it/s 0.2s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-synthetic-depth/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.4s
#                    all         40        105      0.741      0.619      0.671      0.276
# Speed: 3.1ms preprocess, 5.7ms inference, 0.0ms loss, 10.6ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val3
#   mAP50:     0.6707
#   mAP50-95:  0.2762
#   Precision: 0.7408
#   Recall:    0.6190
#
# Seed 789:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 886.8±56.3 MB/s, size: 1212.8 KB)
# val: Scanning /kaggle/input/ffb-synthetic-depth/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 270.5it/s 0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-synthetic-depth/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.4s
#                    all         40        105      0.729       0.59      0.658      0.298
# Speed: 2.9ms preprocess, 9.1ms inference, 0.0ms loss, 7.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val4
#   mAP50:     0.6577
#   mAP50-95:  0.2981
#   Precision: 0.7291
#   Recall:    0.5897
#
# Seed 101:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 940.1±75.5 MB/s, size: 1240.1 KB)
# val: Scanning /kaggle/input/ffb-synthetic-depth/labels/test... 40 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 40/40 263.4it/s 0.2s
# WARNING ⚠️ val: Cache directory /kaggle/input/ffb-synthetic-depth/labels is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         40        105      0.745      0.676      0.701      0.291
# Speed: 2.8ms preprocess, 3.2ms inference, 0.0ms loss, 6.3ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val5
#   mAP50:     0.7009
#   mAP50-95:  0.2906
#   Precision: 0.7452
#   Recall:    0.6762
#
# ============================================================
# EVALUATION COMPLETED
# ============================================================

# %%
# =============================================================================
# Cell 8: Summary
# =============================================================================
if results_dict:
    df = pd.DataFrame(results_dict).T
    df.index.name = 'Seed'
    
    # Calculate statistics
    avg = df.mean()
    std = df.std()
    min_vals = df.min()
    max_vals = df.max()
    
    print("\n" + "="*60)
    print("A.4a SYNTHETIC DEPTH ONLY (V2) - FINAL RESULTS")
    print("="*60 + "\n")
    print(df.to_string(float_format=lambda x: f"{x:.4f}"))
    
    print("\n" + "-"*60)
    print("STATISTICAL SUMMARY")
    print("-"*60)
    print(f"{'Metric':<15} {'Mean':>10} {'Std':>10} {'Min':>10} {'Max':>10}")
    print("-"*60)
    for col in df.columns:
        print(f"{col:<15} {avg[col]:>10.4f} {std[col]:>10.4f} {min_vals[col]:>10.4f} {max_vals[col]:>10.4f}")
    
    # Best seed
    best_seed = df['mAP50'].idxmax()
    print(f"\n✓ Best Seed: {best_seed} (mAP50: {df.loc[best_seed, 'mAP50']:.4f})")
    
    print("="*60)
else:
    print("No results to display.")
# Out:
# ============================================================
# A.4a SYNTHETIC DEPTH ONLY (V2) - FINAL RESULTS
# ============================================================
#
#       mAP50  mAP50-95  Precision  Recall
# Seed
# 42   0.6066    0.2333     0.7244  0.4952
# 123  0.6309    0.2789     0.6483  0.7048
# 456  0.6707    0.2762     0.7408  0.6190
# 789  0.6577    0.2981     0.7291  0.5897
# 101  0.7009    0.2906     0.7452  0.6762
#
# ------------------------------------------------------------
# STATISTICAL SUMMARY
# ------------------------------------------------------------
# Metric                Mean        Std        Min        Max
# ------------------------------------------------------------
# mAP50               0.6533     0.0363     0.6066     0.7009
# mAP50-95            0.2754     0.0252     0.2333     0.2981
# Precision           0.7176     0.0396     0.6483     0.7452
# Recall              0.6170     0.0818     0.4952     0.7048
#
# ✓ Best Seed: 101 (mAP50: 0.7009)
# ============================================================

# %%
# =============================================================================
# Cell 9: Save Results
# =============================================================================
output_file = KAGGLE_OUTPUT / 'a4a_synthetic_v2_results.txt'

with open(output_file, 'w') as f:
    f.write("="*60 + "\n")
    f.write("A.4a Synthetic Depth Only (V2) Results\n")
    f.write(f"Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write(f"Environment: {'Kaggle' if IS_KAGGLE else 'Local'}\n")
    f.write("="*60 + "\n\n")
    
    f.write("Configuration:\n")
    f.write("  Model: YOLOv11n\n")
    f.write("  Depth Source: Depth-Anything-V2 (Synthetic)\n")
    f.write(f"  Epochs: {EPOCHS} (patience: {PATIENCE})\n")
    f.write(f"  Image Size: {IMGSZ}\n")
    f.write(f"  Batch Size: {BATCH_SIZE}\n")
    f.write(f"  Seeds: {SEEDS}\n")
    f.write("\nUniform Augmentation:\n")
    for key, value in AUGMENT_PARAMS.items():
        f.write(f"  {key}: {value}\n")
    f.write("\nSpecial Features:\n")
    f.write("  - Reset BatchNorm statistics for synthetic depth domain adaptation\n")
    
    if results_dict:
        f.write("\n" + "="*60 + "\n")
        f.write("Per-Seed Results:\n")
        f.write("="*60 + "\n")
        f.write(df.to_string(float_format=lambda x: f"{x:.4f}"))
        
        f.write("\n\n" + "-"*60 + "\n")
        f.write("Summary (Mean ± Std):\n")
        f.write("-"*60 + "\n")
        for col in df.columns:
            f.write(f"  {col}: {avg[col]:.4f} ± {std[col]:.4f}\n")
        
        f.write(f"\nBest Seed: {best_seed}\n")

print(f"\n✓ Results saved: {output_file}")

# Also save as JSON for programmatic access
json_output = {
    'experiment': 'A.4a',
    'variant': 'V2',
    'seeds': SEEDS,
    'config': {
        'model': 'yolo11n',
        'depth_source': 'synthetic',
        'epochs': EPOCHS,
        'patience': PATIENCE,
        'imgsz': IMGSZ,
        'batch': BATCH_SIZE,
        'augmentation': AUGMENT_PARAMS,
        'reset_bn': True,
    },
    'results': {str(k): v for k, v in results_dict.items()},
    'summary': {
        'mean': {k: float(v) for k, v in avg.items()},
        'std': {k: float(v) for k, v in std.items()},
        'best_seed': int(best_seed) if results_dict else None,
    } if results_dict else None,
}

json_file = KAGGLE_OUTPUT / 'a4a_synthetic_v2_results.json'
with open(json_file, 'w') as f:
    json.dump(json_output, f, indent=2)

print(f"✓ JSON saved: {json_file}")
# Out:
# ✓ Results saved: /kaggle/working/kaggleoutput/a4a_synthetic_v2_results.txt
# ✓ JSON saved: /kaggle/working/kaggleoutput/a4a_synthetic_v2_results.json

# %%
# =============================================================================
# Cell 10: Create Archives
# =============================================================================
print("\n" + "="*60)
print("CREATING ARCHIVES")
print("="*60 + "\n")

# Archive training runs
if RUNS_PATH.exists():
    runs_zip = BASE_PATH / 'a4a_synthetic_v2_runs.zip'
    shutil.make_archive(str(runs_zip.with_suffix('')), 'zip', RUNS_PATH)
    size_mb = runs_zip.stat().st_size / 1024 / 1024
    print(f"✓ a4a_synthetic_v2_runs.zip: {size_mb:.1f} MB")
else:
    print("✗ No runs directory found")

# Archive outputs
output_zip = BASE_PATH / 'a4a_synthetic_v2_output.zip'
shutil.make_archive(str(output_zip.with_suffix('')), 'zip', KAGGLE_OUTPUT)
size_mb = output_zip.stat().st_size / 1024 / 1024
print(f"✓ a4a_synthetic_v2_output.zip: {size_mb:.1f} MB")

print("\n" + "="*60)
print("ALL DONE!")
print("="*60)
print("\nDownload from Output tab:")
print("  - a4a_synthetic_v2_runs.zip (training runs)")
print("  - a4a_synthetic_v2_output.zip (results)")
# Out:
# ============================================================
# CREATING ARCHIVES
# ============================================================
#
# ✓ a4a_synthetic_v2_runs.zip: 80.0 MB
# ✓ a4a_synthetic_v2_output.zip: 0.0 MB
#
# ============================================================
# ALL DONE!
# ============================================================
#
# Download from Output tab:
#   - a4a_synthetic_v2_runs.zip (training runs)
#   - a4a_synthetic_v2_output.zip (results)
